# %% [markdown]
# # Description
#
# Experiment for trying to combine stats from different resolutions.
#
# In this version all resolutions are normalized using a bilinear upsamplig from the function imresize from scipy package.

# %%
# %load_ext autoreload

import sys
sys.path.insert(0, "/store/tveiga/IC2017/utilities")

import pandas as pd
import numpy as np

from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

import xgboost as xgb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
from IC2017 import *

# %% [markdown]
# <hr>

# %%
# Read database from disk
data = pd.read_csv("../IC2017_DATA/FancyApproach_dataset.csv", header = [0, 1])

# %%
# Copy non feature data from the base, before removing them for training purpose

y = data["GT"].iloc[:, 0] # iloc transform it into a Series
IMG = data["IMG"].iloc[:, 0]
# BLOCK = data["block_num"]
# solo = data["solo"]
base = data["solo"].iloc[:, 0]

#--------------------------

# Remove non feature data from the base, for training purpose

del data["GT"]
del data["IMG"] # big jump in precision by keeping this feature
del data["solo"]

#--------------------------

solo = base # just for variable name compatibility

# %% [markdown]
# <hr>

# %%
# Definition of the experiments

LessCompact = [0]
MoreCompact = [1]
Calibrated = [0, 1]
NotCalibrated = [2]
experiments = [[LessCompact, MoreCompact], [MoreCompact, LessCompact],
              [Calibrated, NotCalibrated], [NotCalibrated, Calibrated]]

# %% [markdown]
# <hr>

# %%
loo = LeaveOneOut()

# %%
VI_cols = names_VI = data.columns.to_list()

# %%
# %%time

'''
Just like in the standard experiment, here we want to know how effective each feature is for
generelazing. Therefore we should obtain training, validation and test accuracy, and also the
threshold found.
''' 

VI_scores = [[[] for vi in names_VI] for _ in range(4)] # 4 is the number of experiments
VI_scores_val = [[[] for vi in names_VI] for _ in range(4)]
VI_scores_test = [[0 for vi in names_VI] for _ in range(4)]
THS = [[[] for vi in names_VI] for _ in range(4)]

for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    
    images = list(set(IMG.loc[solo.isin(left).values.ravel()]))
    for vi, col in enumerate(VI_cols):
        print('>', col)
        
        for train_imgs, test_imgs in loo.split(images):
            
            # fit (find th in fit set)
            prediction = data.loc[IMG.isin(train_imgs), col]
            _auc, mean_acc, bestTH, fpr, tpr = getPerformance(y.loc[IMG.isin(train_imgs)], prediction)
            
            # validate
            prediction = data.loc[IMG.isin(test_imgs), col]
            val_mean_acc = accuracy_score(y.loc[IMG.isin(test_imgs)], 1 * (prediction > bestTH)) # 1 * array = array.astype(int)

            # save results (fit, val and th)
            VI_scores[e][vi].append(mean_acc)
            VI_scores_val[e][vi].append(val_mean_acc)
            THS[e][vi].append(bestTH)
            print(" > > %s\t%s \t Fit vs Val (MAc) = %.3f vs %.3f" % (*col, mean_acc, val_mean_acc))
            
        ths = pd.Series(THS[e][vi])
        print(" > > BEST-TH: %.3f (%.3f)" % (ths.median(), ths.std()))
        
        # test score
        prediction = data.loc[solo.isin(test), col]
        test_mean_acc = accuracy_score(y.loc[solo.isin(test)], 1 * (prediction > bestTH))
        VI_scores_test[e][vi] = test_mean_acc
        print(' > > Test Acc: %.3f' % test_mean_acc)
        
        
print("Done.")
# Out:
# Experiment [0] [1]
# > ('8', 'mean')
#  > > 8	mean 	 Fit vs Val (MAc) = 0.809 vs 0.428
#  > > 8	mean 	 Fit vs Val (MAc) = 0.792 vs 0.880
#  > > 8	mean 	 Fit vs Val (MAc) = 0.797 vs 0.809
#  > > 8	mean 	 Fit vs Val (MAc) = 0.792 vs 0.950
#  > > 8	mean 	 Fit vs Val (MAc) = 0.797 vs 0.740
#  > > 8	mean 	 Fit vs Val (MAc) = 0.790 vs 0.914
#  > > 8	mean 	 Fit vs Val (MAc) = 0.800 vs 0.706
#  > > 8	mean 	 Fit vs Val (MAc) = 0.779 vs 0.987
#  > > 8	mean 	 Fit vs Val (MAc) = 0.793 vs 0.932
#  > > 8	mean 	 Fit vs Val (MAc) = 0.797 vs 0.757
#  > > 8	mean 	 Fit vs Val (MAc) = 0.828 vs 0.681
# /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/numpy/lib/function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  > > 8	mean 	 Fit vs Val (MAc) = 0.798 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.813 vs 0.343
#  > > 8	mean 	 Fit vs Val (MAc) = 0.801 vs 0.799
#  > > 8	mean 	 Fit vs Val (MAc) = 0.813 vs 0.329
#  > > 8	mean 	 Fit vs Val (MAc) = 0.807 vs 0.508
#  > > 8	mean 	 Fit vs Val (MAc) = 0.785 vs 0.950
#  > > BEST-TH: 128.000 (5.040)
# > ('8', 'max')
#  > > 8	max 	 Fit vs Val (MAc) = 0.730 vs 0.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.735 vs 0.022
#  > > 8	max 	 Fit vs Val (MAc) = 0.763 vs 0.872
#  > > 8	max 	 Fit vs Val (MAc) = 0.762 vs 0.838
#  > > 8	max 	 Fit vs Val (MAc) = 0.740 vs 0.044
#  > > 8	max 	 Fit vs Val (MAc) = 0.766 vs 0.940
#  > > 8	max 	 Fit vs Val (MAc) = 0.734 vs 0.017
#  > > 8	max 	 Fit vs Val (MAc) = 0.751 vs 0.605
#  > > 8	max 	 Fit vs Val (MAc) = 0.741 vs 0.048
#  > > 8	max 	 Fit vs Val (MAc) = 0.734 vs 0.016
#  > > 8	max 	 Fit vs Val (MAc) = 0.731 vs 0.239
#  > > 8	max 	 Fit vs Val (MAc) = 0.747 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.730 vs 0.003
#  > > 8	max 	 Fit vs Val (MAc) = 0.767 vs 0.958
#  > > 8	max 	 Fit vs Val (MAc) = 0.730 vs 0.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.767 vs 0.966
#  > > 8	max 	 Fit vs Val (MAc) = 0.752 vs 0.628
#  > > BEST-TH: 1.000 (0.000)
# > ('8', 'min')
#  > > 8	min 	 Fit vs Val (MAc) = 0.615 vs 0.866
#  > > 8	min 	 Fit vs Val (MAc) = 0.620 vs 0.781
#  > > 8	min 	 Fit vs Val (MAc) = 0.628 vs 0.731
#  > > 8	min 	 Fit vs Val (MAc) = 0.608 vs 0.347
#  > > 8	min 	 Fit vs Val (MAc) = 0.624 vs 0.708
#  > > 8	min 	 Fit vs Val (MAc) = 0.613 vs 0.792
#  > > 8	min 	 Fit vs Val (MAc) = 0.620 vs 0.745
#  > > 8	min 	 Fit vs Val (MAc) = 0.656 vs 0.647
#  > > 8	min 	 Fit vs Val (MAc) = 0.617 vs 0.814
#  > > 8	min 	 Fit vs Val (MAc) = 0.627 vs 0.496
#  > > 8	min 	 Fit vs Val (MAc) = 0.646 vs 0.402
#  > > 8	min 	 Fit vs Val (MAc) = 0.619 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.619 vs 0.745
#  > > 8	min 	 Fit vs Val (MAc) = 0.619 vs 0.769
#  > > 8	min 	 Fit vs Val (MAc) = 0.621 vs 0.702
#  > > 8	min 	 Fit vs Val (MAc) = 0.623 vs 0.659
#  > > 8	min 	 Fit vs Val (MAc) = 0.581 vs 0.760
#  > > BEST-TH: 107.000 (13.507)
# > ('8', 'std')
#  > > 8	std 	 Fit vs Val (MAc) = 0.737 vs 0.683
#  > > 8	std 	 Fit vs Val (MAc) = 0.730 vs 0.843
#  > > 8	std 	 Fit vs Val (MAc) = 0.733 vs 0.746
#  > > 8	std 	 Fit vs Val (MAc) = 0.734 vs 0.930
#  > > 8	std 	 Fit vs Val (MAc) = 0.729 vs 0.845
#  > > 8	std 	 Fit vs Val (MAc) = 0.732 vs 0.884
#  > > 8	std 	 Fit vs Val (MAc) = 0.740 vs 0.557
#  > > 8	std 	 Fit vs Val (MAc) = 0.708 vs 0.975
#  > > 8	std 	 Fit vs Val (MAc) = 0.734 vs 0.745
#  > > 8	std 	 Fit vs Val (MAc) = 0.742 vs 0.525
#  > > 8	std 	 Fit vs Val (MAc) = 0.768 vs 0.589
#  > > 8	std 	 Fit vs Val (MAc) = 0.736 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.743 vs 0.524
#  > > 8	std 	 Fit vs Val (MAc) = 0.746 vs 0.561
#  > > 8	std 	 Fit vs Val (MAc) = 0.753 vs 0.256
#  > > 8	std 	 Fit vs Val (MAc) = 0.746 vs 0.534
#  > > 8	std 	 Fit vs Val (MAc) = 0.717 vs 0.953
#  > > BEST-TH: 120.000 (6.145)
# > ('16', 'mean')
#  > > 16	mean 	 Fit vs Val (MAc) = 0.790 vs 0.380
#  > > 16	mean 	 Fit vs Val (MAc) = 0.771 vs 0.861
#  > > 16	mean 	 Fit vs Val (MAc) = 0.773 vs 0.825
#  > > 16	mean 	 Fit vs Val (MAc) = 0.765 vs 0.955
#  > > 16	mean 	 Fit vs Val (MAc) = 0.772 vs 0.956
#  > > 16	mean 	 Fit vs Val (MAc) = 0.767 vs 0.949
#  > > 16	mean 	 Fit vs Val (MAc) = 0.778 vs 0.705
#  > > 16	mean 	 Fit vs Val (MAc) = 0.753 vs 0.985
#  > > 16	mean 	 Fit vs Val (MAc) = 0.773 vs 0.779
#  > > 16	mean 	 Fit vs Val (MAc) = 0.779 vs 0.638
#  > > 16	mean 	 Fit vs Val (MAc) = 0.857 vs 0.446
#  > > 16	mean 	 Fit vs Val (MAc) = 0.777 vs nan
#  > > 16	mean 	 Fit vs Val (MAc) = 0.792 vs 0.328
#  > > 16	mean 	 Fit vs Val (MAc) = 0.774 vs 0.934
#  > > 16	mean 	 Fit vs Val (MAc) = 0.798 vs 0.187
#  > > 16	mean 	 Fit vs Val (MAc) = 0.781 vs 0.582
#  > > 16	mean 	 Fit vs Val (MAc) = 0.759 vs 0.950
#  > > BEST-TH: 138.000 (8.313)
# > ('16', 'max')
#  > > 16	max 	 Fit vs Val (MAc) = 0.889 vs 0.992
#  > > 16	max 	 Fit vs Val (MAc) = 0.892 vs 0.980
#  > > 16	max 	 Fit vs Val (MAc) = 0.907 vs 0.887
#  > > 16	max 	 Fit vs Val (MAc) = 0.890 vs 0.957
#  > > 16	max 	 Fit vs Val (MAc) = 0.896 vs 0.958
#  > > 16	max 	 Fit vs Val (MAc) = 0.893 vs 0.970
#  > > 16	max 	 Fit vs Val (MAc) = 0.892 vs 0.967
#  > > 16	max 	 Fit vs Val (MAc) = 0.874 vs 0.986
#  > > 16	max 	 Fit vs Val (MAc) = 0.896 vs 0.954
#  > > 16	max 	 Fit vs Val (MAc) = 0.891 vs 0.960
#  > > 16	max 	 Fit vs Val (MAc) = 0.852 vs 0.815
#  > > 16	max 	 Fit vs Val (MAc) = 0.891 vs nan
#  > > 16	max 	 Fit vs Val (MAc) = 0.890 vs 0.984
#  > > 16	max 	 Fit vs Val (MAc) = 0.902 vs 0.803
#  > > 16	max 	 Fit vs Val (MAc) = 0.891 vs 0.930
#  > > 16	max 	 Fit vs Val (MAc) = 0.904 vs 0.685
#  > > 16	max 	 Fit vs Val (MAc) = 0.879 vs 0.959
#  > > BEST-TH: 174.000 (10.203)
# > ('16', 'min')
#  > > 16	min 	 Fit vs Val (MAc) = 0.679 vs 0.781
#  > > 16	min 	 Fit vs Val (MAc) = 0.683 vs 0.731
#  > > 16	min 	 Fit vs Val (MAc) = 0.693 vs 0.701
#  > > 16	min 	 Fit vs Val (MAc) = 0.671 vs 0.655
#  > > 16	min 	 Fit vs Val (MAc) = 0.681 vs 0.842
#  > > 16	min 	 Fit vs Val (MAc) = 0.682 vs 0.607
#  > > 16	min 	 Fit vs Val (MAc) = 0.679 vs 0.803
#  > > 16	min 	 Fit vs Val (MAc) = 0.680 vs 0.728
#  > > 16	min 	 Fit vs Val (MAc) = 0.686 vs 0.575
#  > > 16	min 	 Fit vs Val (MAc) = 0.682 vs 0.679
#  > > 16	min 	 Fit vs Val (MAc) = 0.727 vs 0.556
#  > > 16	min 	 Fit vs Val (MAc) = 0.680 vs nan
#  > > 16	min 	 Fit vs Val (MAc) = 0.681 vs 0.737
#  > > 16	min 	 Fit vs Val (MAc) = 0.680 vs 0.821
#  > > 16	min 	 Fit vs Val (MAc) = 0.683 vs 0.679
#  > > 16	min 	 Fit vs Val (MAc) = 0.679 vs 0.738
#  > > 16	min 	 Fit vs Val (MAc) = 0.643 vs 0.831
#  > > BEST-TH: 115.000 (3.968)
# > ('16', 'std')
#  > > 16	std 	 Fit vs Val (MAc) = 0.820 vs 0.876
#  > > 16	std 	 Fit vs Val (MAc) = 0.819 vs 0.881
#  > > 16	std 	 Fit vs Val (MAc) = 0.824 vs 0.808
#  > > 16	std 	 Fit vs Val (MAc) = 0.818 vs 0.954
#  > > 16	std 	 Fit vs Val (MAc) = 0.823 vs 0.872
#  > > 16	std 	 Fit vs Val (MAc) = 0.818 vs 0.969
#  > > 16	std 	 Fit vs Val (MAc) = 0.822 vs 0.866
#  > > 16	std 	 Fit vs Val (MAc) = 0.803 vs 0.982
#  > > 16	std 	 Fit vs Val (MAc) = 0.824 vs 0.786
#  > > 16	std 	 Fit vs Val (MAc) = 0.826 vs 0.768
#  > > 16	std 	 Fit vs Val (MAc) = 0.830 vs 0.761
#  > > 16	std 	 Fit vs Val (MAc) = 0.823 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.827 vs 0.698
#  > > 16	std 	 Fit vs Val (MAc) = 0.836 vs 0.587
#  > > 16	std 	 Fit vs Val (MAc) = 0.830 vs 0.603
#  > > 16	std 	 Fit vs Val (MAc) = 0.833 vs 0.649
#  > > 16	std 	 Fit vs Val (MAc) = 0.811 vs 0.960
#  > > BEST-TH: 99.000 (3.226)
# > ('32', 'mean')
#  > > 32	mean 	 Fit vs Val (MAc) = 0.796 vs 0.476
#  > > 32	mean 	 Fit vs Val (MAc) = 0.784 vs 0.755
#  > > 32	mean 	 Fit vs Val (MAc) = 0.782 vs 0.836
#  > > 32	mean 	 Fit vs Val (MAc) = 0.771 vs 0.937
#  > > 32	mean 	 Fit vs Val (MAc) = 0.781 vs 0.889
#  > > 32	mean 	 Fit vs Val (MAc) = 0.776 vs 0.947
#  > > 32	mean 	 Fit vs Val (MAc) = 0.781 vs 0.880
#  > > 32	mean 	 Fit vs Val (MAc) = 0.754 vs 0.984
#  > > 32	mean 	 Fit vs Val (MAc) = 0.779 vs 0.861
#  > > 32	mean 	 Fit vs Val (MAc) = 0.778 vs 0.959
#  > > 32	mean 	 Fit vs Val (MAc) = 0.875 vs 0.445
#  > > 32	mean 	 Fit vs Val (MAc) = 0.784 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.800 vs 0.374
#  > > 32	mean 	 Fit vs Val (MAc) = 0.783 vs 0.956
#  > > 32	mean 	 Fit vs Val (MAc) = 0.794 vs 0.511
#  > > 32	mean 	 Fit vs Val (MAc) = 0.784 vs 0.767
#  > > 32	mean 	 Fit vs Val (MAc) = 0.761 vs 0.957
#  > > BEST-TH: 120.000 (5.349)
# > ('32', 'max')
#  > > 32	max 	 Fit vs Val (MAc) = 0.892 vs 0.992
#  > > 32	max 	 Fit vs Val (MAc) = 0.895 vs 0.973
#  > > 32	max 	 Fit vs Val (MAc) = 0.907 vs 0.874
#  > > 32	max 	 Fit vs Val (MAc) = 0.893 vs 0.965
#  > > 32	max 	 Fit vs Val (MAc) = 0.899 vs 0.963
#  > > 32	max 	 Fit vs Val (MAc) = 0.895 vs 0.979
#  > > 32	max 	 Fit vs Val (MAc) = 0.896 vs 0.950
#  > > 32	max 	 Fit vs Val (MAc) = 0.878 vs 0.982
#  > > 32	max 	 Fit vs Val (MAc) = 0.899 vs 0.962
#  > > 32	max 	 Fit vs Val (MAc) = 0.895 vs 0.979
#  > > 32	max 	 Fit vs Val (MAc) = 0.858 vs 0.932
#  > > 32	max 	 Fit vs Val (MAc) = 0.894 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.895 vs 0.934
#  > > 32	max 	 Fit vs Val (MAc) = 0.903 vs 0.867
#  > > 32	max 	 Fit vs Val (MAc) = 0.899 vs 0.805
#  > > 32	max 	 Fit vs Val (MAc) = 0.908 vs 0.645
#  > > 32	max 	 Fit vs Val (MAc) = 0.883 vs 0.964
#  > > BEST-TH: 126.000 (3.486)
# > ('32', 'min')
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs 0.779
#  > > 32	min 	 Fit vs Val (MAc) = 0.728 vs 0.712
#  > > 32	min 	 Fit vs Val (MAc) = 0.733 vs 0.655
#  > > 32	min 	 Fit vs Val (MAc) = 0.714 vs 0.742
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.800
#  > > 32	min 	 Fit vs Val (MAc) = 0.727 vs 0.596
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs 0.859
#  > > 32	min 	 Fit vs Val (MAc) = 0.704 vs 0.831
#  > > 32	min 	 Fit vs Val (MAc) = 0.727 vs 0.649
#  > > 32	min 	 Fit vs Val (MAc) = 0.722 vs 0.810
#  > > 32	min 	 Fit vs Val (MAc) = 0.790 vs 0.549
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.726 vs 0.715
#  > > 32	min 	 Fit vs Val (MAc) = 0.722 vs 0.851
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs 0.849
#  > > 32	min 	 Fit vs Val (MAc) = 0.722 vs 0.795
#  > > 32	min 	 Fit vs Val (MAc) = 0.691 vs 0.874
#  > > BEST-TH: 116.000 (2.942)
# > ('32', 'std')
#  > > 32	std 	 Fit vs Val (MAc) = 0.824 vs 0.924
#  > > 32	std 	 Fit vs Val (MAc) = 0.825 vs 0.922
#  > > 32	std 	 Fit vs Val (MAc) = 0.833 vs 0.757
#  > > 32	std 	 Fit vs Val (MAc) = 0.824 vs 0.926
#  > > 32	std 	 Fit vs Val (MAc) = 0.827 vs 0.954
#  > > 32	std 	 Fit vs Val (MAc) = 0.822 vs 0.976
#  > > 32	std 	 Fit vs Val (MAc) = 0.832 vs 0.723
#  > > 32	std 	 Fit vs Val (MAc) = 0.808 vs 0.970
#  > > 32	std 	 Fit vs Val (MAc) = 0.828 vs 0.935
#  > > 32	std 	 Fit vs Val (MAc) = 0.827 vs 0.909
#  > > 32	std 	 Fit vs Val (MAc) = 0.831 vs 0.801
#  > > 32	std 	 Fit vs Val (MAc) = 0.828 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.827 vs 0.863
#  > > 32	std 	 Fit vs Val (MAc) = 0.842 vs 0.575
#  > > 32	std 	 Fit vs Val (MAc) = 0.845 vs 0.381
#  > > 32	std 	 Fit vs Val (MAc) = 0.842 vs 0.523
#  > > 32	std 	 Fit vs Val (MAc) = 0.813 vs 0.956
#  > > BEST-TH: 78.000 (2.398)
# > ('64', 'mean')
#  > > 64	mean 	 Fit vs Val (MAc) = 0.785 vs 0.861
#  > > 64	mean 	 Fit vs Val (MAc) = 0.785 vs 0.908
#  > > 64	mean 	 Fit vs Val (MAc) = 0.788 vs 0.724
#  > > 64	mean 	 Fit vs Val (MAc) = 0.774 vs 0.930
#  > > 64	mean 	 Fit vs Val (MAc) = 0.785 vs 0.904
#  > > 64	mean 	 Fit vs Val (MAc) = 0.781 vs 0.948
#  > > 64	mean 	 Fit vs Val (MAc) = 0.783 vs 0.969
#  > > 64	mean 	 Fit vs Val (MAc) = 0.750 vs 0.984
#  > > 64	mean 	 Fit vs Val (MAc) = 0.789 vs 0.683
#  > > 64	mean 	 Fit vs Val (MAc) = 0.783 vs 0.951
#  > > 64	mean 	 Fit vs Val (MAc) = 0.882 vs 0.455
#  > > 64	mean 	 Fit vs Val (MAc) = 0.785 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.787 vs 0.826
#  > > 64	mean 	 Fit vs Val (MAc) = 0.786 vs 0.933
#  > > 64	mean 	 Fit vs Val (MAc) = 0.792 vs 0.664
#  > > 64	mean 	 Fit vs Val (MAc) = 0.787 vs 0.818
#  > > 64	mean 	 Fit vs Val (MAc) = 0.756 vs 0.955
#  > > BEST-TH: 91.000 (2.830)
# > ('64', 'max')
#  > > 64	max 	 Fit vs Val (MAc) = 0.891 vs 0.960
#  > > 64	max 	 Fit vs Val (MAc) = 0.893 vs 0.956
#  > > 64	max 	 Fit vs Val (MAc) = 0.907 vs 0.875
#  > > 64	max 	 Fit vs Val (MAc) = 0.891 vs 0.955
#  > > 64	max 	 Fit vs Val (MAc) = 0.896 vs 0.950
#  > > 64	max 	 Fit vs Val (MAc) = 0.892 vs 0.977
#  > > 64	max 	 Fit vs Val (MAc) = 0.894 vs 0.932
#  > > 64	max 	 Fit vs Val (MAc) = 0.876 vs 0.972
#  > > 64	max 	 Fit vs Val (MAc) = 0.895 vs 0.958
#  > > 64	max 	 Fit vs Val (MAc) = 0.893 vs 0.962
#  > > 64	max 	 Fit vs Val (MAc) = 0.862 vs 0.952
#  > > 64	max 	 Fit vs Val (MAc) = 0.892 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.892 vs 0.936
#  > > 64	max 	 Fit vs Val (MAc) = 0.898 vs 0.908
#  > > 64	max 	 Fit vs Val (MAc) = 0.900 vs 0.716
#  > > 64	max 	 Fit vs Val (MAc) = 0.902 vs 0.713
#  > > 64	max 	 Fit vs Val (MAc) = 0.882 vs 0.957
#  > > BEST-TH: 99.000 (1.064)
# > ('64', 'min')
#  > > 64	min 	 Fit vs Val (MAc) = 0.728 vs 0.640
#  > > 64	min 	 Fit vs Val (MAc) = 0.724 vs 0.782
#  > > 64	min 	 Fit vs Val (MAc) = 0.731 vs 0.808
#  > > 64	min 	 Fit vs Val (MAc) = 0.713 vs 0.625
#  > > 64	min 	 Fit vs Val (MAc) = 0.722 vs 0.874
#  > > 64	min 	 Fit vs Val (MAc) = 0.720 vs 0.765
#  > > 64	min 	 Fit vs Val (MAc) = 0.719 vs 0.916
#  > > 64	min 	 Fit vs Val (MAc) = 0.686 vs 0.907
#  > > 64	min 	 Fit vs Val (MAc) = 0.721 vs 0.800
#  > > 64	min 	 Fit vs Val (MAc) = 0.719 vs 0.879
#  > > 64	min 	 Fit vs Val (MAc) = 0.811 vs 0.440
#  > > 64	min 	 Fit vs Val (MAc) = 0.720 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.720 vs 0.871
#  > > 64	min 	 Fit vs Val (MAc) = 0.720 vs 0.910
#  > > 64	min 	 Fit vs Val (MAc) = 0.718 vs 0.917
#  > > 64	min 	 Fit vs Val (MAc) = 0.719 vs 0.897
#  > > 64	min 	 Fit vs Val (MAc) = 0.681 vs 0.937
#  > > BEST-TH: 102.000 (2.344)
# > ('64', 'std')
#  > > 64	std 	 Fit vs Val (MAc) = 0.841 vs 0.854
#  > > 64	std 	 Fit vs Val (MAc) = 0.840 vs 0.927
#  > > 64	std 	 Fit vs Val (MAc) = 0.851 vs 0.832
#  > > 64	std 	 Fit vs Val (MAc) = 0.839 vs 0.905
#  > > 64	std 	 Fit vs Val (MAc) = 0.842 vs 0.942
#  > > 64	std 	 Fit vs Val (MAc) = 0.838 vs 0.964
#  > > 64	std 	 Fit vs Val (MAc) = 0.841 vs 0.874
#  > > 64	std 	 Fit vs Val (MAc) = 0.820 vs 0.893
#  > > 64	std 	 Fit vs Val (MAc) = 0.841 vs 0.936
#  > > 64	std 	 Fit vs Val (MAc) = 0.843 vs 0.828
#  > > 64	std 	 Fit vs Val (MAc) = 0.829 vs 0.834
#  > > 64	std 	 Fit vs Val (MAc) = 0.840 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.842 vs 0.814
#  > > 64	std 	 Fit vs Val (MAc) = 0.847 vs 0.803
#  > > 64	std 	 Fit vs Val (MAc) = 0.843 vs 0.779
#  > > 64	std 	 Fit vs Val (MAc) = 0.853 vs 0.579
#  > > 64	std 	 Fit vs Val (MAc) = 0.825 vs 0.933
#  > > BEST-TH: 49.000 (1.222)
# > ('128', 'mean')
#  > > 128	mean 	 Fit vs Val (MAc) = 0.841 vs 0.873
#  > > 128	mean 	 Fit vs Val (MAc) = 0.842 vs 0.892
#  > > 128	mean 	 Fit vs Val (MAc) = 0.853 vs 0.672
#  > > 128	mean 	 Fit vs Val (MAc) = 0.839 vs 0.889
#  > > 128	mean 	 Fit vs Val (MAc) = 0.845 vs 0.862
#  > > 128	mean 	 Fit vs Val (MAc) = 0.843 vs 0.827
#  > > 128	mean 	 Fit vs Val (MAc) = 0.845 vs 0.793
#  > > 128	mean 	 Fit vs Val (MAc) = 0.825 vs 0.965
#  > > 128	mean 	 Fit vs Val (MAc) = 0.846 vs 0.750
#  > > 128	mean 	 Fit vs Val (MAc) = 0.842 vs 0.866
#  > > 128	mean 	 Fit vs Val (MAc) = 0.862 vs 0.696
#  > > 128	mean 	 Fit vs Val (MAc) = 0.843 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.844 vs 0.792
#  > > 128	mean 	 Fit vs Val (MAc) = 0.845 vs 0.854
#  > > 128	mean 	 Fit vs Val (MAc) = 0.847 vs 0.716
#  > > 128	mean 	 Fit vs Val (MAc) = 0.847 vs 0.741
#  > > 128	mean 	 Fit vs Val (MAc) = 0.829 vs 0.932
#  > > BEST-TH: 79.000 (2.339)
# > ('128', 'max')
#  > > 128	max 	 Fit vs Val (MAc) = 0.878 vs 0.934
#  > > 128	max 	 Fit vs Val (MAc) = 0.880 vs 0.960
#  > > 128	max 	 Fit vs Val (MAc) = 0.892 vs 0.799
#  > > 128	max 	 Fit vs Val (MAc) = 0.878 vs 0.931
#  > > 128	max 	 Fit vs Val (MAc) = 0.883 vs 0.924
#  > > 128	max 	 Fit vs Val (MAc) = 0.879 vs 0.935
#  > > 128	max 	 Fit vs Val (MAc) = 0.882 vs 0.874
#  > > 128	max 	 Fit vs Val (MAc) = 0.863 vs 0.970
#  > > 128	max 	 Fit vs Val (MAc) = 0.882 vs 0.876
#  > > 128	max 	 Fit vs Val (MAc) = 0.880 vs 0.915
#  > > 128	max 	 Fit vs Val (MAc) = 0.866 vs 0.856
#  > > 128	max 	 Fit vs Val (MAc) = 0.880 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.879 vs 0.915
#  > > 128	max 	 Fit vs Val (MAc) = 0.885 vs 0.853
#  > > 128	max 	 Fit vs Val (MAc) = 0.884 vs 0.772
#  > > 128	max 	 Fit vs Val (MAc) = 0.886 vs 0.764
#  > > 128	max 	 Fit vs Val (MAc) = 0.868 vs 0.951
#  > > BEST-TH: 86.000 (1.759)
# > ('128', 'min')
#  > > 128	min 	 Fit vs Val (MAc) = 0.689 vs 0.758
#  > > 128	min 	 Fit vs Val (MAc) = 0.691 vs 0.694
#  > > 128	min 	 Fit vs Val (MAc) = 0.692 vs 0.778
#  > > 128	min 	 Fit vs Val (MAc) = 0.672 vs 0.853
#  > > 128	min 	 Fit vs Val (MAc) = 0.689 vs 0.755
#  > > 128	min 	 Fit vs Val (MAc) = 0.687 vs 0.697
#  > > 128	min 	 Fit vs Val (MAc) = 0.686 vs 0.832
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.845
#  > > 128	min 	 Fit vs Val (MAc) = 0.689 vs 0.695
#  > > 128	min 	 Fit vs Val (MAc) = 0.685 vs 0.881
#  > > 128	min 	 Fit vs Val (MAc) = 0.787 vs 0.396
#  > > 128	min 	 Fit vs Val (MAc) = 0.687 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.689 vs 0.760
#  > > 128	min 	 Fit vs Val (MAc) = 0.685 vs 0.937
#  > > 128	min 	 Fit vs Val (MAc) = 0.690 vs 0.728
#  > > 128	min 	 Fit vs Val (MAc) = 0.685 vs 0.901
#  > > 128	min 	 Fit vs Val (MAc) = 0.645 vs 0.946
#  > > BEST-TH: 74.000 (1.586)
# > ('128', 'std')
#  > > 128	std 	 Fit vs Val (MAc) = 0.802 vs 0.872
#  > > 128	std 	 Fit vs Val (MAc) = 0.803 vs 0.879
#  > > 128	std 	 Fit vs Val (MAc) = 0.814 vs 0.792
#  > > 128	std 	 Fit vs Val (MAc) = 0.802 vs 0.815
#  > > 128	std 	 Fit vs Val (MAc) = 0.805 vs 0.876
#  > > 128	std 	 Fit vs Val (MAc) = 0.801 vs 0.920
#  > > 128	std 	 Fit vs Val (MAc) = 0.804 vs 0.835
#  > > 128	std 	 Fit vs Val (MAc) = 0.780 vs 0.878
#  > > 128	std 	 Fit vs Val (MAc) = 0.804 vs 0.895
#  > > 128	std 	 Fit vs Val (MAc) = 0.807 vs 0.762
#  > > 128	std 	 Fit vs Val (MAc) = 0.816 vs 0.711
#  > > 128	std 	 Fit vs Val (MAc) = 0.803 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.805 vs 0.788
#  > > 128	std 	 Fit vs Val (MAc) = 0.810 vs 0.747
#  > > 128	std 	 Fit vs Val (MAc) = 0.806 vs 0.748
#  > > 128	std 	 Fit vs Val (MAc) = 0.811 vs 0.659
#  > > 128	std 	 Fit vs Val (MAc) = 0.785 vs 0.842
#  > > BEST-TH: 31.000 (1.144)
# > ('512', 'ori')
#  > > 512	ori 	 Fit vs Val (MAc) = 0.811 vs 0.831
#  > > 512	ori 	 Fit vs Val (MAc) = 0.813 vs 0.823
#  > > 512	ori 	 Fit vs Val (MAc) = 0.824 vs 0.676
#  > > 512	ori 	 Fit vs Val (MAc) = 0.809 vs 0.844
#  > > 512	ori 	 Fit vs Val (MAc) = 0.816 vs 0.772
#  > > 512	ori 	 Fit vs Val (MAc) = 0.813 vs 0.789
#  > > 512	ori 	 Fit vs Val (MAc) = 0.814 vs 0.776
#  > > 512	ori 	 Fit vs Val (MAc) = 0.795 vs 0.807
#  > > 512	ori 	 Fit vs Val (MAc) = 0.816 vs 0.739
#  > > 512	ori 	 Fit vs Val (MAc) = 0.811 vs 0.858
#  > > 512	ori 	 Fit vs Val (MAc) = 0.840 vs 0.581
#  > > 512	ori 	 Fit vs Val (MAc) = 0.812 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.812 vs 0.799
#  > > 512	ori 	 Fit vs Val (MAc) = 0.815 vs 0.791
#  > > 512	ori 	 Fit vs Val (MAc) = 0.809 vs 0.862
#  > > 512	ori 	 Fit vs Val (MAc) = 0.812 vs 0.842
#  > > 512	ori 	 Fit vs Val (MAc) = 0.798 vs 0.828
#  > > BEST-TH: 0.306 (0.012)
# Experiment [1] [0]
# > ('8', 'mean')
#  > > 8	mean 	 Fit vs Val (MAc) = 0.795 vs 0.371
#  > > 8	mean 	 Fit vs Val (MAc) = 0.780 vs 0.837
#  > > 8	mean 	 Fit vs Val (MAc) = 0.782 vs 0.786
#  > > 8	mean 	 Fit vs Val (MAc) = 0.778 vs 0.946
#  > > 8	mean 	 Fit vs Val (MAc) = 0.784 vs 0.683
#  > > 8	mean 	 Fit vs Val (MAc) = 0.777 vs 0.908
#  > > 8	mean 	 Fit vs Val (MAc) = 0.786 vs 0.674
#  > > 8	mean 	 Fit vs Val (MAc) = 0.766 vs 0.984
#  > > 8	mean 	 Fit vs Val (MAc) = 0.779 vs 0.932
#  > > 8	mean 	 Fit vs Val (MAc) = 0.785 vs 0.647
#  > > 8	mean 	 Fit vs Val (MAc) = 0.784 vs 0.727
#  > > 8	mean 	 Fit vs Val (MAc) = 0.784 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.797 vs 0.324
#  > > 8	mean 	 Fit vs Val (MAc) = 0.786 vs 0.784
#  > > 8	mean 	 Fit vs Val (MAc) = 0.798 vs 0.270
#  > > 8	mean 	 Fit vs Val (MAc) = 0.792 vs 0.452
#  > > 8	mean 	 Fit vs Val (MAc) = 0.771 vs 0.947
#  > > 8	mean 	 Fit vs Val (MAc) = 0.778 vs 0.917
#  > > 8	mean 	 Fit vs Val (MAc) = 0.794 vs 0.818
#  > > 8	mean 	 Fit vs Val (MAc) = 0.793 vs 0.859
#  > > BEST-TH: 134.000 (5.038)
# > ('8', 'max')
#  > > 8	max 	 Fit vs Val (MAc) = 0.715 vs 0.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.719 vs 0.022
#  > > 8	max 	 Fit vs Val (MAc) = 0.743 vs 0.872
#  > > 8	max 	 Fit vs Val (MAc) = 0.742 vs 0.838
#  > > 8	max 	 Fit vs Val (MAc) = 0.724 vs 0.044
#  > > 8	max 	 Fit vs Val (MAc) = 0.745 vs 0.940
#  > > 8	max 	 Fit vs Val (MAc) = 0.718 vs 0.017
#  > > 8	max 	 Fit vs Val (MAc) = 0.733 vs 0.605
#  > > 8	max 	 Fit vs Val (MAc) = 0.724 vs 0.048
#  > > 8	max 	 Fit vs Val (MAc) = 0.718 vs 0.016
#  > > 8	max 	 Fit vs Val (MAc) = 0.718 vs 0.239
#  > > 8	max 	 Fit vs Val (MAc) = 0.730 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.715 vs 0.003
#  > > 8	max 	 Fit vs Val (MAc) = 0.746 vs 0.958
#  > > 8	max 	 Fit vs Val (MAc) = 0.715 vs 0.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.746 vs 0.966
#  > > 8	max 	 Fit vs Val (MAc) = 0.734 vs 0.628
#  > > 8	max 	 Fit vs Val (MAc) = 0.722 vs 0.038
#  > > 8	max 	 Fit vs Val (MAc) = 0.741 vs 0.831
#  > > 8	max 	 Fit vs Val (MAc) = 0.740 vs 0.778
#  > > BEST-TH: 1.000 (0.000)
# > ('8', 'min')
#  > > 8	min 	 Fit vs Val (MAc) = 0.632 vs 0.869
#  > > 8	min 	 Fit vs Val (MAc) = 0.636 vs 0.787
#  > > 8	min 	 Fit vs Val (MAc) = 0.645 vs 0.739
#  > > 8	min 	 Fit vs Val (MAc) = 0.626 vs 0.682
#  > > 8	min 	 Fit vs Val (MAc) = 0.640 vs 0.713
#  > > 8	min 	 Fit vs Val (MAc) = 0.631 vs 0.799
#  > > 8	min 	 Fit vs Val (MAc) = 0.636 vs 0.752
#  > > 8	min 	 Fit vs Val (MAc) = 0.671 vs 0.645
#  > > 8	min 	 Fit vs Val (MAc) = 0.634 vs 0.819
#  > > 8	min 	 Fit vs Val (MAc) = 0.642 vs 0.524
#  > > 8	min 	 Fit vs Val (MAc) = 0.674 vs 0.402
#  > > 8	min 	 Fit vs Val (MAc) = 0.636 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.636 vs 0.751
#  > > 8	min 	 Fit vs Val (MAc) = 0.636 vs 0.774
#  > > 8	min 	 Fit vs Val (MAc) = 0.637 vs 0.709
#  > > 8	min 	 Fit vs Val (MAc) = 0.639 vs 0.664
#  > > 8	min 	 Fit vs Val (MAc) = 0.598 vs 0.896
#  > > 8	min 	 Fit vs Val (MAc) = 0.635 vs 0.778
#  > > 8	min 	 Fit vs Val (MAc) = 0.630 vs 0.505
#  > > 8	min 	 Fit vs Val (MAc) = 0.627 vs 0.495
#  > > BEST-TH: 106.000 (3.392)
# > ('8', 'std')
#  > > 8	std 	 Fit vs Val (MAc) = 0.682 vs 0.669
#  > > 8	std 	 Fit vs Val (MAc) = 0.676 vs 0.839
#  > > 8	std 	 Fit vs Val (MAc) = 0.677 vs 0.743
#  > > 8	std 	 Fit vs Val (MAc) = 0.677 vs 0.930
#  > > 8	std 	 Fit vs Val (MAc) = 0.675 vs 0.845
#  > > 8	std 	 Fit vs Val (MAc) = 0.677 vs 0.880
#  > > 8	std 	 Fit vs Val (MAc) = 0.685 vs 0.557
#  > > 8	std 	 Fit vs Val (MAc) = 0.653 vs 0.972
#  > > 8	std 	 Fit vs Val (MAc) = 0.679 vs 0.745
#  > > 8	std 	 Fit vs Val (MAc) = 0.687 vs 0.493
#  > > 8	std 	 Fit vs Val (MAc) = 0.688 vs 0.504
#  > > 8	std 	 Fit vs Val (MAc) = 0.682 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.687 vs 0.507
#  > > 8	std 	 Fit vs Val (MAc) = 0.689 vs 0.548
#  > > 8	std 	 Fit vs Val (MAc) = 0.696 vs 0.241
#  > > 8	std 	 Fit vs Val (MAc) = 0.689 vs 0.524
#  > > 8	std 	 Fit vs Val (MAc) = 0.659 vs 0.954
#  > > 8	std 	 Fit vs Val (MAc) = 0.675 vs 0.961
#  > > 8	std 	 Fit vs Val (MAc) = 0.704 vs 0.240
#  > > 8	std 	 Fit vs Val (MAc) = 0.715 vs 0.361
#  > > BEST-TH: 122.000 (9.200)
# > ('16', 'mean')
#  > > 16	mean 	 Fit vs Val (MAc) = 0.782 vs 0.380
#  > > 16	mean 	 Fit vs Val (MAc) = 0.766 vs 0.854
#  > > 16	mean 	 Fit vs Val (MAc) = 0.766 vs 0.825
#  > > 16	mean 	 Fit vs Val (MAc) = 0.760 vs 0.955
#  > > 16	mean 	 Fit vs Val (MAc) = 0.766 vs 0.948
#  > > 16	mean 	 Fit vs Val (MAc) = 0.763 vs 0.949
#  > > 16	mean 	 Fit vs Val (MAc) = 0.772 vs 0.705
#  > > 16	mean 	 Fit vs Val (MAc) = 0.748 vs 0.985
#  > > 16	mean 	 Fit vs Val (MAc) = 0.768 vs 0.779
#  > > 16	mean 	 Fit vs Val (MAc) = 0.773 vs 0.638
#  > > 16	mean 	 Fit vs Val (MAc) = 0.810 vs 0.543
#  > > 16	mean 	 Fit vs Val (MAc) = 0.770 vs nan
#  > > 16	mean 	 Fit vs Val (MAc) = 0.784 vs 0.321
#  > > 16	mean 	 Fit vs Val (MAc) = 0.768 vs 0.934
#  > > 16	mean 	 Fit vs Val (MAc) = 0.789 vs 0.187
#  > > 16	mean 	 Fit vs Val (MAc) = 0.774 vs 0.582
#  > > 16	mean 	 Fit vs Val (MAc) = 0.753 vs 0.950
#  > > 16	mean 	 Fit vs Val (MAc) = 0.766 vs 0.833
#  > > 16	mean 	 Fit vs Val (MAc) = 0.775 vs 0.858
#  > > 16	mean 	 Fit vs Val (MAc) = 0.775 vs 0.878
#  > > BEST-TH: 138.500 (4.662)
# > ('16', 'max')
#  > > 16	max 	 Fit vs Val (MAc) = 0.857 vs 0.995
#  > > 16	max 	 Fit vs Val (MAc) = 0.859 vs 0.980
#  > > 16	max 	 Fit vs Val (MAc) = 0.872 vs 0.886
#  > > 16	max 	 Fit vs Val (MAc) = 0.860 vs 0.950
#  > > 16	max 	 Fit vs Val (MAc) = 0.863 vs 0.959
#  > > 16	max 	 Fit vs Val (MAc) = 0.861 vs 0.967
#  > > 16	max 	 Fit vs Val (MAc) = 0.859 vs 0.970
#  > > 16	max 	 Fit vs Val (MAc) = 0.845 vs 0.985
#  > > 16	max 	 Fit vs Val (MAc) = 0.863 vs 0.955
#  > > 16	max 	 Fit vs Val (MAc) = 0.859 vs 0.972
#  > > 16	max 	 Fit vs Val (MAc) = 0.829 vs 0.859
#  > > 16	max 	 Fit vs Val (MAc) = 0.860 vs nan
#  > > 16	max 	 Fit vs Val (MAc) = 0.857 vs 0.989
#  > > 16	max 	 Fit vs Val (MAc) = 0.867 vs 0.817
#  > > 16	max 	 Fit vs Val (MAc) = 0.858 vs 0.940
#  > > 16	max 	 Fit vs Val (MAc) = 0.868 vs 0.730
#  > > 16	max 	 Fit vs Val (MAc) = 0.849 vs 0.962
#  > > 16	max 	 Fit vs Val (MAc) = 0.862 vs 0.964
#  > > 16	max 	 Fit vs Val (MAc) = 0.874 vs 0.297
#  > > 16	max 	 Fit vs Val (MAc) = 0.871 vs 0.396
#  > > BEST-TH: 165.000 (14.404)
# > ('16', 'min')
#  > > 16	min 	 Fit vs Val (MAc) = 0.681 vs 0.815
#  > > 16	min 	 Fit vs Val (MAc) = 0.684 vs 0.766
#  > > 16	min 	 Fit vs Val (MAc) = 0.694 vs 0.718
#  > > 16	min 	 Fit vs Val (MAc) = 0.675 vs 0.674
#  > > 16	min 	 Fit vs Val (MAc) = 0.683 vs 0.862
#  > > 16	min 	 Fit vs Val (MAc) = 0.683 vs 0.652
#  > > 16	min 	 Fit vs Val (MAc) = 0.681 vs 0.828
#  > > 16	min 	 Fit vs Val (MAc) = 0.691 vs 0.699
#  > > 16	min 	 Fit vs Val (MAc) = 0.686 vs 0.625
#  > > 16	min 	 Fit vs Val (MAc) = 0.683 vs 0.714
#  > > 16	min 	 Fit vs Val (MAc) = 0.725 vs 0.548
#  > > 16	min 	 Fit vs Val (MAc) = 0.683 vs nan
#  > > 16	min 	 Fit vs Val (MAc) = 0.682 vs 0.772
#  > > 16	min 	 Fit vs Val (MAc) = 0.682 vs 0.840
#  > > 16	min 	 Fit vs Val (MAc) = 0.684 vs 0.717
#  > > 16	min 	 Fit vs Val (MAc) = 0.682 vs 0.773
#  > > 16	min 	 Fit vs Val (MAc) = 0.654 vs 0.854
#  > > 16	min 	 Fit vs Val (MAc) = 0.689 vs 0.498
#  > > 16	min 	 Fit vs Val (MAc) = 0.679 vs 0.534
#  > > 16	min 	 Fit vs Val (MAc) = 0.678 vs 0.696
#  > > BEST-TH: 111.000 (3.649)
# > ('16', 'std')
#  > > 16	std 	 Fit vs Val (MAc) = 0.761 vs 0.876
#  > > 16	std 	 Fit vs Val (MAc) = 0.759 vs 0.881
#  > > 16	std 	 Fit vs Val (MAc) = 0.761 vs 0.808
#  > > 16	std 	 Fit vs Val (MAc) = 0.756 vs 0.953
#  > > 16	std 	 Fit vs Val (MAc) = 0.762 vs 0.872
#  > > 16	std 	 Fit vs Val (MAc) = 0.757 vs 0.969
#  > > 16	std 	 Fit vs Val (MAc) = 0.762 vs 0.866
#  > > 16	std 	 Fit vs Val (MAc) = 0.737 vs 0.982
#  > > 16	std 	 Fit vs Val (MAc) = 0.763 vs 0.786
#  > > 16	std 	 Fit vs Val (MAc) = 0.765 vs 0.768
#  > > 16	std 	 Fit vs Val (MAc) = 0.747 vs 0.751
#  > > 16	std 	 Fit vs Val (MAc) = 0.763 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.766 vs 0.698
#  > > 16	std 	 Fit vs Val (MAc) = 0.773 vs 0.587
#  > > 16	std 	 Fit vs Val (MAc) = 0.769 vs 0.613
#  > > 16	std 	 Fit vs Val (MAc) = 0.771 vs 0.649
#  > > 16	std 	 Fit vs Val (MAc) = 0.744 vs 0.960
#  > > 16	std 	 Fit vs Val (MAc) = 0.761 vs 0.935
#  > > 16	std 	 Fit vs Val (MAc) = 0.789 vs 0.479
#  > > 16	std 	 Fit vs Val (MAc) = 0.792 vs 0.501
#  > > BEST-TH: 99.000 (3.156)
# > ('32', 'mean')
#  > > 32	mean 	 Fit vs Val (MAc) = 0.781 vs 0.395
#  > > 32	mean 	 Fit vs Val (MAc) = 0.771 vs 0.675
#  > > 32	mean 	 Fit vs Val (MAc) = 0.767 vs 0.803
#  > > 32	mean 	 Fit vs Val (MAc) = 0.758 vs 0.919
#  > > 32	mean 	 Fit vs Val (MAc) = 0.767 vs 0.840
#  > > 32	mean 	 Fit vs Val (MAc) = 0.763 vs 0.917
#  > > 32	mean 	 Fit vs Val (MAc) = 0.768 vs 0.819
#  > > 32	mean 	 Fit vs Val (MAc) = 0.743 vs 0.979
#  > > 32	mean 	 Fit vs Val (MAc) = 0.767 vs 0.790
#  > > 32	mean 	 Fit vs Val (MAc) = 0.765 vs 0.922
#  > > 32	mean 	 Fit vs Val (MAc) = 0.812 vs 0.526
#  > > 32	mean 	 Fit vs Val (MAc) = 0.769 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.784 vs 0.309
#  > > 32	mean 	 Fit vs Val (MAc) = 0.768 vs 0.950
#  > > 32	mean 	 Fit vs Val (MAc) = 0.780 vs 0.451
#  > > 32	mean 	 Fit vs Val (MAc) = 0.771 vs 0.706
#  > > 32	mean 	 Fit vs Val (MAc) = 0.749 vs 0.954
#  > > 32	mean 	 Fit vs Val (MAc) = 0.764 vs 0.944
#  > > 32	mean 	 Fit vs Val (MAc) = 0.777 vs 0.883
#  > > 32	mean 	 Fit vs Val (MAc) = 0.779 vs 0.867
#  > > BEST-TH: 124.500 (4.047)
# > ('32', 'max')
#  > > 32	max 	 Fit vs Val (MAc) = 0.862 vs 0.992
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.972
#  > > 32	max 	 Fit vs Val (MAc) = 0.874 vs 0.872
#  > > 32	max 	 Fit vs Val (MAc) = 0.862 vs 0.965
#  > > 32	max 	 Fit vs Val (MAc) = 0.868 vs 0.963
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.980
#  > > 32	max 	 Fit vs Val (MAc) = 0.865 vs 0.946
#  > > 32	max 	 Fit vs Val (MAc) = 0.850 vs 0.981
#  > > 32	max 	 Fit vs Val (MAc) = 0.867 vs 0.962
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.977
#  > > 32	max 	 Fit vs Val (MAc) = 0.834 vs 0.929
#  > > 32	max 	 Fit vs Val (MAc) = 0.865 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.865 vs 0.928
#  > > 32	max 	 Fit vs Val (MAc) = 0.871 vs 0.863
#  > > 32	max 	 Fit vs Val (MAc) = 0.868 vs 0.805
#  > > 32	max 	 Fit vs Val (MAc) = 0.876 vs 0.645
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs 0.963
#  > > 32	max 	 Fit vs Val (MAc) = 0.867 vs 0.968
#  > > 32	max 	 Fit vs Val (MAc) = 0.880 vs 0.400
#  > > 32	max 	 Fit vs Val (MAc) = 0.875 vs 0.763
#  > > BEST-TH: 129.000 (2.685)
# > ('32', 'min')
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.779
#  > > 32	min 	 Fit vs Val (MAc) = 0.729 vs 0.712
#  > > 32	min 	 Fit vs Val (MAc) = 0.734 vs 0.664
#  > > 32	min 	 Fit vs Val (MAc) = 0.719 vs 0.757
#  > > 32	min 	 Fit vs Val (MAc) = 0.727 vs 0.800
#  > > 32	min 	 Fit vs Val (MAc) = 0.729 vs 0.620
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.864
#  > > 32	min 	 Fit vs Val (MAc) = 0.713 vs 0.842
#  > > 32	min 	 Fit vs Val (MAc) = 0.729 vs 0.649
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.810
#  > > 32	min 	 Fit vs Val (MAc) = 0.782 vs 0.544
#  > > 32	min 	 Fit vs Val (MAc) = 0.726 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.727 vs 0.715
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.856
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs 0.855
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.795
#  > > 32	min 	 Fit vs Val (MAc) = 0.702 vs 0.878
#  > > 32	min 	 Fit vs Val (MAc) = 0.731 vs 0.557
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs 0.668
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs 0.759
#  > > BEST-TH: 116.000 (2.303)
# > ('32', 'std')
#  > > 32	std 	 Fit vs Val (MAc) = 0.772 vs 0.929
#  > > 32	std 	 Fit vs Val (MAc) = 0.772 vs 0.922
#  > > 32	std 	 Fit vs Val (MAc) = 0.777 vs 0.757
#  > > 32	std 	 Fit vs Val (MAc) = 0.768 vs 0.928
#  > > 32	std 	 Fit vs Val (MAc) = 0.774 vs 0.954
#  > > 32	std 	 Fit vs Val (MAc) = 0.769 vs 0.976
#  > > 32	std 	 Fit vs Val (MAc) = 0.779 vs 0.723
#  > > 32	std 	 Fit vs Val (MAc) = 0.750 vs 0.970
#  > > 32	std 	 Fit vs Val (MAc) = 0.774 vs 0.935
#  > > 32	std 	 Fit vs Val (MAc) = 0.774 vs 0.914
#  > > 32	std 	 Fit vs Val (MAc) = 0.755 vs 0.801
#  > > 32	std 	 Fit vs Val (MAc) = 0.775 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.774 vs 0.870
#  > > 32	std 	 Fit vs Val (MAc) = 0.786 vs 0.575
#  > > 32	std 	 Fit vs Val (MAc) = 0.789 vs 0.381
#  > > 32	std 	 Fit vs Val (MAc) = 0.786 vs 0.523
#  > > 32	std 	 Fit vs Val (MAc) = 0.754 vs 0.956
#  > > 32	std 	 Fit vs Val (MAc) = 0.773 vs 0.965
#  > > 32	std 	 Fit vs Val (MAc) = 0.801 vs 0.459
#  > > 32	std 	 Fit vs Val (MAc) = 0.799 vs 0.739
#  > > BEST-TH: 78.000 (2.268)
# > ('64', 'mean')
#  > > 64	mean 	 Fit vs Val (MAc) = 0.759 vs 0.819
#  > > 64	mean 	 Fit vs Val (MAc) = 0.758 vs 0.860
#  > > 64	mean 	 Fit vs Val (MAc) = 0.760 vs 0.675
#  > > 64	mean 	 Fit vs Val (MAc) = 0.747 vs 0.912
#  > > 64	mean 	 Fit vs Val (MAc) = 0.758 vs 0.863
#  > > 64	mean 	 Fit vs Val (MAc) = 0.754 vs 0.932
#  > > 64	mean 	 Fit vs Val (MAc) = 0.756 vs 0.959
#  > > 64	mean 	 Fit vs Val (MAc) = 0.726 vs 0.979
#  > > 64	mean 	 Fit vs Val (MAc) = 0.762 vs 0.634
#  > > 64	mean 	 Fit vs Val (MAc) = 0.756 vs 0.934
#  > > 64	mean 	 Fit vs Val (MAc) = 0.813 vs 0.480
#  > > 64	mean 	 Fit vs Val (MAc) = 0.758 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.761 vs 0.778
#  > > 64	mean 	 Fit vs Val (MAc) = 0.758 vs 0.919
#  > > 64	mean 	 Fit vs Val (MAc) = 0.765 vs 0.611
#  > > 64	mean 	 Fit vs Val (MAc) = 0.760 vs 0.771
#  > > 64	mean 	 Fit vs Val (MAc) = 0.731 vs 0.951
#  > > 64	mean 	 Fit vs Val (MAc) = 0.756 vs 0.873
#  > > 64	mean 	 Fit vs Val (MAc) = 0.771 vs 0.859
#  > > 64	mean 	 Fit vs Val (MAc) = 0.771 vs 0.842
#  > > BEST-TH: 95.000 (2.739)
# > ('64', 'max')
#  > > 64	max 	 Fit vs Val (MAc) = 0.862 vs 0.953
#  > > 64	max 	 Fit vs Val (MAc) = 0.864 vs 0.951
#  > > 64	max 	 Fit vs Val (MAc) = 0.873 vs 0.869
#  > > 64	max 	 Fit vs Val (MAc) = 0.860 vs 0.951
#  > > 64	max 	 Fit vs Val (MAc) = 0.866 vs 0.946
#  > > 64	max 	 Fit vs Val (MAc) = 0.862 vs 0.976
#  > > 64	max 	 Fit vs Val (MAc) = 0.864 vs 0.920
#  > > 64	max 	 Fit vs Val (MAc) = 0.847 vs 0.966
#  > > 64	max 	 Fit vs Val (MAc) = 0.864 vs 0.955
#  > > 64	max 	 Fit vs Val (MAc) = 0.863 vs 0.955
#  > > 64	max 	 Fit vs Val (MAc) = 0.831 vs 0.943
#  > > 64	max 	 Fit vs Val (MAc) = 0.863 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.863 vs 0.925
#  > > 64	max 	 Fit vs Val (MAc) = 0.868 vs 0.891
#  > > 64	max 	 Fit vs Val (MAc) = 0.870 vs 0.691
#  > > 64	max 	 Fit vs Val (MAc) = 0.871 vs 0.680
#  > > 64	max 	 Fit vs Val (MAc) = 0.851 vs 0.954
#  > > 64	max 	 Fit vs Val (MAc) = 0.864 vs 0.968
#  > > 64	max 	 Fit vs Val (MAc) = 0.875 vs 0.664
#  > > 64	max 	 Fit vs Val (MAc) = 0.877 vs 0.823
#  > > BEST-TH: 102.000 (1.536)
# > ('64', 'min')
#  > > 64	min 	 Fit vs Val (MAc) = 0.718 vs 0.625
#  > > 64	min 	 Fit vs Val (MAc) = 0.714 vs 0.763
#  > > 64	min 	 Fit vs Val (MAc) = 0.719 vs 0.794
#  > > 64	min 	 Fit vs Val (MAc) = 0.706 vs 0.598
#  > > 64	min 	 Fit vs Val (MAc) = 0.713 vs 0.859
#  > > 64	min 	 Fit vs Val (MAc) = 0.712 vs 0.746
#  > > 64	min 	 Fit vs Val (MAc) = 0.710 vs 0.902
#  > > 64	min 	 Fit vs Val (MAc) = 0.680 vs 0.930
#  > > 64	min 	 Fit vs Val (MAc) = 0.712 vs 0.784
#  > > 64	min 	 Fit vs Val (MAc) = 0.711 vs 0.861
#  > > 64	min 	 Fit vs Val (MAc) = 0.777 vs 0.449
#  > > 64	min 	 Fit vs Val (MAc) = 0.712 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.711 vs 0.857
#  > > 64	min 	 Fit vs Val (MAc) = 0.711 vs 0.897
#  > > 64	min 	 Fit vs Val (MAc) = 0.710 vs 0.903
#  > > 64	min 	 Fit vs Val (MAc) = 0.710 vs 0.879
#  > > 64	min 	 Fit vs Val (MAc) = 0.680 vs 0.934
#  > > 64	min 	 Fit vs Val (MAc) = 0.714 vs 0.683
#  > > 64	min 	 Fit vs Val (MAc) = 0.712 vs 0.807
#  > > 64	min 	 Fit vs Val (MAc) = 0.717 vs 0.825
#  > > BEST-TH: 104.000 (1.418)
# > ('64', 'std')
#  > > 64	std 	 Fit vs Val (MAc) = 0.791 vs 0.854
#  > > 64	std 	 Fit vs Val (MAc) = 0.789 vs 0.927
#  > > 64	std 	 Fit vs Val (MAc) = 0.797 vs 0.832
#  > > 64	std 	 Fit vs Val (MAc) = 0.786 vs 0.905
#  > > 64	std 	 Fit vs Val (MAc) = 0.791 vs 0.942
#  > > 64	std 	 Fit vs Val (MAc) = 0.787 vs 0.964
#  > > 64	std 	 Fit vs Val (MAc) = 0.791 vs 0.874
#  > > 64	std 	 Fit vs Val (MAc) = 0.765 vs 0.893
#  > > 64	std 	 Fit vs Val (MAc) = 0.790 vs 0.936
#  > > 64	std 	 Fit vs Val (MAc) = 0.792 vs 0.828
#  > > 64	std 	 Fit vs Val (MAc) = 0.760 vs 0.834
#  > > 64	std 	 Fit vs Val (MAc) = 0.790 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.792 vs 0.814
#  > > 64	std 	 Fit vs Val (MAc) = 0.796 vs 0.803
#  > > 64	std 	 Fit vs Val (MAc) = 0.793 vs 0.779
#  > > 64	std 	 Fit vs Val (MAc) = 0.800 vs 0.579
#  > > 64	std 	 Fit vs Val (MAc) = 0.769 vs 0.933
#  > > 64	std 	 Fit vs Val (MAc) = 0.790 vs 0.957
#  > > 64	std 	 Fit vs Val (MAc) = 0.813 vs 0.622
#  > > 64	std 	 Fit vs Val (MAc) = 0.813 vs 0.764
#  > > BEST-TH: 49.000 (1.137)
# > ('128', 'mean')
#  > > 128	mean 	 Fit vs Val (MAc) = 0.805 vs 0.864
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.883
#  > > 128	mean 	 Fit vs Val (MAc) = 0.813 vs 0.659
#  > > 128	mean 	 Fit vs Val (MAc) = 0.800 vs 0.876
#  > > 128	mean 	 Fit vs Val (MAc) = 0.807 vs 0.852
#  > > 128	mean 	 Fit vs Val (MAc) = 0.805 vs 0.817
#  > > 128	mean 	 Fit vs Val (MAc) = 0.808 vs 0.779
#  > > 128	mean 	 Fit vs Val (MAc) = 0.785 vs 0.963
#  > > 128	mean 	 Fit vs Val (MAc) = 0.808 vs 0.737
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.857
#  > > 128	mean 	 Fit vs Val (MAc) = 0.796 vs 0.754
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.808 vs 0.779
#  > > 128	mean 	 Fit vs Val (MAc) = 0.808 vs 0.844
#  > > 128	mean 	 Fit vs Val (MAc) = 0.810 vs 0.679
#  > > 128	mean 	 Fit vs Val (MAc) = 0.810 vs 0.706
#  > > 128	mean 	 Fit vs Val (MAc) = 0.789 vs 0.928
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.833
#  > > 128	mean 	 Fit vs Val (MAc) = 0.819 vs 0.849
#  > > 128	mean 	 Fit vs Val (MAc) = 0.825 vs 0.835
#  > > BEST-TH: 80.000 (1.777)
# > ('128', 'max')
#  > > 128	max 	 Fit vs Val (MAc) = 0.845 vs 0.925
#  > > 128	max 	 Fit vs Val (MAc) = 0.846 vs 0.958
#  > > 128	max 	 Fit vs Val (MAc) = 0.854 vs 0.785
#  > > 128	max 	 Fit vs Val (MAc) = 0.842 vs 0.925
#  > > 128	max 	 Fit vs Val (MAc) = 0.848 vs 0.921
#  > > 128	max 	 Fit vs Val (MAc) = 0.845 vs 0.932
#  > > 128	max 	 Fit vs Val (MAc) = 0.847 vs 0.859
#  > > 128	max 	 Fit vs Val (MAc) = 0.827 vs 0.966
#  > > 128	max 	 Fit vs Val (MAc) = 0.847 vs 0.864
#  > > 128	max 	 Fit vs Val (MAc) = 0.846 vs 0.904
#  > > 128	max 	 Fit vs Val (MAc) = 0.816 vs 0.908
#  > > 128	max 	 Fit vs Val (MAc) = 0.846 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.846 vs 0.903
#  > > 128	max 	 Fit vs Val (MAc) = 0.850 vs 0.834
#  > > 128	max 	 Fit vs Val (MAc) = 0.850 vs 0.749
#  > > 128	max 	 Fit vs Val (MAc) = 0.851 vs 0.737
#  > > 128	max 	 Fit vs Val (MAc) = 0.831 vs 0.946
#  > > 128	max 	 Fit vs Val (MAc) = 0.846 vs 0.919
#  > > 128	max 	 Fit vs Val (MAc) = 0.860 vs 0.819
#  > > 128	max 	 Fit vs Val (MAc) = 0.861 vs 0.822
#  > > BEST-TH: 88.000 (0.733)
# > ('128', 'min')
#  > > 128	min 	 Fit vs Val (MAc) = 0.667 vs 0.758
#  > > 128	min 	 Fit vs Val (MAc) = 0.668 vs 0.694
#  > > 128	min 	 Fit vs Val (MAc) = 0.668 vs 0.778
#  > > 128	min 	 Fit vs Val (MAc) = 0.651 vs 0.853
#  > > 128	min 	 Fit vs Val (MAc) = 0.666 vs 0.755
#  > > 128	min 	 Fit vs Val (MAc) = 0.665 vs 0.697
#  > > 128	min 	 Fit vs Val (MAc) = 0.664 vs 0.832
#  > > 128	min 	 Fit vs Val (MAc) = 0.640 vs 0.858
#  > > 128	min 	 Fit vs Val (MAc) = 0.666 vs 0.695
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.873
#  > > 128	min 	 Fit vs Val (MAc) = 0.730 vs 0.396
#  > > 128	min 	 Fit vs Val (MAc) = 0.665 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.667 vs 0.760
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.937
#  > > 128	min 	 Fit vs Val (MAc) = 0.668 vs 0.728
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.901
#  > > 128	min 	 Fit vs Val (MAc) = 0.627 vs 0.946
#  > > 128	min 	 Fit vs Val (MAc) = 0.667 vs 0.664
#  > > 128	min 	 Fit vs Val (MAc) = 0.670 vs 0.838
#  > > 128	min 	 Fit vs Val (MAc) = 0.678 vs 0.798
#  > > BEST-TH: 74.000 (1.302)
# > ('128', 'std')
#  > > 128	std 	 Fit vs Val (MAc) = 0.760 vs 0.872
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs 0.879
#  > > 128	std 	 Fit vs Val (MAc) = 0.768 vs 0.792
#  > > 128	std 	 Fit vs Val (MAc) = 0.757 vs 0.815
#  > > 128	std 	 Fit vs Val (MAc) = 0.762 vs 0.876
#  > > 128	std 	 Fit vs Val (MAc) = 0.758 vs 0.920
#  > > 128	std 	 Fit vs Val (MAc) = 0.762 vs 0.835
#  > > 128	std 	 Fit vs Val (MAc) = 0.734 vs 0.888
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs 0.895
#  > > 128	std 	 Fit vs Val (MAc) = 0.764 vs 0.762
#  > > 128	std 	 Fit vs Val (MAc) = 0.751 vs 0.711
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.763 vs 0.788
#  > > 128	std 	 Fit vs Val (MAc) = 0.766 vs 0.747
#  > > 128	std 	 Fit vs Val (MAc) = 0.764 vs 0.748
#  > > 128	std 	 Fit vs Val (MAc) = 0.768 vs 0.659
#  > > 128	std 	 Fit vs Val (MAc) = 0.739 vs 0.842
#  > > 128	std 	 Fit vs Val (MAc) = 0.760 vs 0.900
#  > > 128	std 	 Fit vs Val (MAc) = 0.780 vs 0.765
#  > > 128	std 	 Fit vs Val (MAc) = 0.781 vs 0.705
#  > > BEST-TH: 31.000 (0.968)
# > ('512', 'ori')
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.827
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.816
#  > > 512	ori 	 Fit vs Val (MAc) = 0.792 vs 0.672
#  > > 512	ori 	 Fit vs Val (MAc) = 0.779 vs 0.840
#  > > 512	ori 	 Fit vs Val (MAc) = 0.786 vs 0.768
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.785
#  > > 512	ori 	 Fit vs Val (MAc) = 0.785 vs 0.772
#  > > 512	ori 	 Fit vs Val (MAc) = 0.765 vs 0.799
#  > > 512	ori 	 Fit vs Val (MAc) = 0.786 vs 0.735
#  > > 512	ori 	 Fit vs Val (MAc) = 0.782 vs 0.852
#  > > 512	ori 	 Fit vs Val (MAc) = 0.785 vs 0.643
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.795
#  > > 512	ori 	 Fit vs Val (MAc) = 0.786 vs 0.787
#  > > 512	ori 	 Fit vs Val (MAc) = 0.782 vs 0.858
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.838
#  > > 512	ori 	 Fit vs Val (MAc) = 0.768 vs 0.827
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.782
#  > > 512	ori 	 Fit vs Val (MAc) = 0.795 vs 0.750
#  > > 512	ori 	 Fit vs Val (MAc) = 0.797 vs 0.798
#  > > BEST-TH: 0.308 (0.009)
# Experiment [0, 1] [2]
# > ('8', 'mean')
#  > > 8	mean 	 Fit vs Val (MAc) = 0.786 vs 0.440
#  > > 8	mean 	 Fit vs Val (MAc) = 0.777 vs 0.880
#  > > 8	mean 	 Fit vs Val (MAc) = 0.778 vs 0.809
#  > > 8	mean 	 Fit vs Val (MAc) = 0.775 vs 0.950
#  > > 8	mean 	 Fit vs Val (MAc) = 0.780 vs 0.740
#  > > 8	mean 	 Fit vs Val (MAc) = 0.776 vs 0.914
#  > > 8	mean 	 Fit vs Val (MAc) = 0.781 vs 0.706
#  > > 8	mean 	 Fit vs Val (MAc) = 0.770 vs 0.987
#  > > 8	mean 	 Fit vs Val (MAc) = 0.777 vs 0.935
#  > > 8	mean 	 Fit vs Val (MAc) = 0.780 vs 0.757
#  > > 8	mean 	 Fit vs Val (MAc) = 0.780 vs 0.697
#  > > 8	mean 	 Fit vs Val (MAc) = 0.779 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.788 vs 0.343
#  > > 8	mean 	 Fit vs Val (MAc) = 0.780 vs 0.799
#  > > 8	mean 	 Fit vs Val (MAc) = 0.788 vs 0.329
#  > > 8	mean 	 Fit vs Val (MAc) = 0.785 vs 0.508
#  > > 8	mean 	 Fit vs Val (MAc) = 0.772 vs 0.952
#  > > 8	mean 	 Fit vs Val (MAc) = 0.776 vs 0.932
#  > > 8	mean 	 Fit vs Val (MAc) = 0.781 vs 0.824
#  > > 8	mean 	 Fit vs Val (MAc) = 0.781 vs 0.851
#  > > 8	mean 	 Fit vs Val (MAc) = 0.779 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.781 vs 0.829
#  > > 8	mean 	 Fit vs Val (MAc) = 0.782 vs 0.811
#  > > 8	mean 	 Fit vs Val (MAc) = 0.785 vs 0.637
#  > > 8	mean 	 Fit vs Val (MAc) = 0.783 vs 0.816
#  > > 8	mean 	 Fit vs Val (MAc) = 0.780 vs 0.876
#  > > 8	mean 	 Fit vs Val (MAc) = 0.775 vs 0.897
#  > > 8	mean 	 Fit vs Val (MAc) = 0.782 vs 0.736
#  > > 8	mean 	 Fit vs Val (MAc) = 0.766 vs 0.936
#  > > 8	mean 	 Fit vs Val (MAc) = 0.775 vs 0.898
#  > > 8	mean 	 Fit vs Val (MAc) = 0.779 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.781 vs 0.841
#  > > 8	mean 	 Fit vs Val (MAc) = 0.783 vs 0.743
#  > > 8	mean 	 Fit vs Val (MAc) = 0.781 vs 0.829
#  > > 8	mean 	 Fit vs Val (MAc) = 0.775 vs 0.896
#  > > 8	mean 	 Fit vs Val (MAc) = 0.782 vs 0.736
#  > > 8	mean 	 Fit vs Val (MAc) = 0.765 vs 0.974
#  > > BEST-TH: 128.000 (3.266)
# > ('8', 'max')
#  > > 8	max 	 Fit vs Val (MAc) = 0.668 vs 0.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.667 vs 0.022
#  > > 8	max 	 Fit vs Val (MAc) = 0.656 vs 0.873
#  > > 8	max 	 Fit vs Val (MAc) = 0.653 vs 0.911
#  > > 8	max 	 Fit vs Val (MAc) = 0.667 vs 0.044
#  > > 8	max 	 Fit vs Val (MAc) = 0.651 vs 0.952
#  > > 8	max 	 Fit vs Val (MAc) = 0.667 vs 0.017
#  > > 8	max 	 Fit vs Val (MAc) = 0.648 vs 0.968
#  > > 8	max 	 Fit vs Val (MAc) = 0.667 vs 0.048
#  > > 8	max 	 Fit vs Val (MAc) = 0.667 vs 0.016
#  > > 8	max 	 Fit vs Val (MAc) = 0.644 vs 0.983
#  > > 8	max 	 Fit vs Val (MAc) = 0.657 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.668 vs 0.003
#  > > 8	max 	 Fit vs Val (MAc) = 0.652 vs 0.910
#  > > 8	max 	 Fit vs Val (MAc) = 0.668 vs 0.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.651 vs 0.939
#  > > 8	max 	 Fit vs Val (MAc) = 0.650 vs 0.937
#  > > 8	max 	 Fit vs Val (MAc) = 0.667 vs 0.038
#  > > 8	max 	 Fit vs Val (MAc) = 0.656 vs 0.729
#  > > 8	max 	 Fit vs Val (MAc) = 0.656 vs 0.661
#  > > 8	max 	 Fit vs Val (MAc) = 0.657 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.655 vs 0.734
#  > > 8	max 	 Fit vs Val (MAc) = 0.657 vs 0.594
#  > > 8	max 	 Fit vs Val (MAc) = 0.659 vs 0.575
#  > > 8	max 	 Fit vs Val (MAc) = 0.658 vs 0.756
#  > > 8	max 	 Fit vs Val (MAc) = 0.655 vs 0.831
#  > > 8	max 	 Fit vs Val (MAc) = 0.651 vs 0.890
#  > > 8	max 	 Fit vs Val (MAc) = 0.659 vs 0.648
#  > > 8	max 	 Fit vs Val (MAc) = 0.648 vs 0.921
#  > > 8	max 	 Fit vs Val (MAc) = 0.653 vs 0.895
#  > > 8	max 	 Fit vs Val (MAc) = 0.657 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.660 vs 0.423
#  > > 8	max 	 Fit vs Val (MAc) = 0.658 vs 0.603
#  > > 8	max 	 Fit vs Val (MAc) = 0.658 vs 0.515
#  > > 8	max 	 Fit vs Val (MAc) = 0.653 vs 0.889
#  > > 8	max 	 Fit vs Val (MAc) = 0.657 vs 0.653
#  > > 8	max 	 Fit vs Val (MAc) = 0.645 vs 0.972
#  > > BEST-TH: 148.000 (2.500)
# > ('8', 'min')
#  > > 8	min 	 Fit vs Val (MAc) = 0.571 vs 0.866
#  > > 8	min 	 Fit vs Val (MAc) = 0.573 vs 0.781
#  > > 8	min 	 Fit vs Val (MAc) = 0.575 vs 0.731
#  > > 8	min 	 Fit vs Val (MAc) = 0.571 vs 0.676
#  > > 8	min 	 Fit vs Val (MAc) = 0.575 vs 0.708
#  > > 8	min 	 Fit vs Val (MAc) = 0.571 vs 0.792
#  > > 8	min 	 Fit vs Val (MAc) = 0.573 vs 0.745
#  > > 8	min 	 Fit vs Val (MAc) = 0.582 vs 0.646
#  > > 8	min 	 Fit vs Val (MAc) = 0.572 vs 0.814
#  > > 8	min 	 Fit vs Val (MAc) = 0.577 vs 0.515
#  > > 8	min 	 Fit vs Val (MAc) = 0.581 vs 0.433
#  > > 8	min 	 Fit vs Val (MAc) = 0.575 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.573 vs 0.745
#  > > 8	min 	 Fit vs Val (MAc) = 0.573 vs 0.769
#  > > 8	min 	 Fit vs Val (MAc) = 0.574 vs 0.702
#  > > 8	min 	 Fit vs Val (MAc) = 0.575 vs 0.659
#  > > 8	min 	 Fit vs Val (MAc) = 0.561 vs 0.891
#  > > 8	min 	 Fit vs Val (MAc) = 0.572 vs 0.767
#  > > 8	min 	 Fit vs Val (MAc) = 0.574 vs 0.501
#  > > 8	min 	 Fit vs Val (MAc) = 0.573 vs 0.495
#  > > 8	min 	 Fit vs Val (MAc) = 0.575 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.574 vs 0.566
#  > > 8	min 	 Fit vs Val (MAc) = 0.574 vs 0.575
#  > > 8	min 	 Fit vs Val (MAc) = 0.572 vs 0.715
#  > > 8	min 	 Fit vs Val (MAc) = 0.571 vs 0.547
#  > > 8	min 	 Fit vs Val (MAc) = 0.581 vs 0.322
#  > > 8	min 	 Fit vs Val (MAc) = 0.568 vs 0.616
#  > > 8	min 	 Fit vs Val (MAc) = 0.574 vs 0.463
#  > > 8	min 	 Fit vs Val (MAc) = 0.599 vs 0.191
#  > > 8	min 	 Fit vs Val (MAc) = 0.586 vs 0.551
#  > > 8	min 	 Fit vs Val (MAc) = 0.575 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.575 vs 0.425
#  > > 8	min 	 Fit vs Val (MAc) = 0.576 vs 0.431
#  > > 8	min 	 Fit vs Val (MAc) = 0.573 vs 0.634
#  > > 8	min 	 Fit vs Val (MAc) = 0.574 vs 0.395
#  > > 8	min 	 Fit vs Val (MAc) = 0.578 vs 0.397
#  > > 8	min 	 Fit vs Val (MAc) = 0.591 vs 0.280
#  > > BEST-TH: 107.000 (2.627)
# > ('8', 'std')
#  > > 8	std 	 Fit vs Val (MAc) = 0.669 vs 0.900
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.897
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.862
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.898
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.957
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.947
#  > > 8	std 	 Fit vs Val (MAc) = 0.669 vs 0.882
#  > > 8	std 	 Fit vs Val (MAc) = 0.657 vs 0.936
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.885
#  > > 8	std 	 Fit vs Val (MAc) = 0.671 vs 0.805
#  > > 8	std 	 Fit vs Val (MAc) = 0.679 vs 0.442
#  > > 8	std 	 Fit vs Val (MAc) = 0.669 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.671 vs 0.797
#  > > 8	std 	 Fit vs Val (MAc) = 0.671 vs 0.812
#  > > 8	std 	 Fit vs Val (MAc) = 0.673 vs 0.679
#  > > 8	std 	 Fit vs Val (MAc) = 0.672 vs 0.757
#  > > 8	std 	 Fit vs Val (MAc) = 0.661 vs 0.895
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.965
#  > > 8	std 	 Fit vs Val (MAc) = 0.677 vs 0.522
#  > > 8	std 	 Fit vs Val (MAc) = 0.677 vs 0.640
#  > > 8	std 	 Fit vs Val (MAc) = 0.669 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.672 vs 0.798
#  > > 8	std 	 Fit vs Val (MAc) = 0.675 vs 0.723
#  > > 8	std 	 Fit vs Val (MAc) = 0.674 vs 0.741
#  > > 8	std 	 Fit vs Val (MAc) = 0.676 vs 0.646
#  > > 8	std 	 Fit vs Val (MAc) = 0.670 vs 0.840
#  > > 8	std 	 Fit vs Val (MAc) = 0.671 vs 0.677
#  > > 8	std 	 Fit vs Val (MAc) = 0.676 vs 0.697
#  > > 8	std 	 Fit vs Val (MAc) = 0.645 vs 0.865
#  > > 8	std 	 Fit vs Val (MAc) = 0.668 vs 0.730
#  > > 8	std 	 Fit vs Val (MAc) = 0.669 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.675 vs 0.690
#  > > 8	std 	 Fit vs Val (MAc) = 0.675 vs 0.603
#  > > 8	std 	 Fit vs Val (MAc) = 0.676 vs 0.659
#  > > 8	std 	 Fit vs Val (MAc) = 0.662 vs 0.807
#  > > 8	std 	 Fit vs Val (MAc) = 0.674 vs 0.623
#  > > 8	std 	 Fit vs Val (MAc) = 0.643 vs 0.916
#  > > BEST-TH: 76.000 (2.393)
# > ('16', 'mean')
#  > > 16	mean 	 Fit vs Val (MAc) = 0.802 vs 0.445
#  > > 16	mean 	 Fit vs Val (MAc) = 0.793 vs 0.893
#  > > 16	mean 	 Fit vs Val (MAc) = 0.793 vs 0.849
#  > > 16	mean 	 Fit vs Val (MAc) = 0.790 vs 0.956
#  > > 16	mean 	 Fit vs Val (MAc) = 0.793 vs 0.956
#  > > 16	mean 	 Fit vs Val (MAc) = 0.791 vs 0.962
#  > > 16	mean 	 Fit vs Val (MAc) = 0.796 vs 0.757
#  > > 16	mean 	 Fit vs Val (MAc) = 0.786 vs 0.987
#  > > 16	mean 	 Fit vs Val (MAc) = 0.793 vs 0.847
#  > > 16	mean 	 Fit vs Val (MAc) = 0.796 vs 0.685
#  > > 16	mean 	 Fit vs Val (MAc) = 0.805 vs 0.608
#  > > 16	mean 	 Fit vs Val (MAc) = 0.794 vs nan
#  > > 16	mean 	 Fit vs Val (MAc) = 0.803 vs 0.366
#  > > 16	mean 	 Fit vs Val (MAc) = 0.793 vs 0.944
#  > > 16	mean 	 Fit vs Val (MAc) = 0.806 vs 0.225
#  > > 16	mean 	 Fit vs Val (MAc) = 0.797 vs 0.623
#  > > 16	mean 	 Fit vs Val (MAc) = 0.788 vs 0.954
#  > > 16	mean 	 Fit vs Val (MAc) = 0.793 vs 0.882
#  > > 16	mean 	 Fit vs Val (MAc) = 0.796 vs 0.867
#  > > 16	mean 	 Fit vs Val (MAc) = 0.796 vs 0.877
#  > > 16	mean 	 Fit vs Val (MAc) = 0.794 vs nan
#  > > 16	mean 	 Fit vs Val (MAc) = 0.796 vs 0.896
# ...
#  > > 16	min 	 Fit vs Val (MAc) = 0.658 vs 0.850
#  > > 16	min 	 Fit vs Val (MAc) = 0.690 vs 0.485
#  > > 16	min 	 Fit vs Val (MAc) = 0.681 vs 0.527
#  > > 16	min 	 Fit vs Val (MAc) = 0.680 vs 0.683
#  > > 16	min 	 Fit vs Val (MAc) = 0.684 vs nan
#  > > 16	min 	 Fit vs Val (MAc) = 0.683 vs 0.756
#  > > BEST-TH: 114.000 (3.371)
# > ('16', 'std')
#  > > 16	std 	 Fit vs Val (MAc) = 0.748 vs 0.881
#  > > 16	std 	 Fit vs Val (MAc) = 0.747 vs 0.884
#  > > 16	std 	 Fit vs Val (MAc) = 0.748 vs 0.808
#  > > 16	std 	 Fit vs Val (MAc) = 0.743 vs 0.953
#  > > 16	std 	 Fit vs Val (MAc) = 0.749 vs 0.872
#  > > 16	std 	 Fit vs Val (MAc) = 0.744 vs 0.970
#  > > 16	std 	 Fit vs Val (MAc) = 0.749 vs 0.872
#  > > 16	std 	 Fit vs Val (MAc) = 0.723 vs 0.982
#  > > 16	std 	 Fit vs Val (MAc) = 0.750 vs 0.791
#  > > 16	std 	 Fit vs Val (MAc) = 0.752 vs 0.768
#  > > 16	std 	 Fit vs Val (MAc) = 0.730 vs 0.714
#  > > 16	std 	 Fit vs Val (MAc) = 0.750 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.754 vs 0.698
#  > > 16	std 	 Fit vs Val (MAc) = 0.759 vs 0.587
#  > > 16	std 	 Fit vs Val (MAc) = 0.756 vs 0.613
#  > > 16	std 	 Fit vs Val (MAc) = 0.757 vs 0.649
#  > > 16	std 	 Fit vs Val (MAc) = 0.730 vs 0.960
#  > > 16	std 	 Fit vs Val (MAc) = 0.748 vs 0.935
#  > > 16	std 	 Fit vs Val (MAc) = 0.774 vs 0.479
#  > > 16	std 	 Fit vs Val (MAc) = 0.777 vs 0.509
#  > > 16	std 	 Fit vs Val (MAc) = 0.750 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.763 vs 0.803
#  > > BEST-TH: 99.000 (3.864)
# > ('32', 'mean')
#  > > 32	mean 	 Fit vs Val (MAc) = 0.778 vs 0.382
#  > > 32	mean 	 Fit vs Val (MAc) = 0.769 vs 0.660
#  > > 32	mean 	 Fit vs Val (MAc) = 0.764 vs 0.796
#  > > 32	mean 	 Fit vs Val (MAc) = 0.756 vs 0.914
#  > > 32	mean 	 Fit vs Val (MAc) = 0.765 vs 0.819
#  > > 32	mean 	 Fit vs Val (MAc) = 0.761 vs 0.910
#  > > 32	mean 	 Fit vs Val (MAc) = 0.766 vs 0.808
#  > > 32	mean 	 Fit vs Val (MAc) = 0.742 vs 0.979
#  > > 32	mean 	 Fit vs Val (MAc) = 0.765 vs 0.776
#  > > 32	mean 	 Fit vs Val (MAc) = 0.763 vs 0.922
#  > > 32	mean 	 Fit vs Val (MAc) = 0.803 vs 0.545
#  > > 32	mean 	 Fit vs Val (MAc) = 0.767 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.781 vs 0.296
#  > > 32	mean 	 Fit vs Val (MAc) = 0.765 vs 0.950
#  > > 32	mean 	 Fit vs Val (MAc) = 0.777 vs 0.438
#  > > 32	mean 	 Fit vs Val (MAc) = 0.768 vs 0.681
#  > > 32	mean 	 Fit vs Val (MAc) = 0.747 vs 0.952
#  > > 32	mean 	 Fit vs Val (MAc) = 0.761 vs 0.944
#  > > 32	mean 	 Fit vs Val (MAc) = 0.773 vs 0.885
#  > > 32	mean 	 Fit vs Val (MAc) = 0.776 vs 0.868
#  > > 32	mean 	 Fit vs Val (MAc) = 0.767 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.769 vs 0.826
#  > > BEST-TH: 125.500 (3.694)
# > ('32', 'max')
#  > > 32	max 	 Fit vs Val (MAc) = 0.851 vs 0.992
#  > > 32	max 	 Fit vs Val (MAc) = 0.853 vs 0.972
#  > > 32	max 	 Fit vs Val (MAc) = 0.862 vs 0.872
#  > > 32	max 	 Fit vs Val (MAc) = 0.851 vs 0.965
#  > > 32	max 	 Fit vs Val (MAc) = 0.856 vs 0.963
#  > > 32	max 	 Fit vs Val (MAc) = 0.853 vs 0.980
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs 0.946
#  > > 32	max 	 Fit vs Val (MAc) = 0.839 vs 0.980
#  > > 32	max 	 Fit vs Val (MAc) = 0.856 vs 0.962
#  > > 32	max 	 Fit vs Val (MAc) = 0.853 vs 0.977
#  > > 32	max 	 Fit vs Val (MAc) = 0.824 vs 0.929
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs 0.928
#  > > 32	max 	 Fit vs Val (MAc) = 0.860 vs 0.863
#  > > 32	max 	 Fit vs Val (MAc) = 0.857 vs 0.800
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.638
#  > > 32	max 	 Fit vs Val (MAc) = 0.843 vs 0.963
#  > > 32	max 	 Fit vs Val (MAc) = 0.856 vs 0.968
#  > > 32	max 	 Fit vs Val (MAc) = 0.868 vs 0.392
#  > > 32	max 	 Fit vs Val (MAc) = 0.863 vs 0.763
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.865 vs 0.663
#  > > BEST-TH: 129.000 (2.694)
# > ('32', 'min')
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.779
#  > > 32	min 	 Fit vs Val (MAc) = 0.729 vs 0.712
#  > > 32	min 	 Fit vs Val (MAc) = 0.733 vs 0.655
#  > > 32	min 	 Fit vs Val (MAc) = 0.719 vs 0.742
#  > > 32	min 	 Fit vs Val (MAc) = 0.727 vs 0.800
#  > > 32	min 	 Fit vs Val (MAc) = 0.728 vs 0.608
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.859
#  > > 32	min 	 Fit vs Val (MAc) = 0.712 vs 0.854
#  > > 32	min 	 Fit vs Val (MAc) = 0.728 vs 0.649
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.810
#  > > 32	min 	 Fit vs Val (MAc) = 0.777 vs 0.544
#  > > 32	min 	 Fit vs Val (MAc) = 0.726 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.727 vs 0.715
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.851
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs 0.849
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.795
#  > > 32	min 	 Fit vs Val (MAc) = 0.703 vs 0.878
#  > > 32	min 	 Fit vs Val (MAc) = 0.730 vs 0.557
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs 0.661
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs 0.759
#  > > 32	min 	 Fit vs Val (MAc) = 0.726 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.726 vs 0.790
#  > > BEST-TH: 116.000 (2.077)
# > ('32', 'std')
#  > > 32	std 	 Fit vs Val (MAc) = 0.760 vs 0.929
#  > > 32	std 	 Fit vs Val (MAc) = 0.760 vs 0.922
#  > > 32	std 	 Fit vs Val (MAc) = 0.764 vs 0.764
#  > > 32	std 	 Fit vs Val (MAc) = 0.756 vs 0.928
#  > > 32	std 	 Fit vs Val (MAc) = 0.762 vs 0.954
#  > > 32	std 	 Fit vs Val (MAc) = 0.757 vs 0.976
#  > > 32	std 	 Fit vs Val (MAc) = 0.766 vs 0.733
#  > > 32	std 	 Fit vs Val (MAc) = 0.737 vs 0.970
#  > > 32	std 	 Fit vs Val (MAc) = 0.762 vs 0.935
#  > > 32	std 	 Fit vs Val (MAc) = 0.762 vs 0.914
#  > > 32	std 	 Fit vs Val (MAc) = 0.739 vs 0.801
#  > > 32	std 	 Fit vs Val (MAc) = 0.763 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.762 vs 0.870
#  > > 32	std 	 Fit vs Val (MAc) = 0.773 vs 0.575
#  > > 32	std 	 Fit vs Val (MAc) = 0.776 vs 0.381
#  > > 32	std 	 Fit vs Val (MAc) = 0.774 vs 0.523
#  > > 32	std 	 Fit vs Val (MAc) = 0.741 vs 0.956
#  > > 32	std 	 Fit vs Val (MAc) = 0.761 vs 0.965
#  > > 32	std 	 Fit vs Val (MAc) = 0.787 vs 0.459
#  > > 32	std 	 Fit vs Val (MAc) = 0.785 vs 0.744
#  > > 32	std 	 Fit vs Val (MAc) = 0.763 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.775 vs 0.814
#  > > BEST-TH: 77.000 (2.132)
# > ('64', 'mean')
#  > > 64	mean 	 Fit vs Val (MAc) = 0.755 vs 0.807
#  > > 64	mean 	 Fit vs Val (MAc) = 0.754 vs 0.860
#  > > 64	mean 	 Fit vs Val (MAc) = 0.755 vs 0.663
#  > > 64	mean 	 Fit vs Val (MAc) = 0.743 vs 0.907
#  > > 64	mean 	 Fit vs Val (MAc) = 0.754 vs 0.863
#  > > 64	mean 	 Fit vs Val (MAc) = 0.749 vs 0.922
#  > > 64	mean 	 Fit vs Val (MAc) = 0.752 vs 0.948
#  > > 64	mean 	 Fit vs Val (MAc) = 0.723 vs 0.979
#  > > 64	mean 	 Fit vs Val (MAc) = 0.758 vs 0.618
#  > > 64	mean 	 Fit vs Val (MAc) = 0.752 vs 0.923
#  > > 64	mean 	 Fit vs Val (MAc) = 0.801 vs 0.489
#  > > 64	mean 	 Fit vs Val (MAc) = 0.754 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.756 vs 0.765
#  > > 64	mean 	 Fit vs Val (MAc) = 0.754 vs 0.910
#  > > 64	mean 	 Fit vs Val (MAc) = 0.761 vs 0.593
#  > > 64	mean 	 Fit vs Val (MAc) = 0.756 vs 0.758
#  > > 64	mean 	 Fit vs Val (MAc) = 0.728 vs 0.948
#  > > 64	mean 	 Fit vs Val (MAc) = 0.752 vs 0.873
#  > > 64	mean 	 Fit vs Val (MAc) = 0.765 vs 0.860
#  > > 64	mean 	 Fit vs Val (MAc) = 0.766 vs 0.845
#  > > 64	mean 	 Fit vs Val (MAc) = 0.754 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.758 vs 0.872
#  > > BEST-TH: 95.000 (2.462)
# > ('64', 'max')
#  > > 64	max 	 Fit vs Val (MAc) = 0.850 vs 0.953
#  > > 64	max 	 Fit vs Val (MAc) = 0.851 vs 0.953
#  > > 64	max 	 Fit vs Val (MAc) = 0.860 vs 0.871
#  > > 64	max 	 Fit vs Val (MAc) = 0.848 vs 0.951
#  > > 64	max 	 Fit vs Val (MAc) = 0.853 vs 0.948
#  > > 64	max 	 Fit vs Val (MAc) = 0.850 vs 0.977
#  > > 64	max 	 Fit vs Val (MAc) = 0.852 vs 0.920
#  > > 64	max 	 Fit vs Val (MAc) = 0.834 vs 0.966
#  > > 64	max 	 Fit vs Val (MAc) = 0.852 vs 0.956
#  > > 64	max 	 Fit vs Val (MAc) = 0.851 vs 0.955
#  > > 64	max 	 Fit vs Val (MAc) = 0.819 vs 0.940
#  > > 64	max 	 Fit vs Val (MAc) = 0.852 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.851 vs 0.925
#  > > 64	max 	 Fit vs Val (MAc) = 0.855 vs 0.897
#  > > 64	max 	 Fit vs Val (MAc) = 0.858 vs 0.691
#  > > 64	max 	 Fit vs Val (MAc) = 0.859 vs 0.691
#  > > 64	max 	 Fit vs Val (MAc) = 0.839 vs 0.954
#  > > 64	max 	 Fit vs Val (MAc) = 0.852 vs 0.970
#  > > 64	max 	 Fit vs Val (MAc) = 0.862 vs 0.676
#  > > 64	max 	 Fit vs Val (MAc) = 0.863 vs 0.823
#  > > 64	max 	 Fit vs Val (MAc) = 0.852 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.863 vs 0.646
#  > > BEST-TH: 102.000 (1.833)
# > ('64', 'min')
#  > > 64	min 	 Fit vs Val (MAc) = 0.716 vs 0.596
#  > > 64	min 	 Fit vs Val (MAc) = 0.712 vs 0.753
#  > > 64	min 	 Fit vs Val (MAc) = 0.716 vs 0.790
#  > > 64	min 	 Fit vs Val (MAc) = 0.704 vs 0.572
#  > > 64	min 	 Fit vs Val (MAc) = 0.710 vs 0.854
#  > > 64	min 	 Fit vs Val (MAc) = 0.710 vs 0.724
#  > > 64	min 	 Fit vs Val (MAc) = 0.708 vs 0.897
#  > > 64	min 	 Fit vs Val (MAc) = 0.678 vs 0.939
#  > > 64	min 	 Fit vs Val (MAc) = 0.710 vs 0.776
#  > > 64	min 	 Fit vs Val (MAc) = 0.708 vs 0.854
#  > > 64	min 	 Fit vs Val (MAc) = 0.769 vs 0.454
#  > > 64	min 	 Fit vs Val (MAc) = 0.709 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.709 vs 0.850
#  > > 64	min 	 Fit vs Val (MAc) = 0.709 vs 0.893
#  > > 64	min 	 Fit vs Val (MAc) = 0.707 vs 0.898
#  > > 64	min 	 Fit vs Val (MAc) = 0.708 vs 0.874
#  > > 64	min 	 Fit vs Val (MAc) = 0.679 vs 0.930
#  > > 64	min 	 Fit vs Val (MAc) = 0.712 vs 0.662
#  > > 64	min 	 Fit vs Val (MAc) = 0.709 vs 0.804
#  > > 64	min 	 Fit vs Val (MAc) = 0.714 vs 0.826
#  > > 64	min 	 Fit vs Val (MAc) = 0.709 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.712 vs 0.861
#  > > BEST-TH: 105.000 (1.403)
# > ('64', 'std')
#  > > 64	std 	 Fit vs Val (MAc) = 0.777 vs 0.862
#  > > 64	std 	 Fit vs Val (MAc) = 0.776 vs 0.927
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs 0.832
#  > > 64	std 	 Fit vs Val (MAc) = 0.772 vs 0.909
#  > > 64	std 	 Fit vs Val (MAc) = 0.777 vs 0.942
#  > > 64	std 	 Fit vs Val (MAc) = 0.774 vs 0.964
#  > > 64	std 	 Fit vs Val (MAc) = 0.777 vs 0.883
#  > > 64	std 	 Fit vs Val (MAc) = 0.750 vs 0.903
#  > > 64	std 	 Fit vs Val (MAc) = 0.777 vs 0.936
#  > > 64	std 	 Fit vs Val (MAc) = 0.779 vs 0.828
#  > > 64	std 	 Fit vs Val (MAc) = 0.744 vs 0.834
#  > > 64	std 	 Fit vs Val (MAc) = 0.777 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.779 vs 0.814
#  > > 64	std 	 Fit vs Val (MAc) = 0.782 vs 0.803
#  > > 64	std 	 Fit vs Val (MAc) = 0.779 vs 0.779
#  > > 64	std 	 Fit vs Val (MAc) = 0.786 vs 0.579
#  > > 64	std 	 Fit vs Val (MAc) = 0.755 vs 0.933
#  > > 64	std 	 Fit vs Val (MAc) = 0.776 vs 0.957
#  > > 64	std 	 Fit vs Val (MAc) = 0.798 vs 0.622
#  > > 64	std 	 Fit vs Val (MAc) = 0.797 vs 0.764
#  > > 64	std 	 Fit vs Val (MAc) = 0.777 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.790 vs 0.736
#  > > BEST-TH: 48.000 (1.008)
# > ('128', 'mean')
#  > > 128	mean 	 Fit vs Val (MAc) = 0.797 vs 0.864
#  > > 128	mean 	 Fit vs Val (MAc) = 0.798 vs 0.883
#  > > 128	mean 	 Fit vs Val (MAc) = 0.804 vs 0.645
#  > > 128	mean 	 Fit vs Val (MAc) = 0.792 vs 0.876
#  > > 128	mean 	 Fit vs Val (MAc) = 0.799 vs 0.852
#  > > 128	mean 	 Fit vs Val (MAc) = 0.797 vs 0.807
#  > > 128	mean 	 Fit vs Val (MAc) = 0.800 vs 0.765
#  > > 128	mean 	 Fit vs Val (MAc) = 0.776 vs 0.963
#  > > 128	mean 	 Fit vs Val (MAc) = 0.800 vs 0.724
#  > > 128	mean 	 Fit vs Val (MAc) = 0.797 vs 0.847
#  > > 128	mean 	 Fit vs Val (MAc) = 0.782 vs 0.771
#  > > 128	mean 	 Fit vs Val (MAc) = 0.798 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.800 vs 0.766
#  > > 128	mean 	 Fit vs Val (MAc) = 0.799 vs 0.833
#  > > 128	mean 	 Fit vs Val (MAc) = 0.802 vs 0.679
#  > > 128	mean 	 Fit vs Val (MAc) = 0.801 vs 0.706
#  > > 128	mean 	 Fit vs Val (MAc) = 0.780 vs 0.928
#  > > 128	mean 	 Fit vs Val (MAc) = 0.798 vs 0.823
#  > > 128	mean 	 Fit vs Val (MAc) = 0.810 vs 0.849
#  > > 128	mean 	 Fit vs Val (MAc) = 0.815 vs 0.835
#  > > 128	mean 	 Fit vs Val (MAc) = 0.798 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.865
#  > > BEST-TH: 81.000 (1.566)
# > ('128', 'max')
#  > > 128	max 	 Fit vs Val (MAc) = 0.834 vs 0.929
#  > > 128	max 	 Fit vs Val (MAc) = 0.835 vs 0.958
#  > > 128	max 	 Fit vs Val (MAc) = 0.842 vs 0.785
#  > > 128	max 	 Fit vs Val (MAc) = 0.831 vs 0.925
#  > > 128	max 	 Fit vs Val (MAc) = 0.837 vs 0.921
#  > > 128	max 	 Fit vs Val (MAc) = 0.833 vs 0.932
#  > > 128	max 	 Fit vs Val (MAc) = 0.836 vs 0.859
#  > > 128	max 	 Fit vs Val (MAc) = 0.816 vs 0.966
#  > > 128	max 	 Fit vs Val (MAc) = 0.836 vs 0.864
#  > > 128	max 	 Fit vs Val (MAc) = 0.835 vs 0.904
#  > > 128	max 	 Fit vs Val (MAc) = 0.803 vs 0.911
#  > > 128	max 	 Fit vs Val (MAc) = 0.835 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.834 vs 0.903
#  > > 128	max 	 Fit vs Val (MAc) = 0.839 vs 0.834
#  > > 128	max 	 Fit vs Val (MAc) = 0.839 vs 0.749
#  > > 128	max 	 Fit vs Val (MAc) = 0.840 vs 0.737
#  > > 128	max 	 Fit vs Val (MAc) = 0.819 vs 0.946
#  > > 128	max 	 Fit vs Val (MAc) = 0.835 vs 0.919
#  > > 128	max 	 Fit vs Val (MAc) = 0.848 vs 0.819
#  > > 128	max 	 Fit vs Val (MAc) = 0.848 vs 0.822
#  > > 128	max 	 Fit vs Val (MAc) = 0.835 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.846 vs 0.754
#  > > BEST-TH: 88.000 (0.631)
# > ('128', 'min')
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.743
#  > > 128	min 	 Fit vs Val (MAc) = 0.664 vs 0.676
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.771
#  > > 128	min 	 Fit vs Val (MAc) = 0.647 vs 0.845
#  > > 128	min 	 Fit vs Val (MAc) = 0.662 vs 0.755
#  > > 128	min 	 Fit vs Val (MAc) = 0.660 vs 0.681
#  > > 128	min 	 Fit vs Val (MAc) = 0.660 vs 0.832
#  > > 128	min 	 Fit vs Val (MAc) = 0.635 vs 0.858
#  > > 128	min 	 Fit vs Val (MAc) = 0.662 vs 0.678
#  > > 128	min 	 Fit vs Val (MAc) = 0.659 vs 0.873
#  > > 128	min 	 Fit vs Val (MAc) = 0.718 vs 0.396
#  > > 128	min 	 Fit vs Val (MAc) = 0.661 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.745
#  > > 128	min 	 Fit vs Val (MAc) = 0.659 vs 0.935
#  > > 128	min 	 Fit vs Val (MAc) = 0.664 vs 0.707
#  > > 128	min 	 Fit vs Val (MAc) = 0.659 vs 0.895
#  > > 128	min 	 Fit vs Val (MAc) = 0.624 vs 0.946
#  > > 128	min 	 Fit vs Val (MAc) = 0.663 vs 0.648
#  > > 128	min 	 Fit vs Val (MAc) = 0.665 vs 0.837
#  > > 128	min 	 Fit vs Val (MAc) = 0.672 vs 0.798
#  > > 128	min 	 Fit vs Val (MAc) = 0.661 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.665 vs 0.874
#  > > BEST-TH: 74.000 (1.316)
# > ('128', 'std')
#  > > 128	std 	 Fit vs Val (MAc) = 0.747 vs 0.872
#  > > 128	std 	 Fit vs Val (MAc) = 0.748 vs 0.879
#  > > 128	std 	 Fit vs Val (MAc) = 0.755 vs 0.792
#  > > 128	std 	 Fit vs Val (MAc) = 0.744 vs 0.815
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs 0.876
#  > > 128	std 	 Fit vs Val (MAc) = 0.745 vs 0.920
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs 0.835
#  > > 128	std 	 Fit vs Val (MAc) = 0.721 vs 0.888
#  > > 128	std 	 Fit vs Val (MAc) = 0.748 vs 0.895
#  > > 128	std 	 Fit vs Val (MAc) = 0.751 vs 0.762
#  > > 128	std 	 Fit vs Val (MAc) = 0.735 vs 0.711
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.750 vs 0.788
#  > > 128	std 	 Fit vs Val (MAc) = 0.753 vs 0.747
#  > > 128	std 	 Fit vs Val (MAc) = 0.751 vs 0.748
#  > > 128	std 	 Fit vs Val (MAc) = 0.754 vs 0.659
#  > > 128	std 	 Fit vs Val (MAc) = 0.726 vs 0.842
#  > > 128	std 	 Fit vs Val (MAc) = 0.747 vs 0.900
#  > > 128	std 	 Fit vs Val (MAc) = 0.766 vs 0.765
#  > > 128	std 	 Fit vs Val (MAc) = 0.766 vs 0.705
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs 0.681
#  > > BEST-TH: 31.000 (0.921)
# > ('512', 'ori')
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs 0.827
#  > > 512	ori 	 Fit vs Val (MAc) = 0.776 vs 0.816
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.672
#  > > 512	ori 	 Fit vs Val (MAc) = 0.771 vs 0.840
#  > > 512	ori 	 Fit vs Val (MAc) = 0.778 vs 0.768
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs 0.785
#  > > 512	ori 	 Fit vs Val (MAc) = 0.777 vs 0.772
#  > > 512	ori 	 Fit vs Val (MAc) = 0.757 vs 0.799
#  > > 512	ori 	 Fit vs Val (MAc) = 0.778 vs 0.735
#  > > 512	ori 	 Fit vs Val (MAc) = 0.774 vs 0.852
#  > > 512	ori 	 Fit vs Val (MAc) = 0.772 vs 0.652
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.776 vs 0.795
#  > > 512	ori 	 Fit vs Val (MAc) = 0.778 vs 0.787
#  > > 512	ori 	 Fit vs Val (MAc) = 0.774 vs 0.858
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs 0.838
#  > > 512	ori 	 Fit vs Val (MAc) = 0.759 vs 0.823
#  > > 512	ori 	 Fit vs Val (MAc) = 0.776 vs 0.782
#  > > 512	ori 	 Fit vs Val (MAc) = 0.785 vs 0.750
#  > > 512	ori 	 Fit vs Val (MAc) = 0.787 vs 0.798
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.775
#  > > BEST-TH: 0.308 (0.008)
# Done.
# CPU times: user 1h 35min 15s, sys: 9min 43s, total: 1h 44min 58s
# Wall time: 57min 14s

# %%
for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    exp_fit = VI_scores[e]
    exp_val = VI_scores_val[e]
    for vi, (r, f) in enumerate(VI_cols):
        ar_fit = pd.Series(exp_fit[vi])
        ar_val = pd.Series(exp_val[vi])
        
        results = (r, f , ar_fit.mean(), ar_fit.std(), ar_val.mean(), ar_val.std(), VI_scores_test[e][vi])
        print(" > > %-3s %s \t Fit vs Val vs Test (MAc) = %.3f (%.3f) vs %.3f (%.3f) vs %.3f" % results)
        if vi % 4 == 3:
            print()
    print()
    
# TODO: show generalization after getting mean th
# Out:
# Experiment [0] [1]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.799 (0.012) vs 0.732 (0.220) vs 0.833
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.746 (0.014) vs 0.387 (0.418) vs 0.676
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.621 (0.015) vs 0.685 (0.147) vs 0.382
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.737 (0.013) vs 0.697 (0.202) vs 0.581
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.780 (0.023) vs 0.716 (0.261) vs 0.863
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.890 (0.013) vs 0.924 (0.086) vs 0.524
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.682 (0.015) vs 0.716 (0.088) vs 0.578
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.823 (0.008) vs 0.814 (0.129) vs 0.688
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.786 (0.025) vs 0.783 (0.210) vs 0.888
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.893 (0.012) vs 0.923 (0.090) vs 0.734
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.725 (0.020) vs 0.754 (0.100) vs 0.718
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.828 (0.009) vs 0.818 (0.181) vs 0.727
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.787 (0.027) vs 0.845 (0.146) vs 0.874
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.892 (0.010) vs 0.917 (0.083) vs 0.800
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.722 (0.027) vs 0.811 (0.137) vs 0.804
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.840 (0.008) vs 0.856 (0.093) vs 0.746
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.843 (0.008) vs 0.820 (0.086) vs 0.858
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.879 (0.007) vs 0.889 (0.065) vs 0.857
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.689 (0.028) vs 0.778 (0.132) vs 0.770
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.803 (0.009) vs 0.814 (0.074) vs 0.754
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.813 (0.010) vs 0.789 (0.073) vs 0.819
#
# Experiment [1] [0]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.785 (0.009) vs 0.730 (0.224) vs 0.756
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.729 (0.012) vs 0.413 (0.414) vs 0.367
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.637 (0.015) vs 0.700 (0.134) vs 0.727
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.683 (0.014) vs 0.658 (0.240) vs 0.716
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.771 (0.013) vs 0.742 (0.239) vs 0.745
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.860 (0.010) vs 0.872 (0.198) vs 0.935
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.684 (0.012) vs 0.715 (0.108) vs 0.739
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.763 (0.013) vs 0.786 (0.159) vs 0.827
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.770 (0.014) vs 0.771 (0.206) vs 0.783
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.865 (0.010) vs 0.888 (0.149) vs 0.926
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.727 (0.015) vs 0.743 (0.103) vs 0.751
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.775 (0.013) vs 0.804 (0.190) vs 0.829
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.759 (0.017) vs 0.824 (0.136) vs 0.840
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.863 (0.010) vs 0.894 (0.103) vs 0.920
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.713 (0.019) vs 0.795 (0.128) vs 0.803
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.790 (0.013) vs 0.844 (0.105) vs 0.864
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.806 (0.009) vs 0.815 (0.081) vs 0.822
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.845 (0.010) vs 0.878 (0.069) vs 0.890
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.666 (0.019) vs 0.777 (0.125) vs 0.773
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.761 (0.011) vs 0.810 (0.076) vs 0.825
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.784 (0.007) vs 0.787 (0.057) vs 0.799
#
# Experiment [0, 1] [2]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.779 (0.005) vs 0.788 (0.168) vs 0.738
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.657 (0.007) vs 0.587 (0.372) vs 0.759
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.575 (0.006) vs 0.598 (0.175) vs 0.510
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.669 (0.008) vs 0.779 (0.131) vs 0.613
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.794 (0.005) vs 0.813 (0.178) vs 0.797
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.831 (0.005) vs 0.853 (0.157) vs 0.822
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.685 (0.005) vs 0.636 (0.147) vs 0.558
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.725 (0.007) vs 0.808 (0.136) vs 0.707
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.805 (0.005) vs 0.829 (0.158) vs 0.807
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.838 (0.005) vs 0.863 (0.134) vs 0.818
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.745 (0.005) vs 0.729 (0.117) vs 0.578
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.752 (0.007) vs 0.822 (0.132) vs 0.743
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.789 (0.005) vs 0.831 (0.115) vs 0.752
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.839 (0.005) vs 0.870 (0.111) vs 0.803
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.753 (0.005) vs 0.761 (0.125) vs 0.643
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.765 (0.006) vs 0.831 (0.111) vs 0.721
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.791 (0.005) vs 0.825 (0.087) vs 0.724
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.831 (0.005) vs 0.872 (0.064) vs 0.786
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.669 (0.007) vs 0.692 (0.200) vs 0.592
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.748 (0.006) vs 0.814 (0.078) vs 0.720
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.788 (0.004) vs 0.817 (0.054) vs 0.795
#
# Experiment [2] [0, 1]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.777 (0.008) vs 0.726 (0.226) vs 0.787
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.718 (0.011) vs 0.436 (0.416) vs 0.534
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.640 (0.014) vs 0.696 (0.134) vs 0.595
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.668 (0.013) vs 0.655 (0.233) vs 0.639
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.766 (0.011) vs 0.745 (0.237) vs 0.810
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.852 (0.009) vs 0.863 (0.197) vs 0.743
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.685 (0.011) vs 0.706 (0.108) vs 0.661
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.750 (0.013) vs 0.786 (0.155) vs 0.754
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.767 (0.012) vs 0.768 (0.204) vs 0.836
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.854 (0.009) vs 0.876 (0.155) vs 0.823
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.726 (0.013) vs 0.743 (0.102) vs 0.736
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.763 (0.013) vs 0.806 (0.185) vs 0.785
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.754 (0.014) vs 0.820 (0.134) vs 0.852
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.851 (0.010) vs 0.883 (0.112) vs 0.845
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.710 (0.016) vs 0.790 (0.130) vs 0.801
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.776 (0.013) vs 0.840 (0.106) vs 0.804
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.798 (0.009) vs 0.814 (0.082) vs 0.841
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.834 (0.010) vs 0.872 (0.073) vs 0.868
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.661 (0.017) vs 0.775 (0.126) vs 0.772
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.748 (0.011) vs 0.804 (0.080) vs 0.791
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.775 (0.007) vs 0.786 (0.054) vs 0.813

# %%
def XGBTrain2(data, train_imgs, y, n_trees, verbose = False, val_imgs = None):

    X_train, y_train = data.loc[IMG.isin(train_imgs)], y.loc[IMG.isin(train_imgs)]
    
    
    n = len(X_train)
    f = .02
    ix = X_train.index.values.copy()
    np.random.shuffle(ix)
    X_train = X_train.loc[ix[:int(n * f)]]
    y_train = y_train.loc[ix[:int(n * f)]]
    
    
    ratio = float(np.sum(y_train == 1)) / np.sum(y_train==0)

    clf = xgb.XGBClassifier(
                    max_depth = 2,
                    n_estimators=n_trees,
                    learning_rate=0.1, 
                    nthread=6,
                    subsample=1,
                    colsample_bytree=.5,
                    scale_pos_weight = ratio,
                    reg_alpha=0,
                    seed=1301)
    
    if type(val_imgs) != np.ndarray:
        eval_set = [
            (X_train, y_train),
        ]
    else:
        X_val, y_val = data.loc[IMG.isin(val_imgs)], y.loc[IMG.isin(val_imgs)]
        eval_set = [
            (X_train, y_train),
            (X_val, y_val),
        ]
        
    clf.fit(X_train, y_train, early_stopping_rounds=100 , eval_metric="auc",
            eval_set=eval_set,
            verbose = verbose,
           )
    
    return clf

# %%
fit_imgs = IMG.loc[solo.isin([0, 1])].unique()
val_imgs = IMG.loc[solo.isin([2])].unique()
XGBTrain2(data, fit_imgs, y, 100, verbose = True, val_imgs = val_imgs)
# Out:
# [0]	validation_0-auc:0.851897	validation_1-auc:0.816532
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.861152	validation_1-auc:0.831977
# [2]	validation_0-auc:0.872506	validation_1-auc:0.840096
# [3]	validation_0-auc:0.904317	validation_1-auc:0.839472
# [4]	validation_0-auc:0.908669	validation_1-auc:0.84527
# [5]	validation_0-auc:0.911479	validation_1-auc:0.850146
# [6]	validation_0-auc:0.913097	validation_1-auc:0.848026
# [7]	validation_0-auc:0.915936	validation_1-auc:0.853643
# [8]	validation_0-auc:0.918047	validation_1-auc:0.851785
# [9]	validation_0-auc:0.922171	validation_1-auc:0.863245
# [10]	validation_0-auc:0.923546	validation_1-auc:0.867116
# [11]	validation_0-auc:0.927944	validation_1-auc:0.867585
# [12]	validation_0-auc:0.928556	validation_1-auc:0.866242
# [13]	validation_0-auc:0.930884	validation_1-auc:0.864618
# [14]	validation_0-auc:0.935847	validation_1-auc:0.876891
# [15]	validation_0-auc:0.936118	validation_1-auc:0.875918
# [16]	validation_0-auc:0.939333	validation_1-auc:0.882938
# [17]	validation_0-auc:0.940116	validation_1-auc:0.882844
# [18]	validation_0-auc:0.94035	validation_1-auc:0.882755
# [19]	validation_0-auc:0.940866	validation_1-auc:0.881444
# [20]	validation_0-auc:0.941861	validation_1-auc:0.884766
# [21]	validation_0-auc:0.942292	validation_1-auc:0.882214
# [22]	validation_0-auc:0.943707	validation_1-auc:0.885837
# [23]	validation_0-auc:0.944872	validation_1-auc:0.890568
# [24]	validation_0-auc:0.946135	validation_1-auc:0.89526
# [25]	validation_0-auc:0.946836	validation_1-auc:0.897714
# [26]	validation_0-auc:0.948733	validation_1-auc:0.899859
# [27]	validation_0-auc:0.948881	validation_1-auc:0.900243
# [28]	validation_0-auc:0.950196	validation_1-auc:0.901689
# [29]	validation_0-auc:0.951037	validation_1-auc:0.900921
# [30]	validation_0-auc:0.95192	validation_1-auc:0.902186
# [31]	validation_0-auc:0.952473	validation_1-auc:0.904022
# [32]	validation_0-auc:0.952715	validation_1-auc:0.905334
# [33]	validation_0-auc:0.95348	validation_1-auc:0.905449
# [34]	validation_0-auc:0.953866	validation_1-auc:0.904805
# [35]	validation_0-auc:0.954641	validation_1-auc:0.905339
# [36]	validation_0-auc:0.955102	validation_1-auc:0.905354
# [37]	validation_0-auc:0.955172	validation_1-auc:0.905414
# [38]	validation_0-auc:0.955479	validation_1-auc:0.905568
# [39]	validation_0-auc:0.955668	validation_1-auc:0.90707
# [40]	validation_0-auc:0.956355	validation_1-auc:0.904812
# [41]	validation_0-auc:0.95671	validation_1-auc:0.905902
# [42]	validation_0-auc:0.957024	validation_1-auc:0.906869
# [43]	validation_0-auc:0.957195	validation_1-auc:0.906707
# [44]	validation_0-auc:0.957294	validation_1-auc:0.90796
# [45]	validation_0-auc:0.957759	validation_1-auc:0.906271
# [46]	validation_0-auc:0.957997	validation_1-auc:0.905404
# [47]	validation_0-auc:0.958026	validation_1-auc:0.905203
# [48]	validation_0-auc:0.958368	validation_1-auc:0.904359
# [49]	validation_0-auc:0.958568	validation_1-auc:0.903533
# [50]	validation_0-auc:0.95872	validation_1-auc:0.903545
# [51]	validation_0-auc:0.958881	validation_1-auc:0.903616
# [52]	validation_0-auc:0.959098	validation_1-auc:0.903884
# [53]	validation_0-auc:0.959216	validation_1-auc:0.903972
# [54]	validation_0-auc:0.959435	validation_1-auc:0.902694
# [55]	validation_0-auc:0.959465	validation_1-auc:0.902734
# [56]	validation_0-auc:0.959625	validation_1-auc:0.901585
# [57]	validation_0-auc:0.959731	validation_1-auc:0.901454
# [58]	validation_0-auc:0.959763	validation_1-auc:0.900783
# [59]	validation_0-auc:0.959933	validation_1-auc:0.899984
# [60]	validation_0-auc:0.959993	validation_1-auc:0.900067
# [61]	validation_0-auc:0.960062	validation_1-auc:0.899977
# [62]	validation_0-auc:0.960125	validation_1-auc:0.900052
# [63]	validation_0-auc:0.960234	validation_1-auc:0.899778
# [64]	validation_0-auc:0.960383	validation_1-auc:0.899092
# [65]	validation_0-auc:0.960396	validation_1-auc:0.898571
# [66]	validation_0-auc:0.960456	validation_1-auc:0.897907
# [67]	validation_0-auc:0.960575	validation_1-auc:0.897281
# [68]	validation_0-auc:0.960625	validation_1-auc:0.89701
# [69]	validation_0-auc:0.960627	validation_1-auc:0.897287
# [70]	validation_0-auc:0.960824	validation_1-auc:0.896894
# [71]	validation_0-auc:0.960882	validation_1-auc:0.896331
# [72]	validation_0-auc:0.960909	validation_1-auc:0.896366
# [73]	validation_0-auc:0.96093	validation_1-auc:0.896375
# [74]	validation_0-auc:0.961095	validation_1-auc:0.895847
# [75]	validation_0-auc:0.961222	validation_1-auc:0.895978
# [76]	validation_0-auc:0.961293	validation_1-auc:0.896053
# [77]	validation_0-auc:0.96136	validation_1-auc:0.895631
# [78]	validation_0-auc:0.961398	validation_1-auc:0.895889
# [79]	validation_0-auc:0.961467	validation_1-auc:0.896001
# [80]	validation_0-auc:0.961484	validation_1-auc:0.896002
# [81]	validation_0-auc:0.961559	validation_1-auc:0.896103
# [82]	validation_0-auc:0.961583	validation_1-auc:0.896234
# [83]	validation_0-auc:0.961634	validation_1-auc:0.89589
# [84]	validation_0-auc:0.961761	validation_1-auc:0.895344
# [85]	validation_0-auc:0.961835	validation_1-auc:0.894988
# [86]	validation_0-auc:0.961872	validation_1-auc:0.894512
# [87]	validation_0-auc:0.961919	validation_1-auc:0.894073
# [88]	validation_0-auc:0.962031	validation_1-auc:0.894263
# [89]	validation_0-auc:0.962064	validation_1-auc:0.894499
# [90]	validation_0-auc:0.962111	validation_1-auc:0.894536
# [91]	validation_0-auc:0.962134	validation_1-auc:0.894717
# [92]	validation_0-auc:0.962142	validation_1-auc:0.894722
# [93]	validation_0-auc:0.962194	validation_1-auc:0.894344
# [94]	validation_0-auc:0.962224	validation_1-auc:0.894608
# [95]	validation_0-auc:0.962325	validation_1-auc:0.89447
# [96]	validation_0-auc:0.962401	validation_1-auc:0.894657
# [97]	validation_0-auc:0.962477	validation_1-auc:0.89424
# [98]	validation_0-auc:0.962499	validation_1-auc:0.894489
# [99]	validation_0-auc:0.962541	validation_1-auc:0.894539
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.5, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=6, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=3.2983824506979835,
#        seed=1301, silent=True, subsample=1)

# %%
type(val_imgs)
# Out:
# numpy.ndarray

# %%
IMG.isin(test_imgs) & (np.random.rand(len(data)) <= 0.2)
# Out:
# 52196

# %%
tree_list = list(range(30, 60, 10))
tree_list = [50]

VI_scores = [[[] for vi in tree_list] for _ in range(4)] # 4 is the number of experiments
VI_scores_val = [[[] for t in tree_list] for _ in range(4)]
VI_scores_test = [[0 for t in tree_list] for _ in range(4)]
THS = [[[] for vi in names_VI] for _ in range(4)]

for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    
    images = list(set(IMG.loc[data.loc[solo.isin(left)].index]))
    for t, trees in enumerate(tree_list):

        print('>', trees)
        
        for train_imgs, test_imgs in loo.split(images):
            
            # fit model
            clf = XGBTrain2(data, train_imgs, y, trees)
            
            # fit score
            frac = .2
            fit_mask = IMG.isin(train_imgs) & (np.random.rand(len(data)) <= frac)
            prediction = clf.predict_proba(data.loc[fit_mask])[:,-1]
            fit_y = y.loc[fit_mask]
            _auc, mean_acc, bestTH, fpr, tpr = getPerformance(fit_y, prediction)
            
            # val score
            val_mask = IMG.isin(test_imgs)
            prediction = clf.predict_proba(data.loc[val_mask])[:,-1]
            val_y = y.loc[val_mask]
            val_mean_acc = accuracy_score(val_y, 1 * (prediction > bestTH))
            
            # save
            VI_scores[e][t].append(mean_acc)
            VI_scores_val[e][t].append(val_mean_acc)
            THS[e][t].append(bestTH)
            print(" > > %d \t Fit vs Val (MAc) = %.3f vs %.3f" % (trees, mean_acc, val_mean_acc))
        
        # test score
        ar = np.array(THS[e][t])
        bestTH = np.median(ar)
        print(" > > BEST-TH: %.3f (%.3f)" % (bestTH, ar.std()))
        
        test_mask = solo.isin(test)
        prediction = clf.predict_proba(data.loc[test_mask])[:,-1]
        test_y = y.loc[test_mask]
        test_mean_acc = accuracy_score(test_y, 1 * (prediction > bestTH))
        
        VI_scores_test[e][t] = test_mean_acc
        print(" > > TEST Score : %.3f" % test_mean_acc)
        
print("Done.")
# Out:
# Experiment [0] [1]
# > 25
#  > > 25 	 Fit vs Val (MAc) = 0.910 vs 0.985
#  > > 25 	 Fit vs Val (MAc) = 0.912 vs 0.979
#  > > 25 	 Fit vs Val (MAc) = 0.924 vs 0.886
#  > > 25 	 Fit vs Val (MAc) = 0.908 vs 0.964
#  > > 25 	 Fit vs Val (MAc) = 0.915 vs 0.961
#  > > 25 	 Fit vs Val (MAc) = 0.911 vs 0.978
#  > > 25 	 Fit vs Val (MAc) = 0.911 vs 0.972
#  > > 25 	 Fit vs Val (MAc) = 0.894 vs 0.987
#  > > 25 	 Fit vs Val (MAc) = 0.913 vs 0.963
#  > > 25 	 Fit vs Val (MAc) = 0.911 vs 0.977
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs 0.804
# /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/numpy/lib/function_base.py:356: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /store/tveiga/miniconda3/envs/py/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  > > 25 	 Fit vs Val (MAc) = 0.909 vs nan
#  > > 25 	 Fit vs Val (MAc) = 0.910 vs 0.965
#  > > 25 	 Fit vs Val (MAc) = 0.918 vs 0.913
#  > > 25 	 Fit vs Val (MAc) = 0.913 vs 0.789
#  > > 25 	 Fit vs Val (MAc) = 0.921 vs 0.748
#  > > 25 	 Fit vs Val (MAc) = 0.902 vs 0.969
#  > > BEST-TH: 0.932 (0.007)
#  > > TEST Score : 0.839
# Experiment [1] [0]
# > 25
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs 0.976
#  > > 25 	 Fit vs Val (MAc) = 0.886 vs 0.977
#  > > 25 	 Fit vs Val (MAc) = 0.892 vs 0.886
#  > > 25 	 Fit vs Val (MAc) = 0.880 vs 0.963
#  > > 25 	 Fit vs Val (MAc) = 0.889 vs 0.961
#  > > 25 	 Fit vs Val (MAc) = 0.884 vs 0.975
#  > > 25 	 Fit vs Val (MAc) = 0.884 vs 0.966
#  > > 25 	 Fit vs Val (MAc) = 0.867 vs 0.987
#  > > 25 	 Fit vs Val (MAc) = 0.886 vs 0.964
#  > > 25 	 Fit vs Val (MAc) = 0.884 vs 0.979
#  > > 25 	 Fit vs Val (MAc) = 0.862 vs 0.967
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs nan
#  > > 25 	 Fit vs Val (MAc) = 0.883 vs 0.947
#  > > 25 	 Fit vs Val (MAc) = 0.890 vs 0.921
#  > > 25 	 Fit vs Val (MAc) = 0.885 vs 0.744
#  > > 25 	 Fit vs Val (MAc) = 0.890 vs 0.773
#  > > 25 	 Fit vs Val (MAc) = 0.875 vs 0.966
#  > > 25 	 Fit vs Val (MAc) = 0.884 vs 0.974
#  > > 25 	 Fit vs Val (MAc) = 0.896 vs 0.549
#  > > 25 	 Fit vs Val (MAc) = 0.894 vs 0.861
#  > > BEST-TH: 0.936 (0.005)
#  > > TEST Score : 0.950
# Experiment [0, 1] [2]
# > 25
#  > > 25 	 Fit vs Val (MAc) = 0.876 vs 0.988
#  > > 25 	 Fit vs Val (MAc) = 0.878 vs 0.979
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs 0.881
#  > > 25 	 Fit vs Val (MAc) = 0.877 vs 0.964
#  > > 25 	 Fit vs Val (MAc) = 0.880 vs 0.961
#  > > 25 	 Fit vs Val (MAc) = 0.877 vs 0.977
#  > > 25 	 Fit vs Val (MAc) = 0.877 vs 0.969
#  > > 25 	 Fit vs Val (MAc) = 0.874 vs 0.989
#  > > 25 	 Fit vs Val (MAc) = 0.879 vs 0.964
#  > > 25 	 Fit vs Val (MAc) = 0.877 vs 0.980
#  > > 25 	 Fit vs Val (MAc) = 0.873 vs 0.919
#  > > 25 	 Fit vs Val (MAc) = 0.878 vs nan
#  > > 25 	 Fit vs Val (MAc) = 0.878 vs 0.962
#  > > 25 	 Fit vs Val (MAc) = 0.880 vs 0.919
#  > > 25 	 Fit vs Val (MAc) = 0.879 vs 0.850
#  > > 25 	 Fit vs Val (MAc) = 0.879 vs 0.774
#  > > 25 	 Fit vs Val (MAc) = 0.875 vs 0.966
#  > > 25 	 Fit vs Val (MAc) = 0.878 vs 0.973
#  > > 25 	 Fit vs Val (MAc) = 0.881 vs 0.635
#  > > 25 	 Fit vs Val (MAc) = 0.879 vs 0.876
#  > > 25 	 Fit vs Val (MAc) = 0.878 vs nan
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs 0.826
#  > > 25 	 Fit vs Val (MAc) = 0.878 vs 0.855
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs 0.640
#  > > 25 	 Fit vs Val (MAc) = 0.881 vs 0.861
#  > > 25 	 Fit vs Val (MAc) = 0.879 vs 0.870
#  > > 25 	 Fit vs Val (MAc) = 0.877 vs 0.924
#  > > 25 	 Fit vs Val (MAc) = 0.880 vs 0.799
#  > > 25 	 Fit vs Val (MAc) = 0.871 vs 0.953
#  > > 25 	 Fit vs Val (MAc) = 0.877 vs 0.913
#  > > 25 	 Fit vs Val (MAc) = 0.876 vs nan
#  > > 25 	 Fit vs Val (MAc) = 0.879 vs 0.820
#  > > 25 	 Fit vs Val (MAc) = 0.883 vs 0.749
#  > > 25 	 Fit vs Val (MAc) = 0.881 vs 0.802
#  > > 25 	 Fit vs Val (MAc) = 0.875 vs 0.912
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs 0.617
#  > > 25 	 Fit vs Val (MAc) = 0.870 vs 0.975
#  > > BEST-TH: 0.902 (0.004)
#  > > TEST Score : 0.816
# Experiment [2] [0, 1]
# > 25
#  > > 25 	 Fit vs Val (MAc) = 0.873 vs 0.984
#  > > 25 	 Fit vs Val (MAc) = 0.873 vs 0.978
#  > > 25 	 Fit vs Val (MAc) = 0.880 vs 0.886
#  > > 25 	 Fit vs Val (MAc) = 0.870 vs 0.963
#  > > 25 	 Fit vs Val (MAc) = 0.877 vs 0.959
#  > > 25 	 Fit vs Val (MAc) = 0.874 vs 0.976
#  > > 25 	 Fit vs Val (MAc) = 0.873 vs 0.941
#  > > 25 	 Fit vs Val (MAc) = 0.859 vs 0.987
#  > > 25 	 Fit vs Val (MAc) = 0.878 vs 0.964
#  > > 25 	 Fit vs Val (MAc) = 0.873 vs 0.980
#  > > 25 	 Fit vs Val (MAc) = 0.851 vs 0.977
#  > > 25 	 Fit vs Val (MAc) = 0.873 vs nan
#  > > 25 	 Fit vs Val (MAc) = 0.874 vs 0.940
#  > > 25 	 Fit vs Val (MAc) = 0.879 vs 0.909
#  > > 25 	 Fit vs Val (MAc) = 0.872 vs 0.778
#  > > 25 	 Fit vs Val (MAc) = 0.882 vs 0.744
#  > > 25 	 Fit vs Val (MAc) = 0.865 vs 0.963
#  > > 25 	 Fit vs Val (MAc) = 0.875 vs 0.971
#  > > 25 	 Fit vs Val (MAc) = 0.885 vs 0.531
#  > > 25 	 Fit vs Val (MAc) = 0.881 vs 0.865
#  > > 25 	 Fit vs Val (MAc) = 0.875 vs nan
#  > > 25 	 Fit vs Val (MAc) = 0.884 vs 0.822
#  > > BEST-TH: 0.941 (0.006)
#  > > TEST Score : 0.874
# Done.

# %%
for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    exp_fit = VI_scores[e]
    exp_val = VI_scores_val[e]
    for t, trees in enumerate(tree_list):
        ar_fit = pd.Series(exp_fit[t])
        ar_val = pd.Series(exp_val[t])
        
        results = (trees, ar_fit.mean(), ar_fit.std(), ar_val.mean(), ar_val.std(), VI_scores_test[e][t])
        print(" > > %d \t Fit vs Val vs Test (MAc) = %.3f (%.3f) vs %.3f (%.3f) vs %.3f" % results)
# Out:
# Experiment [0] [1]
#  > > 25 	 Fit vs Val vs Test (MAc) = 0.910 (0.010) vs 0.927 (0.078) vs 0.839
# Experiment [1] [0]
#  > > 25 	 Fit vs Val vs Test (MAc) = 0.884 (0.008) vs 0.912 (0.112) vs 0.950
# Experiment [0, 1] [2]
#  > > 25 	 Fit vs Val vs Test (MAc) = 0.878 (0.003) vs 0.884 (0.105) vs 0.816
# Experiment [2] [0, 1]
#  > > 25 	 Fit vs Val vs Test (MAc) = 0.874 (0.008) vs 0.906 (0.114) vs 0.874

# %%
"""
trees = 50
Experiment [0] [1]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.923 (0.007) vs 0.923 (0.087) vs 0.810
Experiment [1] [0]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.906 (0.007) vs 0.908 (0.116) vs 0.956
Experiment [0, 1] [2]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.893 (0.003) vs 0.901 (0.078) vs 0.815
Experiment [2] [0, 1]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.900 (0.006) vs 0.903 (0.110) vs 0.885 

"""
