# %% [markdown]
# # Fancy Approach (repeat upsampling)

# %% [markdown]
# **Descrition:**
#
# Experiment for trying to combine stats from different resolutions.
#
# Just like the other Fancy approch, but this time a different base is used. In this new base, no bilinear upsampling was used. Pixels were just repeated (apparently this yield better results).

# %%
# %load_ext autoreload

import sys
sys.path.insert(0, "/store/tveiga/IC2017/utilities")

import pandas as pd
import numpy as np

from sklearn.model_selection import LeaveOneOut
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

import xgboost as xgb

# %%
# %autoreload
from IC2017 import *

# %% [markdown]
# <hr>

# %%
# Read database from disk
data = pd.read_csv("../IC2017_DATA/FancyApproach_dataset-Repeat.csv", header = [0, 1])

# %%
# Copy non feature data from the base, before removing them for training purpose

y = data["GT"].iloc[:, 0] # iloc transform it into a Series
IMG = data["IMG"].iloc[:, 0]
# BLOCK = data["block_num"]
# solo = data["solo"]
base = data["solo"].iloc[:, 0]

#--------------------------

# Remove non feature data from the base, for training purpose

del data["GT"]
del data["IMG"] # big jump in precision by keeping this feature
del data["solo"]

#--------------------------

solo = base # just for variable name compatibility

# %% [markdown]
# <hr>

# %%
# Definition of the experiments

LessCompact = [0]
MoreCompact = [1]
Calibrated = [0, 1]
NotCalibrated = [2]
experiments = [[LessCompact, MoreCompact], [MoreCompact, LessCompact],
              [Calibrated, NotCalibrated], [NotCalibrated, Calibrated]]

# %% [markdown]
# <hr>

# %% [markdown]
# ## Individual Feature

# %%
loo = LeaveOneOut()

# %%
VI_cols = names_VI = data.columns.to_list()

# %%
# %%time

'''
Just like in the standard experiment, here we want to know how effective each feature is for
generelazing. Therefore we should obtain training, validation and test accuracy, and also the
threshold found.
''' 

VI_scores = [[[] for vi in names_VI] for _ in range(4)] # 4 is the number of experiments
VI_scores_val = [[[] for vi in names_VI] for _ in range(4)]
VI_scores_test = [[0 for vi in names_VI] for _ in range(4)]
THS = [[[] for vi in names_VI] for _ in range(4)]

for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    
    images = np.unique(IMG.loc[solo.isin(left)])
    for vi, col in enumerate(VI_cols):
        print('>', col)
        
        for _in, _out in loo.split(images):
            train_imgs, test_imgs = images[_in], images[_out]
            
            # fit (find th in fit set)
            # frac = .2
            # fit_mask = IMG.isin(train_imgs) & (np.random.rand(len(data)) <= frac)
            fit_mask = IMG.isin(train_imgs)
            prediction = data.loc[fit_mask, col]
            fit_y = y.loc[fit_mask]
            _auc, mean_acc, bestTH, fpr, tpr = getPerformance(fit_y, prediction)
            
            # val score
            val_mask = IMG.isin(test_imgs)
            prediction = data.loc[val_mask, col]
            val_y = y.loc[val_mask]
            val_mean_acc = accuracy_score(val_y, 1 * (prediction > bestTH))
            
            # save results (fit, val and th)
            VI_scores[e][vi].append(mean_acc)
            VI_scores_val[e][vi].append(val_mean_acc)
            THS[e][vi].append(bestTH)
            print(" > > %s\t%s \t Fit vs Val (MAc) = %.3f vs %.3f" % (*col, mean_acc, val_mean_acc))
            
        ths = pd.Series(THS[e][vi])
        print(" > > BEST-TH: %.3f (%.3f)" % (ths.median(), ths.std()))
        
        # test score
        test_mask = solo.isin(test)
        prediction = data.loc[test_mask, col]
        test_y = y.loc[test_mask]
        test_mean_acc = accuracy_score(test_y, 1 * (prediction > bestTH))
        
        VI_scores_test[e][vi] = test_mean_acc
        print(' > > Test Acc: %.3f' % test_mean_acc)
        
        
print("Done.")
# Out:
# Experiment [0] [1]
# > ('8', 'mean')
#  > > 8	mean 	 Fit vs Val (MAc) = 0.913 vs 1.000
#  > > 8	mean 	 Fit vs Val (MAc) = 0.917 vs 0.978
#  > > 8	mean 	 Fit vs Val (MAc) = 0.924 vs 0.808
#  > > 8	mean 	 Fit vs Val (MAc) = 0.916 vs 0.942
#  > > 8	mean 	 Fit vs Val (MAc) = 0.922 vs 0.956
#  > > 8	mean 	 Fit vs Val (MAc) = 0.915 vs 0.924
#  > > 8	mean 	 Fit vs Val (MAc) = 0.916 vs 0.938
#  > > 8	mean 	 Fit vs Val (MAc) = 0.910 vs 0.742
#  > > 8	mean 	 Fit vs Val (MAc) = 0.917 vs 0.919
#  > > 8	mean 	 Fit vs Val (MAc) = 0.916 vs 0.984
#  > > 8	mean 	 Fit vs Val (MAc) = 0.894 vs 0.857
#  > > 8	mean 	 Fit vs Val (MAc) = 0.915 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.913 vs 0.997
#  > > 8	mean 	 Fit vs Val (MAc) = 0.923 vs 0.869
#  > > 8	mean 	 Fit vs Val (MAc) = 0.913 vs 1.000
#  > > 8	mean 	 Fit vs Val (MAc) = 0.920 vs 0.955
#  > > 8	mean 	 Fit vs Val (MAc) = 0.910 vs 0.915
#  > > BEST-TH: 0.365 (0.004)
#  > > Test Acc: 0.838
# > ('8', 'max')
#  > > 8	max 	 Fit vs Val (MAc) = 0.870 vs 1.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.874 vs 0.978
#  > > 8	max 	 Fit vs Val (MAc) = 0.893 vs 0.874
#  > > 8	max 	 Fit vs Val (MAc) = 0.878 vs 0.927
#  > > 8	max 	 Fit vs Val (MAc) = 0.878 vs 0.956
#  > > 8	max 	 Fit vs Val (MAc) = 0.878 vs 0.949
#  > > 8	max 	 Fit vs Val (MAc) = 0.873 vs 0.983
#  > > 8	max 	 Fit vs Val (MAc) = 0.850 vs 0.976
#  > > 8	max 	 Fit vs Val (MAc) = 0.879 vs 0.952
#  > > 8	max 	 Fit vs Val (MAc) = 0.873 vs 0.984
#  > > 8	max 	 Fit vs Val (MAc) = 0.812 vs 0.764
#  > > 8	max 	 Fit vs Val (MAc) = 0.871 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.870 vs 0.997
#  > > 8	max 	 Fit vs Val (MAc) = 0.880 vs 0.896
#  > > 8	max 	 Fit vs Val (MAc) = 0.870 vs 1.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.878 vs 0.844
#  > > 8	max 	 Fit vs Val (MAc) = 0.854 vs 0.938
#  > > BEST-TH: 0.976 (0.028)
#  > > Test Acc: 0.606
# > ('8', 'min')
#  > > 8	min 	 Fit vs Val (MAc) = 0.709 vs 0.766
#  > > 8	min 	 Fit vs Val (MAc) = 0.710 vs 0.823
#  > > 8	min 	 Fit vs Val (MAc) = 0.729 vs 0.454
#  > > 8	min 	 Fit vs Val (MAc) = 0.706 vs 0.735
#  > > 8	min 	 Fit vs Val (MAc) = 0.719 vs 0.679
#  > > 8	min 	 Fit vs Val (MAc) = 0.714 vs 0.565
#  > > 8	min 	 Fit vs Val (MAc) = 0.716 vs 0.632
#  > > 8	min 	 Fit vs Val (MAc) = 0.685 vs 0.701
#  > > 8	min 	 Fit vs Val (MAc) = 0.722 vs 0.475
#  > > 8	min 	 Fit vs Val (MAc) = 0.710 vs 0.754
#  > > 8	min 	 Fit vs Val (MAc) = 0.771 vs 0.448
#  > > 8	min 	 Fit vs Val (MAc) = 0.712 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.712 vs 0.700
#  > > 8	min 	 Fit vs Val (MAc) = 0.713 vs 0.765
#  > > 8	min 	 Fit vs Val (MAc) = 0.704 vs 0.891
#  > > 8	min 	 Fit vs Val (MAc) = 0.707 vs 0.939
#  > > 8	min 	 Fit vs Val (MAc) = 0.688 vs 0.762
#  > > BEST-TH: 0.058 (0.004)
#  > > Test Acc: 0.445
# > ('8', 'std')
#  > > 8	std 	 Fit vs Val (MAc) = 0.853 vs 1.000
#  > > 8	std 	 Fit vs Val (MAc) = 0.857 vs 0.978
#  > > 8	std 	 Fit vs Val (MAc) = 0.876 vs 0.872
#  > > 8	std 	 Fit vs Val (MAc) = 0.860 vs 0.927
#  > > 8	std 	 Fit vs Val (MAc) = 0.861 vs 0.956
#  > > 8	std 	 Fit vs Val (MAc) = 0.863 vs 0.940
#  > > 8	std 	 Fit vs Val (MAc) = 0.856 vs 0.983
#  > > 8	std 	 Fit vs Val (MAc) = 0.828 vs 0.976
#  > > 8	std 	 Fit vs Val (MAc) = 0.861 vs 0.952
#  > > 8	std 	 Fit vs Val (MAc) = 0.856 vs 0.984
#  > > 8	std 	 Fit vs Val (MAc) = 0.788 vs 0.764
#  > > 8	std 	 Fit vs Val (MAc) = 0.854 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.853 vs 0.997
#  > > 8	std 	 Fit vs Val (MAc) = 0.862 vs 0.911
#  > > 8	std 	 Fit vs Val (MAc) = 0.853 vs 1.000
#  > > 8	std 	 Fit vs Val (MAc) = 0.864 vs 0.572
#  > > 8	std 	 Fit vs Val (MAc) = 0.843 vs 0.924
#  > > BEST-TH: 0.089 (0.006)
#  > > Test Acc: 0.676
# > ('16', 'mean')
#  > > 16	mean 	 Fit vs Val (MAc) = 0.930 vs 1.000
#  > > 16	mean 	 Fit vs Val (MAc) = 0.934 vs 0.980
#  > > 16	mean 	 Fit vs Val (MAc) = 0.940 vs 0.879
#  > > 16	mean 	 Fit vs Val (MAc) = 0.931 vs 0.953
#  > > 16	mean 	 Fit vs Val (MAc) = 0.937 vs 0.956
#  > > 16	mean 	 Fit vs Val (MAc) = 0.931 vs 0.974
#  > > 16	mean 	 Fit vs Val (MAc) = 0.933 vs 0.949
#  > > 16	mean 	 Fit vs Val (MAc) = 0.924 vs 0.867
#  > > 16	mean 	 Fit vs Val (MAc) = 0.934 vs 0.933
#  > > 16	mean 	 Fit vs Val (MAc) = 0.932 vs 0.987
#  > > 16	mean 	 Fit vs Val (MAc) = 0.907 vs 0.917
#  > > 16	mean 	 Fit vs Val (MAc) = 0.931 vs nan
#  > > 16	mean 	 Fit vs Val (MAc) = 0.931 vs 0.989
#  > > 16	mean 	 Fit vs Val (MAc) = 0.937 vs 0.931
#  > > 16	mean 	 Fit vs Val (MAc) = 0.930 vs 1.000
#  > > 16	mean 	 Fit vs Val (MAc) = 0.934 vs 0.960
#  > > 16	mean 	 Fit vs Val (MAc) = 0.927 vs 0.933
#  > > BEST-TH: 0.348 (0.004)
#  > > Test Acc: 0.881
# > ('16', 'max')
#  > > 16	max 	 Fit vs Val (MAc) = 0.886 vs 1.000
#  > > 16	max 	 Fit vs Val (MAc) = 0.889 vs 0.980
#  > > 16	max 	 Fit vs Val (MAc) = 0.906 vs 0.880
#  > > 16	max 	 Fit vs Val (MAc) = 0.888 vs 0.943
#  > > 16	max 	 Fit vs Val (MAc) = 0.894 vs 0.956
#  > > 16	max 	 Fit vs Val (MAc) = 0.891 vs 0.966
#  > > 16	max 	 Fit vs Val (MAc) = 0.889 vs 0.981
#  > > 16	max 	 Fit vs Val (MAc) = 0.869 vs 0.924
#  > > 16	max 	 Fit vs Val (MAc) = 0.893 vs 0.956
#  > > 16	max 	 Fit vs Val (MAc) = 0.889 vs 0.984
#  > > 16	max 	 Fit vs Val (MAc) = 0.845 vs 0.821
#  > > 16	max 	 Fit vs Val (MAc) = 0.887 vs nan
#  > > 16	max 	 Fit vs Val (MAc) = 0.886 vs 0.997
#  > > 16	max 	 Fit vs Val (MAc) = 0.895 vs 0.841
#  > > 16	max 	 Fit vs Val (MAc) = 0.886 vs 0.992
#  > > 16	max 	 Fit vs Val (MAc) = 0.896 vs 0.783
#  > > 16	max 	 Fit vs Val (MAc) = 0.873 vs 0.914
#  > > BEST-TH: 0.738 (0.059)
#  > > Test Acc: 0.439
# > ('16', 'min')
#  > > 16	min 	 Fit vs Val (MAc) = 0.722 vs 0.855
#  > > 16	min 	 Fit vs Val (MAc) = 0.724 vs 0.876
#  > > 16	min 	 Fit vs Val (MAc) = 0.737 vs 0.608
#  > > 16	min 	 Fit vs Val (MAc) = 0.722 vs 0.804
#  > > 16	min 	 Fit vs Val (MAc) = 0.728 vs 0.786
#  > > 16	min 	 Fit vs Val (MAc) = 0.726 vs 0.719
#  > > 16	min 	 Fit vs Val (MAc) = 0.725 vs 0.779
#  > > 16	min 	 Fit vs Val (MAc) = 0.689 vs 0.695
#  > > 16	min 	 Fit vs Val (MAc) = 0.731 vs 0.607
#  > > 16	min 	 Fit vs Val (MAc) = 0.722 vs 0.869
#  > > 16	min 	 Fit vs Val (MAc) = 0.789 vs 0.486
#  > > 16	min 	 Fit vs Val (MAc) = 0.724 vs nan
#  > > 16	min 	 Fit vs Val (MAc) = 0.724 vs 0.825
#  > > 16	min 	 Fit vs Val (MAc) = 0.725 vs 0.857
#  > > 16	min 	 Fit vs Val (MAc) = 0.719 vs 0.934
#  > > 16	min 	 Fit vs Val (MAc) = 0.722 vs 0.943
#  > > 16	min 	 Fit vs Val (MAc) = 0.690 vs 0.817
#  > > BEST-TH: 0.079 (0.005)
#  > > Test Acc: 0.559
# > ('16', 'std')
#  > > 16	std 	 Fit vs Val (MAc) = 0.863 vs 1.000
#  > > 16	std 	 Fit vs Val (MAc) = 0.867 vs 0.978
#  > > 16	std 	 Fit vs Val (MAc) = 0.885 vs 0.877
#  > > 16	std 	 Fit vs Val (MAc) = 0.867 vs 0.941
#  > > 16	std 	 Fit vs Val (MAc) = 0.870 vs 0.956
#  > > 16	std 	 Fit vs Val (MAc) = 0.871 vs 0.951
#  > > 16	std 	 Fit vs Val (MAc) = 0.865 vs 0.981
#  > > 16	std 	 Fit vs Val (MAc) = 0.841 vs 0.959
#  > > 16	std 	 Fit vs Val (MAc) = 0.871 vs 0.952
#  > > 16	std 	 Fit vs Val (MAc) = 0.865 vs 0.984
#  > > 16	std 	 Fit vs Val (MAc) = 0.813 vs 0.804
#  > > 16	std 	 Fit vs Val (MAc) = 0.863 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.863 vs 0.997
#  > > 16	std 	 Fit vs Val (MAc) = 0.875 vs 0.720
#  > > 16	std 	 Fit vs Val (MAc) = 0.863 vs 0.992
#  > > 16	std 	 Fit vs Val (MAc) = 0.876 vs 0.635
#  > > 16	std 	 Fit vs Val (MAc) = 0.850 vs 0.945
#  > > BEST-TH: 0.083 (0.006)
#  > > Test Acc: 0.585
# > ('32', 'mean')
#  > > 32	mean 	 Fit vs Val (MAc) = 0.924 vs 0.990
#  > > 32	mean 	 Fit vs Val (MAc) = 0.928 vs 0.975
#  > > 32	mean 	 Fit vs Val (MAc) = 0.937 vs 0.848
#  > > 32	mean 	 Fit vs Val (MAc) = 0.925 vs 0.957
#  > > 32	mean 	 Fit vs Val (MAc) = 0.930 vs 0.944
#  > > 32	mean 	 Fit vs Val (MAc) = 0.926 vs 0.958
#  > > 32	mean 	 Fit vs Val (MAc) = 0.927 vs 0.944
#  > > 32	mean 	 Fit vs Val (MAc) = 0.916 vs 0.902
#  > > 32	mean 	 Fit vs Val (MAc) = 0.927 vs 0.936
#  > > 32	mean 	 Fit vs Val (MAc) = 0.926 vs 0.978
#  > > 32	mean 	 Fit vs Val (MAc) = 0.903 vs 0.949
#  > > 32	mean 	 Fit vs Val (MAc) = 0.926 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.925 vs 0.963
#  > > 32	mean 	 Fit vs Val (MAc) = 0.931 vs 0.924
#  > > 32	mean 	 Fit vs Val (MAc) = 0.924 vs 0.990
#  > > 32	mean 	 Fit vs Val (MAc) = 0.928 vs 0.948
#  > > 32	mean 	 Fit vs Val (MAc) = 0.919 vs 0.932
#  > > BEST-TH: 0.330 (0.001)
#  > > Test Acc: 0.894
# > ('32', 'max')
#  > > 32	max 	 Fit vs Val (MAc) = 0.898 vs 0.996
#  > > 32	max 	 Fit vs Val (MAc) = 0.902 vs 0.979
#  > > 32	max 	 Fit vs Val (MAc) = 0.916 vs 0.882
#  > > 32	max 	 Fit vs Val (MAc) = 0.899 vs 0.950
#  > > 32	max 	 Fit vs Val (MAc) = 0.905 vs 0.957
#  > > 32	max 	 Fit vs Val (MAc) = 0.901 vs 0.975
#  > > 32	max 	 Fit vs Val (MAc) = 0.901 vs 0.971
#  > > 32	max 	 Fit vs Val (MAc) = 0.883 vs 0.942
#  > > 32	max 	 Fit vs Val (MAc) = 0.905 vs 0.952
#  > > 32	max 	 Fit vs Val (MAc) = 0.901 vs 0.980
#  > > 32	max 	 Fit vs Val (MAc) = 0.863 vs 0.865
#  > > 32	max 	 Fit vs Val (MAc) = 0.899 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.899 vs 0.991
#  > > 32	max 	 Fit vs Val (MAc) = 0.908 vs 0.860
#  > > 32	max 	 Fit vs Val (MAc) = 0.899 vs 0.980
#  > > 32	max 	 Fit vs Val (MAc) = 0.907 vs 0.841
#  > > 32	max 	 Fit vs Val (MAc) = 0.887 vs 0.937
#  > > BEST-TH: 0.569 (0.015)
#  > > Test Acc: 0.778
# > ('32', 'min')
#  > > 32	min 	 Fit vs Val (MAc) = 0.732 vs 0.868
#  > > 32	min 	 Fit vs Val (MAc) = 0.734 vs 0.874
#  > > 32	min 	 Fit vs Val (MAc) = 0.743 vs 0.647
#  > > 32	min 	 Fit vs Val (MAc) = 0.728 vs 0.856
#  > > 32	min 	 Fit vs Val (MAc) = 0.738 vs 0.789
#  > > 32	min 	 Fit vs Val (MAc) = 0.735 vs 0.765
#  > > 32	min 	 Fit vs Val (MAc) = 0.735 vs 0.832
#  > > 32	min 	 Fit vs Val (MAc) = 0.695 vs 0.807
#  > > 32	min 	 Fit vs Val (MAc) = 0.738 vs 0.708
#  > > 32	min 	 Fit vs Val (MAc) = 0.730 vs 0.912
#  > > 32	min 	 Fit vs Val (MAc) = 0.813 vs 0.466
#  > > 32	min 	 Fit vs Val (MAc) = 0.733 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.733 vs 0.853
#  > > 32	min 	 Fit vs Val (MAc) = 0.734 vs 0.876
#  > > 32	min 	 Fit vs Val (MAc) = 0.730 vs 0.938
#  > > 32	min 	 Fit vs Val (MAc) = 0.732 vs 0.945
#  > > 32	min 	 Fit vs Val (MAc) = 0.698 vs 0.867
#  > > BEST-TH: 0.116 (0.002)
#  > > Test Acc: 0.682
# > ('32', 'std')
#  > > 32	std 	 Fit vs Val (MAc) = 0.866 vs 0.998
#  > > 32	std 	 Fit vs Val (MAc) = 0.870 vs 0.975
#  > > 32	std 	 Fit vs Val (MAc) = 0.887 vs 0.875
#  > > 32	std 	 Fit vs Val (MAc) = 0.871 vs 0.919
#  > > 32	std 	 Fit vs Val (MAc) = 0.873 vs 0.958
#  > > 32	std 	 Fit vs Val (MAc) = 0.870 vs 0.968
#  > > 32	std 	 Fit vs Val (MAc) = 0.869 vs 0.968
#  > > 32	std 	 Fit vs Val (MAc) = 0.847 vs 0.925
#  > > 32	std 	 Fit vs Val (MAc) = 0.873 vs 0.953
#  > > 32	std 	 Fit vs Val (MAc) = 0.869 vs 0.967
#  > > 32	std 	 Fit vs Val (MAc) = 0.826 vs 0.823
#  > > 32	std 	 Fit vs Val (MAc) = 0.868 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.867 vs 0.989
#  > > 32	std 	 Fit vs Val (MAc) = 0.878 vs 0.839
#  > > 32	std 	 Fit vs Val (MAc) = 0.868 vs 0.938
#  > > 32	std 	 Fit vs Val (MAc) = 0.878 vs 0.669
#  > > 32	std 	 Fit vs Val (MAc) = 0.853 vs 0.932
#  > > BEST-TH: 0.074 (0.004)
#  > > Test Acc: 0.674
# > ('64', 'mean')
#  > > 64	mean 	 Fit vs Val (MAc) = 0.885 vs 0.940
#  > > 64	mean 	 Fit vs Val (MAc) = 0.887 vs 0.940
#  > > 64	mean 	 Fit vs Val (MAc) = 0.898 vs 0.784
#  > > 64	mean 	 Fit vs Val (MAc) = 0.885 vs 0.916
#  > > 64	mean 	 Fit vs Val (MAc) = 0.890 vs 0.893
#  > > 64	mean 	 Fit vs Val (MAc) = 0.887 vs 0.906
#  > > 64	mean 	 Fit vs Val (MAc) = 0.888 vs 0.880
#  > > 64	mean 	 Fit vs Val (MAc) = 0.875 vs 0.847
#  > > 64	mean 	 Fit vs Val (MAc) = 0.889 vs 0.857
#  > > 64	mean 	 Fit vs Val (MAc) = 0.886 vs 0.935
#  > > 64	mean 	 Fit vs Val (MAc) = 0.877 vs 0.848
#  > > 64	mean 	 Fit vs Val (MAc) = 0.886 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.886 vs 0.900
#  > > 64	mean 	 Fit vs Val (MAc) = 0.891 vs 0.875
#  > > 64	mean 	 Fit vs Val (MAc) = 0.884 vs 0.948
#  > > 64	mean 	 Fit vs Val (MAc) = 0.888 vs 0.913
#  > > 64	mean 	 Fit vs Val (MAc) = 0.877 vs 0.898
#  > > BEST-TH: 0.320 (0.005)
#  > > Test Acc: 0.873
# > ('64', 'max')
#  > > 64	max 	 Fit vs Val (MAc) = 0.896 vs 0.987
#  > > 64	max 	 Fit vs Val (MAc) = 0.899 vs 0.972
#  > > 64	max 	 Fit vs Val (MAc) = 0.914 vs 0.864
#  > > 64	max 	 Fit vs Val (MAc) = 0.897 vs 0.940
#  > > 64	max 	 Fit vs Val (MAc) = 0.902 vs 0.950
#  > > 64	max 	 Fit vs Val (MAc) = 0.898 vs 0.957
#  > > 64	max 	 Fit vs Val (MAc) = 0.899 vs 0.950
#  > > 64	max 	 Fit vs Val (MAc) = 0.880 vs 0.938
#  > > 64	max 	 Fit vs Val (MAc) = 0.901 vs 0.944
#  > > 64	max 	 Fit vs Val (MAc) = 0.898 vs 0.968
#  > > 64	max 	 Fit vs Val (MAc) = 0.865 vs 0.921
#  > > 64	max 	 Fit vs Val (MAc) = 0.897 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.897 vs 0.966
#  > > 64	max 	 Fit vs Val (MAc) = 0.903 vs 0.902
#  > > 64	max 	 Fit vs Val (MAc) = 0.896 vs 0.969
#  > > 64	max 	 Fit vs Val (MAc) = 0.901 vs 0.910
#  > > 64	max 	 Fit vs Val (MAc) = 0.885 vs 0.936
#  > > BEST-TH: 0.438 (0.004)
#  > > Test Acc: 0.862
# > ('64', 'min')
#  > > 64	min 	 Fit vs Val (MAc) = 0.741 vs 0.829
#  > > 64	min 	 Fit vs Val (MAc) = 0.743 vs 0.818
#  > > 64	min 	 Fit vs Val (MAc) = 0.750 vs 0.644
#  > > 64	min 	 Fit vs Val (MAc) = 0.732 vs 0.876
#  > > 64	min 	 Fit vs Val (MAc) = 0.745 vs 0.755
#  > > 64	min 	 Fit vs Val (MAc) = 0.742 vs 0.753
#  > > 64	min 	 Fit vs Val (MAc) = 0.742 vs 0.811
#  > > 64	min 	 Fit vs Val (MAc) = 0.714 vs 0.702
#  > > 64	min 	 Fit vs Val (MAc) = 0.745 vs 0.690
#  > > 64	min 	 Fit vs Val (MAc) = 0.739 vs 0.902
#  > > 64	min 	 Fit vs Val (MAc) = 0.825 vs 0.464
#  > > 64	min 	 Fit vs Val (MAc) = 0.741 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.742 vs 0.810
#  > > 64	min 	 Fit vs Val (MAc) = 0.742 vs 0.852
#  > > 64	min 	 Fit vs Val (MAc) = 0.737 vs 0.928
#  > > 64	min 	 Fit vs Val (MAc) = 0.739 vs 0.925
#  > > 64	min 	 Fit vs Val (MAc) = 0.715 vs 0.776
#  > > BEST-TH: 0.174 (0.015)
#  > > Test Acc: 0.757
# > ('64', 'std')
#  > > 64	std 	 Fit vs Val (MAc) = 0.843 vs 0.971
#  > > 64	std 	 Fit vs Val (MAc) = 0.846 vs 0.955
#  > > 64	std 	 Fit vs Val (MAc) = 0.863 vs 0.856
#  > > 64	std 	 Fit vs Val (MAc) = 0.848 vs 0.870
#  > > 64	std 	 Fit vs Val (MAc) = 0.850 vs 0.935
#  > > 64	std 	 Fit vs Val (MAc) = 0.846 vs 0.947
#  > > 64	std 	 Fit vs Val (MAc) = 0.847 vs 0.906
#  > > 64	std 	 Fit vs Val (MAc) = 0.827 vs 0.911
#  > > 64	std 	 Fit vs Val (MAc) = 0.849 vs 0.940
#  > > 64	std 	 Fit vs Val (MAc) = 0.848 vs 0.897
#  > > 64	std 	 Fit vs Val (MAc) = 0.813 vs 0.842
#  > > 64	std 	 Fit vs Val (MAc) = 0.846 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.845 vs 0.943
#  > > 64	std 	 Fit vs Val (MAc) = 0.854 vs 0.781
#  > > 64	std 	 Fit vs Val (MAc) = 0.847 vs 0.850
#  > > 64	std 	 Fit vs Val (MAc) = 0.855 vs 0.707
#  > > 64	std 	 Fit vs Val (MAc) = 0.833 vs 0.878
#  > > BEST-TH: 0.057 (0.001)
#  > > Test Acc: 0.674
# > ('128', 'mean')
#  > > 128	mean 	 Fit vs Val (MAc) = 0.843 vs 0.874
#  > > 128	mean 	 Fit vs Val (MAc) = 0.845 vs 0.866
#  > > 128	mean 	 Fit vs Val (MAc) = 0.856 vs 0.717
#  > > 128	mean 	 Fit vs Val (MAc) = 0.842 vs 0.873
#  > > 128	mean 	 Fit vs Val (MAc) = 0.848 vs 0.825
#  > > 128	mean 	 Fit vs Val (MAc) = 0.845 vs 0.833
#  > > 128	mean 	 Fit vs Val (MAc) = 0.846 vs 0.811
#  > > 128	mean 	 Fit vs Val (MAc) = 0.830 vs 0.828
#  > > 128	mean 	 Fit vs Val (MAc) = 0.847 vs 0.787
#  > > 128	mean 	 Fit vs Val (MAc) = 0.843 vs 0.886
#  > > 128	mean 	 Fit vs Val (MAc) = 0.857 vs 0.674
#  > > 128	mean 	 Fit vs Val (MAc) = 0.844 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.844 vs 0.835
#  > > 128	mean 	 Fit vs Val (MAc) = 0.848 vs 0.826
#  > > 128	mean 	 Fit vs Val (MAc) = 0.842 vs 0.896
#  > > 128	mean 	 Fit vs Val (MAc) = 0.845 vs 0.870
#  > > 128	mean 	 Fit vs Val (MAc) = 0.832 vs 0.853
#  > > BEST-TH: 0.314 (0.010)
#  > > Test Acc: 0.842
# > ('128', 'max')
#  > > 128	max 	 Fit vs Val (MAc) = 0.869 vs 0.934
#  > > 128	max 	 Fit vs Val (MAc) = 0.871 vs 0.922
#  > > 128	max 	 Fit vs Val (MAc) = 0.884 vs 0.809
#  > > 128	max 	 Fit vs Val (MAc) = 0.869 vs 0.906
#  > > 128	max 	 Fit vs Val (MAc) = 0.874 vs 0.896
#  > > 128	max 	 Fit vs Val (MAc) = 0.871 vs 0.902
#  > > 128	max 	 Fit vs Val (MAc) = 0.872 vs 0.882
#  > > 128	max 	 Fit vs Val (MAc) = 0.854 vs 0.894
#  > > 128	max 	 Fit vs Val (MAc) = 0.873 vs 0.878
#  > > 128	max 	 Fit vs Val (MAc) = 0.870 vs 0.920
#  > > 128	max 	 Fit vs Val (MAc) = 0.859 vs 0.808
#  > > 128	max 	 Fit vs Val (MAc) = 0.870 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.870 vs 0.898
#  > > 128	max 	 Fit vs Val (MAc) = 0.875 vs 0.860
#  > > 128	max 	 Fit vs Val (MAc) = 0.869 vs 0.923
#  > > 128	max 	 Fit vs Val (MAc) = 0.873 vs 0.883
#  > > 128	max 	 Fit vs Val (MAc) = 0.858 vs 0.899
#  > > BEST-TH: 0.376 (0.007)
#  > > Test Acc: 0.854
# > ('128', 'min')
#  > > 128	min 	 Fit vs Val (MAc) = 0.771 vs 0.756
#  > > 128	min 	 Fit vs Val (MAc) = 0.773 vs 0.750
#  > > 128	min 	 Fit vs Val (MAc) = 0.782 vs 0.567
#  > > 128	min 	 Fit vs Val (MAc) = 0.767 vs 0.813
#  > > 128	min 	 Fit vs Val (MAc) = 0.776 vs 0.674
#  > > 128	min 	 Fit vs Val (MAc) = 0.774 vs 0.692
#  > > 128	min 	 Fit vs Val (MAc) = 0.774 vs 0.695
#  > > 128	min 	 Fit vs Val (MAc) = 0.756 vs 0.724
#  > > 128	min 	 Fit vs Val (MAc) = 0.777 vs 0.612
#  > > 128	min 	 Fit vs Val (MAc) = 0.770 vs 0.829
#  > > 128	min 	 Fit vs Val (MAc) = 0.834 vs 0.500
#  > > 128	min 	 Fit vs Val (MAc) = 0.772 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.773 vs 0.721
#  > > 128	min 	 Fit vs Val (MAc) = 0.774 vs 0.753
#  > > 128	min 	 Fit vs Val (MAc) = 0.768 vs 0.849
#  > > 128	min 	 Fit vs Val (MAc) = 0.770 vs 0.853
#  > > 128	min 	 Fit vs Val (MAc) = 0.757 vs 0.775
#  > > BEST-TH: 0.252 (0.013)
#  > > Test Acc: 0.786
# > ('128', 'std')
#  > > 128	std 	 Fit vs Val (MAc) = 0.801 vs 0.901
#  > > 128	std 	 Fit vs Val (MAc) = 0.804 vs 0.891
#  > > 128	std 	 Fit vs Val (MAc) = 0.818 vs 0.815
#  > > 128	std 	 Fit vs Val (MAc) = 0.805 vs 0.814
#  > > 128	std 	 Fit vs Val (MAc) = 0.806 vs 0.880
#  > > 128	std 	 Fit vs Val (MAc) = 0.803 vs 0.892
#  > > 128	std 	 Fit vs Val (MAc) = 0.805 vs 0.844
#  > > 128	std 	 Fit vs Val (MAc) = 0.785 vs 0.866
#  > > 128	std 	 Fit vs Val (MAc) = 0.806 vs 0.885
#  > > 128	std 	 Fit vs Val (MAc) = 0.805 vs 0.832
#  > > 128	std 	 Fit vs Val (MAc) = 0.784 vs 0.778
#  > > 128	std 	 Fit vs Val (MAc) = 0.803 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.803 vs 0.859
#  > > 128	std 	 Fit vs Val (MAc) = 0.811 vs 0.736
#  > > 128	std 	 Fit vs Val (MAc) = 0.805 vs 0.774
#  > > 128	std 	 Fit vs Val (MAc) = 0.811 vs 0.670
#  > > 128	std 	 Fit vs Val (MAc) = 0.790 vs 0.836
#  > > BEST-TH: 0.035 (0.001)
#  > > Test Acc: 0.681
# > ('512', 'ori')
#  > > 512	ori 	 Fit vs Val (MAc) = 0.811 vs 0.831
#  > > 512	ori 	 Fit vs Val (MAc) = 0.813 vs 0.823
#  > > 512	ori 	 Fit vs Val (MAc) = 0.824 vs 0.676
#  > > 512	ori 	 Fit vs Val (MAc) = 0.809 vs 0.844
#  > > 512	ori 	 Fit vs Val (MAc) = 0.816 vs 0.772
#  > > 512	ori 	 Fit vs Val (MAc) = 0.813 vs 0.789
#  > > 512	ori 	 Fit vs Val (MAc) = 0.814 vs 0.776
#  > > 512	ori 	 Fit vs Val (MAc) = 0.795 vs 0.807
#  > > 512	ori 	 Fit vs Val (MAc) = 0.816 vs 0.739
#  > > 512	ori 	 Fit vs Val (MAc) = 0.811 vs 0.858
#  > > 512	ori 	 Fit vs Val (MAc) = 0.840 vs 0.581
#  > > 512	ori 	 Fit vs Val (MAc) = 0.812 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.812 vs 0.799
#  > > 512	ori 	 Fit vs Val (MAc) = 0.815 vs 0.791
#  > > 512	ori 	 Fit vs Val (MAc) = 0.809 vs 0.862
#  > > 512	ori 	 Fit vs Val (MAc) = 0.812 vs 0.842
#  > > 512	ori 	 Fit vs Val (MAc) = 0.798 vs 0.828
#  > > BEST-TH: 0.306 (0.012)
#  > > Test Acc: 0.819
# Experiment [1] [0]
# > ('8', 'mean')
#  > > 8	mean 	 Fit vs Val (MAc) = 0.886 vs 1.000
#  > > 8	mean 	 Fit vs Val (MAc) = 0.890 vs 0.978
#  > > 8	mean 	 Fit vs Val (MAc) = 0.893 vs 0.711
#  > > 8	mean 	 Fit vs Val (MAc) = 0.888 vs 0.942
#  > > 8	mean 	 Fit vs Val (MAc) = 0.891 vs 0.944
#  > > 8	mean 	 Fit vs Val (MAc) = 0.888 vs 0.924
#  > > 8	mean 	 Fit vs Val (MAc) = 0.889 vs 0.908
#  > > 8	mean 	 Fit vs Val (MAc) = 0.884 vs 0.742
#  > > 8	mean 	 Fit vs Val (MAc) = 0.889 vs 0.886
#  > > 8	mean 	 Fit vs Val (MAc) = 0.888 vs 0.981
#  > > 8	mean 	 Fit vs Val (MAc) = 0.866 vs 0.857
#  > > 8	mean 	 Fit vs Val (MAc) = 0.889 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.886 vs 0.997
#  > > 8	mean 	 Fit vs Val (MAc) = 0.895 vs 0.829
#  > > 8	mean 	 Fit vs Val (MAc) = 0.886 vs 1.000
#  > > 8	mean 	 Fit vs Val (MAc) = 0.891 vs 0.949
#  > > 8	mean 	 Fit vs Val (MAc) = 0.883 vs 0.864
#  > > 8	mean 	 Fit vs Val (MAc) = 0.889 vs 0.966
#  > > 8	mean 	 Fit vs Val (MAc) = 0.898 vs 0.696
#  > > 8	mean 	 Fit vs Val (MAc) = 0.901 vs 0.850
#  > > BEST-TH: 0.374 (0.001)
#  > > Test Acc: 0.920
# > ('8', 'max')
#  > > 8	max 	 Fit vs Val (MAc) = 0.842 vs 1.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.845 vs 0.978
#  > > 8	max 	 Fit vs Val (MAc) = 0.861 vs 0.874
#  > > 8	max 	 Fit vs Val (MAc) = 0.848 vs 0.922
#  > > 8	max 	 Fit vs Val (MAc) = 0.849 vs 0.956
#  > > 8	max 	 Fit vs Val (MAc) = 0.849 vs 0.949
#  > > 8	max 	 Fit vs Val (MAc) = 0.844 vs 0.983
#  > > 8	max 	 Fit vs Val (MAc) = 0.826 vs 0.976
#  > > 8	max 	 Fit vs Val (MAc) = 0.849 vs 0.952
#  > > 8	max 	 Fit vs Val (MAc) = 0.844 vs 0.984
#  > > 8	max 	 Fit vs Val (MAc) = 0.800 vs 0.885
#  > > 8	max 	 Fit vs Val (MAc) = 0.844 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.842 vs 0.997
#  > > 8	max 	 Fit vs Val (MAc) = 0.850 vs 0.896
#  > > 8	max 	 Fit vs Val (MAc) = 0.842 vs 1.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.848 vs 0.884
#  > > 8	max 	 Fit vs Val (MAc) = 0.829 vs 0.952
#  > > 8	max 	 Fit vs Val (MAc) = 0.848 vs 0.962
#  > > 8	max 	 Fit vs Val (MAc) = 0.856 vs 0.486
#  > > 8	max 	 Fit vs Val (MAc) = 0.852 vs 0.421
#  > > BEST-TH: 0.937 (0.011)
#  > > Test Acc: 0.949
# > ('8', 'min')
#  > > 8	min 	 Fit vs Val (MAc) = 0.705 vs 0.812
#  > > 8	min 	 Fit vs Val (MAc) = 0.706 vs 0.853
#  > > 8	min 	 Fit vs Val (MAc) = 0.722 vs 0.454
#  > > 8	min 	 Fit vs Val (MAc) = 0.703 vs 0.758
#  > > 8	min 	 Fit vs Val (MAc) = 0.714 vs 0.679
#  > > 8	min 	 Fit vs Val (MAc) = 0.709 vs 0.565
#  > > 8	min 	 Fit vs Val (MAc) = 0.710 vs 0.632
#  > > 8	min 	 Fit vs Val (MAc) = 0.688 vs 0.701
#  > > 8	min 	 Fit vs Val (MAc) = 0.715 vs 0.475
#  > > 8	min 	 Fit vs Val (MAc) = 0.706 vs 0.798
#  > > 8	min 	 Fit vs Val (MAc) = 0.760 vs 0.448
#  > > 8	min 	 Fit vs Val (MAc) = 0.708 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.707 vs 0.747
#  > > 8	min 	 Fit vs Val (MAc) = 0.709 vs 0.765
#  > > 8	min 	 Fit vs Val (MAc) = 0.700 vs 0.953
#  > > 8	min 	 Fit vs Val (MAc) = 0.703 vs 0.970
#  > > 8	min 	 Fit vs Val (MAc) = 0.690 vs 0.762
#  > > 8	min 	 Fit vs Val (MAc) = 0.705 vs 0.832
#  > > 8	min 	 Fit vs Val (MAc) = 0.712 vs 0.366
#  > > 8	min 	 Fit vs Val (MAc) = 0.710 vs 0.519
#  > > BEST-TH: 0.052 (0.004)
#  > > Test Acc: 0.708
# > ('8', 'std')
#  > > 8	std 	 Fit vs Val (MAc) = 0.786 vs 1.000
#  > > 8	std 	 Fit vs Val (MAc) = 0.790 vs 0.978
#  > > 8	std 	 Fit vs Val (MAc) = 0.802 vs 0.873
#  > > 8	std 	 Fit vs Val (MAc) = 0.792 vs 0.918
#  > > 8	std 	 Fit vs Val (MAc) = 0.793 vs 0.956
#  > > 8	std 	 Fit vs Val (MAc) = 0.795 vs 0.940
#  > > 8	std 	 Fit vs Val (MAc) = 0.789 vs 0.983
#  > > 8	std 	 Fit vs Val (MAc) = 0.776 vs 0.746
#  > > 8	std 	 Fit vs Val (MAc) = 0.794 vs 0.952
#  > > 8	std 	 Fit vs Val (MAc) = 0.789 vs 0.984
#  > > 8	std 	 Fit vs Val (MAc) = 0.756 vs 0.764
#  > > 8	std 	 Fit vs Val (MAc) = 0.791 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.787 vs 0.997
#  > > 8	std 	 Fit vs Val (MAc) = 0.804 vs 0.393
#  > > 8	std 	 Fit vs Val (MAc) = 0.789 vs 0.875
#  > > 8	std 	 Fit vs Val (MAc) = 0.807 vs 0.314
#  > > 8	std 	 Fit vs Val (MAc) = 0.777 vs 0.736
#  > > 8	std 	 Fit vs Val (MAc) = 0.792 vs 0.962
#  > > 8	std 	 Fit vs Val (MAc) = 0.818 vs 0.206
#  > > 8	std 	 Fit vs Val (MAc) = 0.817 vs 0.567
#  > > BEST-TH: 0.108 (0.008)
#  > > Test Acc: 0.949
# > ('16', 'mean')
#  > > 16	mean 	 Fit vs Val (MAc) = 0.899 vs 1.000
#  > > 16	mean 	 Fit vs Val (MAc) = 0.902 vs 0.980
#  > > 16	mean 	 Fit vs Val (MAc) = 0.906 vs 0.824
#  > > 16	mean 	 Fit vs Val (MAc) = 0.899 vs 0.953
#  > > 16	mean 	 Fit vs Val (MAc) = 0.904 vs 0.957
#  > > 16	mean 	 Fit vs Val (MAc) = 0.900 vs 0.974
#  > > 16	mean 	 Fit vs Val (MAc) = 0.902 vs 0.945
#  > > 16	mean 	 Fit vs Val (MAc) = 0.892 vs 0.828
#  > > 16	mean 	 Fit vs Val (MAc) = 0.902 vs 0.919
#  > > 16	mean 	 Fit vs Val (MAc) = 0.901 vs 0.988
#  > > 16	mean 	 Fit vs Val (MAc) = 0.875 vs 0.893
#  > > 16	mean 	 Fit vs Val (MAc) = 0.901 vs nan
#  > > 16	mean 	 Fit vs Val (MAc) = 0.900 vs 0.982
#  > > 16	mean 	 Fit vs Val (MAc) = 0.906 vs 0.892
#  > > 16	mean 	 Fit vs Val (MAc) = 0.899 vs 1.000
#  > > 16	mean 	 Fit vs Val (MAc) = 0.902 vs 0.960
#  > > 16	mean 	 Fit vs Val (MAc) = 0.894 vs 0.902
#  > > 16	mean 	 Fit vs Val (MAc) = 0.902 vs 0.967
#  > > 16	mean 	 Fit vs Val (MAc) = 0.912 vs 0.849
#  > > 16	mean 	 Fit vs Val (MAc) = 0.915 vs 0.868
#  > > BEST-TH: 0.353 (0.003)
#  > > Test Acc: 0.943
# > ('16', 'max')
#  > > 16	max 	 Fit vs Val (MAc) = 0.854 vs 1.000
#  > > 16	max 	 Fit vs Val (MAc) = 0.857 vs 0.980
#  > > 16	max 	 Fit vs Val (MAc) = 0.870 vs 0.884
#  > > 16	max 	 Fit vs Val (MAc) = 0.856 vs 0.931
#  > > 16	max 	 Fit vs Val (MAc) = 0.862 vs 0.956
#  > > 16	max 	 Fit vs Val (MAc) = 0.858 vs 0.966
#  > > 16	max 	 Fit vs Val (MAc) = 0.857 vs 0.969
#  > > 16	max 	 Fit vs Val (MAc) = 0.843 vs 0.972
#  > > 16	max 	 Fit vs Val (MAc) = 0.860 vs 0.955
#  > > 16	max 	 Fit vs Val (MAc) = 0.857 vs 0.977
#  > > 16	max 	 Fit vs Val (MAc) = 0.824 vs 0.834
#  > > 16	max 	 Fit vs Val (MAc) = 0.858 vs nan
#  > > 16	max 	 Fit vs Val (MAc) = 0.855 vs 0.993
#  > > 16	max 	 Fit vs Val (MAc) = 0.864 vs 0.841
#  > > 16	max 	 Fit vs Val (MAc) = 0.855 vs 0.977
#  > > 16	max 	 Fit vs Val (MAc) = 0.865 vs 0.783
#  > > 16	max 	 Fit vs Val (MAc) = 0.846 vs 0.945
#  > > 16	max 	 Fit vs Val (MAc) = 0.860 vs 0.964
#  > > 16	max 	 Fit vs Val (MAc) = 0.870 vs 0.430
#  > > 16	max 	 Fit vs Val (MAc) = 0.867 vs 0.495
#  > > BEST-TH: 0.792 (0.018)
#  > > Test Acc: 0.944
# > ('16', 'min')
#  > > 16	min 	 Fit vs Val (MAc) = 0.720 vs 0.855
#  > > 16	min 	 Fit vs Val (MAc) = 0.722 vs 0.880
#  > > 16	min 	 Fit vs Val (MAc) = 0.734 vs 0.608
#  > > 16	min 	 Fit vs Val (MAc) = 0.721 vs 0.804
#  > > 16	min 	 Fit vs Val (MAc) = 0.726 vs 0.786
#  > > 16	min 	 Fit vs Val (MAc) = 0.724 vs 0.719
#  > > 16	min 	 Fit vs Val (MAc) = 0.723 vs 0.814
#  > > 16	min 	 Fit vs Val (MAc) = 0.693 vs 0.787
#  > > 16	min 	 Fit vs Val (MAc) = 0.727 vs 0.647
#  > > 16	min 	 Fit vs Val (MAc) = 0.721 vs 0.873
#  > > 16	min 	 Fit vs Val (MAc) = 0.776 vs 0.486
#  > > 16	min 	 Fit vs Val (MAc) = 0.722 vs nan
#  > > 16	min 	 Fit vs Val (MAc) = 0.722 vs 0.825
#  > > 16	min 	 Fit vs Val (MAc) = 0.723 vs 0.857
#  > > 16	min 	 Fit vs Val (MAc) = 0.718 vs 0.934
#  > > 16	min 	 Fit vs Val (MAc) = 0.720 vs 0.943
#  > > 16	min 	 Fit vs Val (MAc) = 0.695 vs 0.871
#  > > 16	min 	 Fit vs Val (MAc) = 0.723 vs 0.800
#  > > 16	min 	 Fit vs Val (MAc) = 0.721 vs 0.562
#  > > 16	min 	 Fit vs Val (MAc) = 0.723 vs 0.708
#  > > BEST-TH: 0.079 (0.001)
#  > > Test Acc: 0.797
# > ('16', 'std')
#  > > 16	std 	 Fit vs Val (MAc) = 0.801 vs 1.000
#  > > 16	std 	 Fit vs Val (MAc) = 0.804 vs 0.978
#  > > 16	std 	 Fit vs Val (MAc) = 0.817 vs 0.875
#  > > 16	std 	 Fit vs Val (MAc) = 0.801 vs 0.938
#  > > 16	std 	 Fit vs Val (MAc) = 0.807 vs 0.959
#  > > 16	std 	 Fit vs Val (MAc) = 0.805 vs 0.960
#  > > 16	std 	 Fit vs Val (MAc) = 0.804 vs 0.971
#  > > 16	std 	 Fit vs Val (MAc) = 0.789 vs 0.767
#  > > 16	std 	 Fit vs Val (MAc) = 0.808 vs 0.954
#  > > 16	std 	 Fit vs Val (MAc) = 0.804 vs 0.976
#  > > 16	std 	 Fit vs Val (MAc) = 0.774 vs 0.768
#  > > 16	std 	 Fit vs Val (MAc) = 0.805 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.801 vs 0.997
#  > > 16	std 	 Fit vs Val (MAc) = 0.814 vs 0.720
#  > > 16	std 	 Fit vs Val (MAc) = 0.803 vs 0.938
#  > > 16	std 	 Fit vs Val (MAc) = 0.816 vs 0.463
#  > > 16	std 	 Fit vs Val (MAc) = 0.791 vs 0.854
#  > > 16	std 	 Fit vs Val (MAc) = 0.807 vs 0.962
#  > > 16	std 	 Fit vs Val (MAc) = 0.832 vs 0.461
#  > > 16	std 	 Fit vs Val (MAc) = 0.830 vs 0.551
#  > > BEST-TH: 0.097 (0.008)
#  > > Test Acc: 0.949
# > ('32', 'mean')
#  > > 32	mean 	 Fit vs Val (MAc) = 0.892 vs 0.983
#  > > 32	mean 	 Fit vs Val (MAc) = 0.895 vs 0.973
#  > > 32	mean 	 Fit vs Val (MAc) = 0.901 vs 0.809
#  > > 32	mean 	 Fit vs Val (MAc) = 0.891 vs 0.948
#  > > 32	mean 	 Fit vs Val (MAc) = 0.896 vs 0.939
#  > > 32	mean 	 Fit vs Val (MAc) = 0.893 vs 0.950
#  > > 32	mean 	 Fit vs Val (MAc) = 0.895 vs 0.924
#  > > 32	mean 	 Fit vs Val (MAc) = 0.882 vs 0.886
#  > > 32	mean 	 Fit vs Val (MAc) = 0.895 vs 0.907
#  > > 32	mean 	 Fit vs Val (MAc) = 0.893 vs 0.971
#  > > 32	mean 	 Fit vs Val (MAc) = 0.865 vs 0.928
#  > > 32	mean 	 Fit vs Val (MAc) = 0.894 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.894 vs 0.946
#  > > 32	mean 	 Fit vs Val (MAc) = 0.898 vs 0.903
#  > > 32	mean 	 Fit vs Val (MAc) = 0.892 vs 0.983
#  > > 32	mean 	 Fit vs Val (MAc) = 0.895 vs 0.936
#  > > 32	mean 	 Fit vs Val (MAc) = 0.885 vs 0.921
#  > > 32	mean 	 Fit vs Val (MAc) = 0.895 vs 0.943
#  > > 32	mean 	 Fit vs Val (MAc) = 0.903 vs 0.867
#  > > 32	mean 	 Fit vs Val (MAc) = 0.911 vs 0.864
#  > > BEST-TH: 0.339 (0.003)
#  > > Test Acc: 0.942
# > ('32', 'max')
#  > > 32	max 	 Fit vs Val (MAc) = 0.863 vs 0.995
#  > > 32	max 	 Fit vs Val (MAc) = 0.866 vs 0.974
#  > > 32	max 	 Fit vs Val (MAc) = 0.876 vs 0.875
#  > > 32	max 	 Fit vs Val (MAc) = 0.862 vs 0.946
#  > > 32	max 	 Fit vs Val (MAc) = 0.868 vs 0.958
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.973
#  > > 32	max 	 Fit vs Val (MAc) = 0.866 vs 0.958
#  > > 32	max 	 Fit vs Val (MAc) = 0.850 vs 0.918
#  > > 32	max 	 Fit vs Val (MAc) = 0.868 vs 0.945
#  > > 32	max 	 Fit vs Val (MAc) = 0.866 vs 0.969
#  > > 32	max 	 Fit vs Val (MAc) = 0.833 vs 0.860
#  > > 32	max 	 Fit vs Val (MAc) = 0.865 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.980
#  > > 32	max 	 Fit vs Val (MAc) = 0.872 vs 0.846
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.959
#  > > 32	max 	 Fit vs Val (MAc) = 0.872 vs 0.822
#  > > 32	max 	 Fit vs Val (MAc) = 0.853 vs 0.912
#  > > 32	max 	 Fit vs Val (MAc) = 0.867 vs 0.963
#  > > 32	max 	 Fit vs Val (MAc) = 0.880 vs 0.671
#  > > 32	max 	 Fit vs Val (MAc) = 0.877 vs 0.721
#  > > BEST-TH: 0.602 (0.010)
#  > > Test Acc: 0.936
# > ('32', 'min')
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs 0.868
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.875
#  > > 32	min 	 Fit vs Val (MAc) = 0.732 vs 0.647
#  > > 32	min 	 Fit vs Val (MAc) = 0.720 vs 0.864
#  > > 32	min 	 Fit vs Val (MAc) = 0.728 vs 0.789
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.765
#  > > 32	min 	 Fit vs Val (MAc) = 0.726 vs 0.836
#  > > 32	min 	 Fit vs Val (MAc) = 0.694 vs 0.807
#  > > 32	min 	 Fit vs Val (MAc) = 0.728 vs 0.712
#  > > 32	min 	 Fit vs Val (MAc) = 0.722 vs 0.912
#  > > 32	min 	 Fit vs Val (MAc) = 0.785 vs 0.457
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.853
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.876
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs 0.938
#  > > 32	min 	 Fit vs Val (MAc) = 0.723 vs 0.945
#  > > 32	min 	 Fit vs Val (MAc) = 0.696 vs 0.867
#  > > 32	min 	 Fit vs Val (MAc) = 0.728 vs 0.776
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.678
#  > > 32	min 	 Fit vs Val (MAc) = 0.730 vs 0.761
#  > > BEST-TH: 0.116 (0.004)
#  > > Test Acc: 0.814
# > ('32', 'std')
#  > > 32	std 	 Fit vs Val (MAc) = 0.810 vs 0.998
#  > > 32	std 	 Fit vs Val (MAc) = 0.813 vs 0.975
#  > > 32	std 	 Fit vs Val (MAc) = 0.826 vs 0.870
#  > > 32	std 	 Fit vs Val (MAc) = 0.811 vs 0.919
#  > > 32	std 	 Fit vs Val (MAc) = 0.815 vs 0.958
#  > > 32	std 	 Fit vs Val (MAc) = 0.812 vs 0.968
#  > > 32	std 	 Fit vs Val (MAc) = 0.813 vs 0.968
#  > > 32	std 	 Fit vs Val (MAc) = 0.787 vs 0.957
#  > > 32	std 	 Fit vs Val (MAc) = 0.816 vs 0.953
#  > > 32	std 	 Fit vs Val (MAc) = 0.813 vs 0.967
#  > > 32	std 	 Fit vs Val (MAc) = 0.764 vs 0.810
#  > > 32	std 	 Fit vs Val (MAc) = 0.812 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.811 vs 0.989
#  > > 32	std 	 Fit vs Val (MAc) = 0.819 vs 0.839
#  > > 32	std 	 Fit vs Val (MAc) = 0.812 vs 0.938
#  > > 32	std 	 Fit vs Val (MAc) = 0.819 vs 0.788
#  > > 32	std 	 Fit vs Val (MAc) = 0.792 vs 0.931
#  > > 32	std 	 Fit vs Val (MAc) = 0.814 vs 0.965
#  > > 32	std 	 Fit vs Val (MAc) = 0.836 vs 0.676
#  > > 32	std 	 Fit vs Val (MAc) = 0.836 vs 0.566
#  > > BEST-TH: 0.074 (0.004)
#  > > Test Acc: 0.932
# > ('64', 'mean')
#  > > 64	mean 	 Fit vs Val (MAc) = 0.854 vs 0.921
#  > > 64	mean 	 Fit vs Val (MAc) = 0.856 vs 0.922
#  > > 64	mean 	 Fit vs Val (MAc) = 0.864 vs 0.747
#  > > 64	mean 	 Fit vs Val (MAc) = 0.853 vs 0.906
#  > > 64	mean 	 Fit vs Val (MAc) = 0.858 vs 0.869
#  > > 64	mean 	 Fit vs Val (MAc) = 0.855 vs 0.887
#  > > 64	mean 	 Fit vs Val (MAc) = 0.858 vs 0.848
#  > > 64	mean 	 Fit vs Val (MAc) = 0.843 vs 0.848
#  > > 64	mean 	 Fit vs Val (MAc) = 0.858 vs 0.831
#  > > 64	mean 	 Fit vs Val (MAc) = 0.855 vs 0.918
#  > > 64	mean 	 Fit vs Val (MAc) = 0.831 vs 0.905
#  > > 64	mean 	 Fit vs Val (MAc) = 0.856 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.856 vs 0.870
#  > > 64	mean 	 Fit vs Val (MAc) = 0.859 vs 0.845
#  > > 64	mean 	 Fit vs Val (MAc) = 0.854 vs 0.927
#  > > 64	mean 	 Fit vs Val (MAc) = 0.857 vs 0.900
#  > > 64	mean 	 Fit vs Val (MAc) = 0.845 vs 0.884
#  > > 64	mean 	 Fit vs Val (MAc) = 0.856 vs 0.886
#  > > 64	mean 	 Fit vs Val (MAc) = 0.867 vs 0.826
#  > > 64	mean 	 Fit vs Val (MAc) = 0.871 vs 0.843
#  > > BEST-TH: 0.330 (0.002)
#  > > Test Acc: 0.878
# > ('64', 'max')
#  > > 64	max 	 Fit vs Val (MAc) = 0.856 vs 0.981
#  > > 64	max 	 Fit vs Val (MAc) = 0.859 vs 0.967
#  > > 64	max 	 Fit vs Val (MAc) = 0.869 vs 0.856
#  > > 64	max 	 Fit vs Val (MAc) = 0.855 vs 0.935
#  > > 64	max 	 Fit vs Val (MAc) = 0.861 vs 0.944
#  > > 64	max 	 Fit vs Val (MAc) = 0.857 vs 0.953
#  > > 64	max 	 Fit vs Val (MAc) = 0.859 vs 0.936
#  > > 64	max 	 Fit vs Val (MAc) = 0.838 vs 0.911
#  > > 64	max 	 Fit vs Val (MAc) = 0.860 vs 0.933
#  > > 64	max 	 Fit vs Val (MAc) = 0.858 vs 0.958
#  > > 64	max 	 Fit vs Val (MAc) = 0.819 vs 0.894
#  > > 64	max 	 Fit vs Val (MAc) = 0.857 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.857 vs 0.957
#  > > 64	max 	 Fit vs Val (MAc) = 0.862 vs 0.888
#  > > 64	max 	 Fit vs Val (MAc) = 0.857 vs 0.954
#  > > 64	max 	 Fit vs Val (MAc) = 0.861 vs 0.872
#  > > 64	max 	 Fit vs Val (MAc) = 0.842 vs 0.906
#  > > 64	max 	 Fit vs Val (MAc) = 0.859 vs 0.956
#  > > 64	max 	 Fit vs Val (MAc) = 0.874 vs 0.821
#  > > 64	max 	 Fit vs Val (MAc) = 0.874 vs 0.820
#  > > BEST-TH: 0.453 (0.011)
#  > > Test Acc: 0.935
# > ('64', 'min')
#  > > 64	min 	 Fit vs Val (MAc) = 0.729 vs 0.829
#  > > 64	min 	 Fit vs Val (MAc) = 0.731 vs 0.818
#  > > 64	min 	 Fit vs Val (MAc) = 0.737 vs 0.634
#  > > 64	min 	 Fit vs Val (MAc) = 0.722 vs 0.864
#  > > 64	min 	 Fit vs Val (MAc) = 0.733 vs 0.755
#  > > 64	min 	 Fit vs Val (MAc) = 0.730 vs 0.753
#  > > 64	min 	 Fit vs Val (MAc) = 0.730 vs 0.803
#  > > 64	min 	 Fit vs Val (MAc) = 0.708 vs 0.702
#  > > 64	min 	 Fit vs Val (MAc) = 0.733 vs 0.690
#  > > 64	min 	 Fit vs Val (MAc) = 0.728 vs 0.895
#  > > 64	min 	 Fit vs Val (MAc) = 0.789 vs 0.490
#  > > 64	min 	 Fit vs Val (MAc) = 0.730 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.730 vs 0.810
#  > > 64	min 	 Fit vs Val (MAc) = 0.730 vs 0.852
#  > > 64	min 	 Fit vs Val (MAc) = 0.726 vs 0.926
#  > > 64	min 	 Fit vs Val (MAc) = 0.728 vs 0.925
#  > > 64	min 	 Fit vs Val (MAc) = 0.708 vs 0.779
#  > > 64	min 	 Fit vs Val (MAc) = 0.731 vs 0.757
#  > > 64	min 	 Fit vs Val (MAc) = 0.732 vs 0.711
#  > > 64	min 	 Fit vs Val (MAc) = 0.737 vs 0.794
#  > > BEST-TH: 0.174 (0.012)
#  > > Test Acc: 0.804
# > ('64', 'std')
#  > > 64	std 	 Fit vs Val (MAc) = 0.795 vs 0.971
#  > > 64	std 	 Fit vs Val (MAc) = 0.797 vs 0.955
#  > > 64	std 	 Fit vs Val (MAc) = 0.809 vs 0.856
#  > > 64	std 	 Fit vs Val (MAc) = 0.796 vs 0.885
#  > > 64	std 	 Fit vs Val (MAc) = 0.800 vs 0.935
#  > > 64	std 	 Fit vs Val (MAc) = 0.797 vs 0.947
#  > > 64	std 	 Fit vs Val (MAc) = 0.798 vs 0.914
#  > > 64	std 	 Fit vs Val (MAc) = 0.774 vs 0.911
#  > > 64	std 	 Fit vs Val (MAc) = 0.799 vs 0.940
#  > > 64	std 	 Fit vs Val (MAc) = 0.798 vs 0.906
#  > > 64	std 	 Fit vs Val (MAc) = 0.755 vs 0.842
#  > > 64	std 	 Fit vs Val (MAc) = 0.797 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.796 vs 0.943
#  > > 64	std 	 Fit vs Val (MAc) = 0.803 vs 0.790
#  > > 64	std 	 Fit vs Val (MAc) = 0.798 vs 0.858
#  > > 64	std 	 Fit vs Val (MAc) = 0.804 vs 0.713
#  > > 64	std 	 Fit vs Val (MAc) = 0.779 vs 0.881
#  > > 64	std 	 Fit vs Val (MAc) = 0.798 vs 0.950
#  > > 64	std 	 Fit vs Val (MAc) = 0.819 vs 0.689
#  > > 64	std 	 Fit vs Val (MAc) = 0.818 vs 0.598
#  > > BEST-TH: 0.055 (0.001)
#  > > Test Acc: 0.895
# > ('128', 'mean')
#  > > 128	mean 	 Fit vs Val (MAc) = 0.813 vs 0.872
#  > > 128	mean 	 Fit vs Val (MAc) = 0.815 vs 0.865
#  > > 128	mean 	 Fit vs Val (MAc) = 0.823 vs 0.715
#  > > 128	mean 	 Fit vs Val (MAc) = 0.811 vs 0.861
#  > > 128	mean 	 Fit vs Val (MAc) = 0.817 vs 0.823
#  > > 128	mean 	 Fit vs Val (MAc) = 0.815 vs 0.832
#  > > 128	mean 	 Fit vs Val (MAc) = 0.816 vs 0.811
#  > > 128	mean 	 Fit vs Val (MAc) = 0.799 vs 0.819
#  > > 128	mean 	 Fit vs Val (MAc) = 0.817 vs 0.785
#  > > 128	mean 	 Fit vs Val (MAc) = 0.814 vs 0.884
#  > > 128	mean 	 Fit vs Val (MAc) = 0.804 vs 0.755
#  > > 128	mean 	 Fit vs Val (MAc) = 0.814 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.815 vs 0.832
#  > > 128	mean 	 Fit vs Val (MAc) = 0.817 vs 0.823
#  > > 128	mean 	 Fit vs Val (MAc) = 0.813 vs 0.894
#  > > 128	mean 	 Fit vs Val (MAc) = 0.815 vs 0.868
#  > > 128	mean 	 Fit vs Val (MAc) = 0.801 vs 0.845
#  > > 128	mean 	 Fit vs Val (MAc) = 0.815 vs 0.830
#  > > 128	mean 	 Fit vs Val (MAc) = 0.826 vs 0.784
#  > > 128	mean 	 Fit vs Val (MAc) = 0.828 vs 0.818
#  > > BEST-TH: 0.315 (0.006)
#  > > Test Acc: 0.839
# > ('128', 'max')
#  > > 128	max 	 Fit vs Val (MAc) = 0.832 vs 0.927
#  > > 128	max 	 Fit vs Val (MAc) = 0.834 vs 0.916
#  > > 128	max 	 Fit vs Val (MAc) = 0.842 vs 0.800
#  > > 128	max 	 Fit vs Val (MAc) = 0.829 vs 0.902
#  > > 128	max 	 Fit vs Val (MAc) = 0.836 vs 0.890
#  > > 128	max 	 Fit vs Val (MAc) = 0.833 vs 0.898
#  > > 128	max 	 Fit vs Val (MAc) = 0.834 vs 0.875
#  > > 128	max 	 Fit vs Val (MAc) = 0.814 vs 0.877
#  > > 128	max 	 Fit vs Val (MAc) = 0.835 vs 0.873
#  > > 128	max 	 Fit vs Val (MAc) = 0.833 vs 0.917
#  > > 128	max 	 Fit vs Val (MAc) = 0.804 vs 0.870
#  > > 128	max 	 Fit vs Val (MAc) = 0.833 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.833 vs 0.892
#  > > 128	max 	 Fit vs Val (MAc) = 0.837 vs 0.853
#  > > 128	max 	 Fit vs Val (MAc) = 0.832 vs 0.918
#  > > 128	max 	 Fit vs Val (MAc) = 0.835 vs 0.877
#  > > 128	max 	 Fit vs Val (MAc) = 0.817 vs 0.888
#  > > 128	max 	 Fit vs Val (MAc) = 0.834 vs 0.899
#  > > 128	max 	 Fit vs Val (MAc) = 0.848 vs 0.811
#  > > 128	max 	 Fit vs Val (MAc) = 0.849 vs 0.815
#  > > BEST-TH: 0.380 (0.003)
#  > > Test Acc: 0.889
# > ('128', 'min')
#  > > 128	min 	 Fit vs Val (MAc) = 0.753 vs 0.754
#  > > 128	min 	 Fit vs Val (MAc) = 0.755 vs 0.744
#  > > 128	min 	 Fit vs Val (MAc) = 0.761 vs 0.565
#  > > 128	min 	 Fit vs Val (MAc) = 0.748 vs 0.813
#  > > 128	min 	 Fit vs Val (MAc) = 0.757 vs 0.673
#  > > 128	min 	 Fit vs Val (MAc) = 0.755 vs 0.692
#  > > 128	min 	 Fit vs Val (MAc) = 0.755 vs 0.695
#  > > 128	min 	 Fit vs Val (MAc) = 0.738 vs 0.720
#  > > 128	min 	 Fit vs Val (MAc) = 0.758 vs 0.612
#  > > 128	min 	 Fit vs Val (MAc) = 0.752 vs 0.817
#  > > 128	min 	 Fit vs Val (MAc) = 0.786 vs 0.519
#  > > 128	min 	 Fit vs Val (MAc) = 0.754 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.754 vs 0.721
#  > > 128	min 	 Fit vs Val (MAc) = 0.755 vs 0.751
#  > > 128	min 	 Fit vs Val (MAc) = 0.750 vs 0.836
#  > > 128	min 	 Fit vs Val (MAc) = 0.752 vs 0.837
#  > > 128	min 	 Fit vs Val (MAc) = 0.739 vs 0.773
#  > > 128	min 	 Fit vs Val (MAc) = 0.755 vs 0.692
#  > > 128	min 	 Fit vs Val (MAc) = 0.760 vs 0.689
#  > > 128	min 	 Fit vs Val (MAc) = 0.763 vs 0.790
#  > > BEST-TH: 0.252 (0.011)
#  > > Test Acc: 0.735
# > ('128', 'std')
#  > > 128	std 	 Fit vs Val (MAc) = 0.759 vs 0.901
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs 0.896
#  > > 128	std 	 Fit vs Val (MAc) = 0.771 vs 0.815
#  > > 128	std 	 Fit vs Val (MAc) = 0.760 vs 0.814
#  > > 128	std 	 Fit vs Val (MAc) = 0.763 vs 0.880
#  > > 128	std 	 Fit vs Val (MAc) = 0.760 vs 0.891
#  > > 128	std 	 Fit vs Val (MAc) = 0.762 vs 0.844
#  > > 128	std 	 Fit vs Val (MAc) = 0.740 vs 0.860
#  > > 128	std 	 Fit vs Val (MAc) = 0.762 vs 0.885
#  > > 128	std 	 Fit vs Val (MAc) = 0.763 vs 0.832
#  > > 128	std 	 Fit vs Val (MAc) = 0.730 vs 0.781
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs 0.859
#  > > 128	std 	 Fit vs Val (MAc) = 0.767 vs 0.738
#  > > 128	std 	 Fit vs Val (MAc) = 0.763 vs 0.767
#  > > 128	std 	 Fit vs Val (MAc) = 0.767 vs 0.658
#  > > 128	std 	 Fit vs Val (MAc) = 0.744 vs 0.833
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs 0.898
#  > > 128	std 	 Fit vs Val (MAc) = 0.781 vs 0.702
#  > > 128	std 	 Fit vs Val (MAc) = 0.779 vs 0.598
#  > > BEST-TH: 0.035 (0.001)
#  > > Test Acc: 0.838
# > ('512', 'ori')
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.827
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.816
#  > > 512	ori 	 Fit vs Val (MAc) = 0.792 vs 0.672
#  > > 512	ori 	 Fit vs Val (MAc) = 0.779 vs 0.840
#  > > 512	ori 	 Fit vs Val (MAc) = 0.786 vs 0.768
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.785
#  > > 512	ori 	 Fit vs Val (MAc) = 0.785 vs 0.772
#  > > 512	ori 	 Fit vs Val (MAc) = 0.765 vs 0.799
#  > > 512	ori 	 Fit vs Val (MAc) = 0.786 vs 0.735
#  > > 512	ori 	 Fit vs Val (MAc) = 0.782 vs 0.852
#  > > 512	ori 	 Fit vs Val (MAc) = 0.785 vs 0.643
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.795
#  > > 512	ori 	 Fit vs Val (MAc) = 0.786 vs 0.787
#  > > 512	ori 	 Fit vs Val (MAc) = 0.782 vs 0.858
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.838
#  > > 512	ori 	 Fit vs Val (MAc) = 0.768 vs 0.827
#  > > 512	ori 	 Fit vs Val (MAc) = 0.784 vs 0.782
#  > > 512	ori 	 Fit vs Val (MAc) = 0.795 vs 0.750
#  > > 512	ori 	 Fit vs Val (MAc) = 0.797 vs 0.798
#  > > BEST-TH: 0.308 (0.009)
#  > > Test Acc: 0.799
# Experiment [0, 1] [2]
# > ('8', 'mean')
#  > > 8	mean 	 Fit vs Val (MAc) = 0.846 vs 1.000
#  > > 8	mean 	 Fit vs Val (MAc) = 0.847 vs 0.978
#  > > 8	mean 	 Fit vs Val (MAc) = 0.849 vs 0.769
#  > > 8	mean 	 Fit vs Val (MAc) = 0.846 vs 0.942
#  > > 8	mean 	 Fit vs Val (MAc) = 0.848 vs 0.950
#  > > 8	mean 	 Fit vs Val (MAc) = 0.847 vs 0.924
#  > > 8	mean 	 Fit vs Val (MAc) = 0.847 vs 0.923
#  > > 8	mean 	 Fit vs Val (MAc) = 0.845 vs 0.773
#  > > 8	mean 	 Fit vs Val (MAc) = 0.847 vs 0.886
#  > > 8	mean 	 Fit vs Val (MAc) = 0.846 vs 0.981
#  > > 8	mean 	 Fit vs Val (MAc) = 0.839 vs 0.857
#  > > 8	mean 	 Fit vs Val (MAc) = 0.848 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.846 vs 0.997
#  > > 8	mean 	 Fit vs Val (MAc) = 0.850 vs 0.845
#  > > 8	mean 	 Fit vs Val (MAc) = 0.846 vs 1.000
#  > > 8	mean 	 Fit vs Val (MAc) = 0.848 vs 0.955
#  > > 8	mean 	 Fit vs Val (MAc) = 0.844 vs 0.899
#  > > 8	mean 	 Fit vs Val (MAc) = 0.847 vs 0.966
#  > > 8	mean 	 Fit vs Val (MAc) = 0.851 vs 0.770
#  > > 8	mean 	 Fit vs Val (MAc) = 0.851 vs 0.848
#  > > 8	mean 	 Fit vs Val (MAc) = 0.848 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.853 vs 0.753
#  > > 8	mean 	 Fit vs Val (MAc) = 0.852 vs 0.791
#  > > 8	mean 	 Fit vs Val (MAc) = 0.853 vs 0.816
#  > > 8	mean 	 Fit vs Val (MAc) = 0.851 vs 0.800
#  > > 8	mean 	 Fit vs Val (MAc) = 0.849 vs 0.876
#  > > 8	mean 	 Fit vs Val (MAc) = 0.846 vs 0.879
#  > > 8	mean 	 Fit vs Val (MAc) = 0.853 vs 0.688
#  > > 8	mean 	 Fit vs Val (MAc) = 0.837 vs 0.915
#  > > 8	mean 	 Fit vs Val (MAc) = 0.844 vs 0.860
#  > > 8	mean 	 Fit vs Val (MAc) = 0.848 vs nan
#  > > 8	mean 	 Fit vs Val (MAc) = 0.852 vs 0.842
#  > > 8	mean 	 Fit vs Val (MAc) = 0.854 vs 0.840
#  > > 8	mean 	 Fit vs Val (MAc) = 0.853 vs 0.628
#  > > 8	mean 	 Fit vs Val (MAc) = 0.847 vs 0.882
#  > > 8	mean 	 Fit vs Val (MAc) = 0.852 vs 0.819
#  > > 8	mean 	 Fit vs Val (MAc) = 0.838 vs 0.927
#  > > BEST-TH: 0.370 (0.001)
#  > > Test Acc: 0.839
# > ('8', 'max')
#  > > 8	max 	 Fit vs Val (MAc) = 0.818 vs 1.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.819 vs 0.978
#  > > 8	max 	 Fit vs Val (MAc) = 0.825 vs 0.872
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs 0.927
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs 0.956
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs 0.949
#  > > 8	max 	 Fit vs Val (MAc) = 0.819 vs 0.983
#  > > 8	max 	 Fit vs Val (MAc) = 0.813 vs 0.976
#  > > 8	max 	 Fit vs Val (MAc) = 0.821 vs 0.952
#  > > 8	max 	 Fit vs Val (MAc) = 0.819 vs 0.984
#  > > 8	max 	 Fit vs Val (MAc) = 0.805 vs 0.966
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.818 vs 0.997
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs 0.958
#  > > 8	max 	 Fit vs Val (MAc) = 0.818 vs 1.000
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs 0.955
#  > > 8	max 	 Fit vs Val (MAc) = 0.816 vs 0.932
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs 0.962
#  > > 8	max 	 Fit vs Val (MAc) = 0.825 vs 0.713
#  > > 8	max 	 Fit vs Val (MAc) = 0.823 vs 0.767
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.824 vs 0.756
#  > > 8	max 	 Fit vs Val (MAc) = 0.825 vs 0.698
#  > > 8	max 	 Fit vs Val (MAc) = 0.825 vs 0.827
#  > > 8	max 	 Fit vs Val (MAc) = 0.826 vs 0.791
#  > > 8	max 	 Fit vs Val (MAc) = 0.822 vs 0.764
#  > > 8	max 	 Fit vs Val (MAc) = 0.815 vs 0.804
#  > > 8	max 	 Fit vs Val (MAc) = 0.826 vs 0.712
#  > > 8	max 	 Fit vs Val (MAc) = 0.803 vs 0.888
#  > > 8	max 	 Fit vs Val (MAc) = 0.817 vs 0.882
#  > > 8	max 	 Fit vs Val (MAc) = 0.820 vs nan
#  > > 8	max 	 Fit vs Val (MAc) = 0.825 vs 0.739
#  > > 8	max 	 Fit vs Val (MAc) = 0.826 vs 0.743
#  > > 8	max 	 Fit vs Val (MAc) = 0.826 vs 0.681
#  > > 8	max 	 Fit vs Val (MAc) = 0.816 vs 0.881
#  > > 8	max 	 Fit vs Val (MAc) = 0.825 vs 0.842
#  > > 8	max 	 Fit vs Val (MAc) = 0.805 vs 0.903
#  > > BEST-TH: 0.776 (0.001)
#  > > Test Acc: 0.833
# > ('8', 'min')
#  > > 8	min 	 Fit vs Val (MAc) = 0.597 vs 0.766
#  > > 8	min 	 Fit vs Val (MAc) = 0.596 vs 0.823
#  > > 8	min 	 Fit vs Val (MAc) = 0.604 vs 0.454
#  > > 8	min 	 Fit vs Val (MAc) = 0.596 vs 0.735
#  > > 8	min 	 Fit vs Val (MAc) = 0.600 vs 0.654
#  > > 8	min 	 Fit vs Val (MAc) = 0.600 vs 0.565
#  > > 8	min 	 Fit vs Val (MAc) = 0.600 vs 0.632
#  > > 8	min 	 Fit vs Val (MAc) = 0.592 vs 0.701
#  > > 8	min 	 Fit vs Val (MAc) = 0.603 vs 0.475
#  > > 8	min 	 Fit vs Val (MAc) = 0.597 vs 0.754
#  > > 8	min 	 Fit vs Val (MAc) = 0.603 vs 0.598
#  > > 8	min 	 Fit vs Val (MAc) = 0.601 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.598 vs 0.700
#  > > 8	min 	 Fit vs Val (MAc) = 0.597 vs 0.765
#  > > 8	min 	 Fit vs Val (MAc) = 0.594 vs 0.891
#  > > 8	min 	 Fit vs Val (MAc) = 0.594 vs 0.939
#  > > 8	min 	 Fit vs Val (MAc) = 0.592 vs 0.762
#  > > 8	min 	 Fit vs Val (MAc) = 0.596 vs 0.816
#  > > 8	min 	 Fit vs Val (MAc) = 0.602 vs 0.366
#  > > 8	min 	 Fit vs Val (MAc) = 0.600 vs 0.519
#  > > 8	min 	 Fit vs Val (MAc) = 0.601 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.599 vs 0.600
#  > > 8	min 	 Fit vs Val (MAc) = 0.602 vs 0.476
#  > > 8	min 	 Fit vs Val (MAc) = 0.598 vs 0.726
#  > > 8	min 	 Fit vs Val (MAc) = 0.600 vs 0.362
#  > > 8	min 	 Fit vs Val (MAc) = 0.607 vs 0.355
#  > > 8	min 	 Fit vs Val (MAc) = 0.611 vs 0.504
#  > > 8	min 	 Fit vs Val (MAc) = 0.601 vs 0.393
#  > > 8	min 	 Fit vs Val (MAc) = 0.610 vs 0.475
#  > > 8	min 	 Fit vs Val (MAc) = 0.604 vs 0.369
#  > > 8	min 	 Fit vs Val (MAc) = 0.601 vs nan
#  > > 8	min 	 Fit vs Val (MAc) = 0.601 vs 0.519
#  > > 8	min 	 Fit vs Val (MAc) = 0.601 vs 0.492
#  > > 8	min 	 Fit vs Val (MAc) = 0.604 vs 0.259
#  > > 8	min 	 Fit vs Val (MAc) = 0.605 vs 0.443
#  > > 8	min 	 Fit vs Val (MAc) = 0.604 vs 0.308
#  > > 8	min 	 Fit vs Val (MAc) = 0.622 vs 0.357
#  > > BEST-TH: 0.058 (0.000)
#  > > Test Acc: 0.483
# > ('8', 'std')
#  > > 8	std 	 Fit vs Val (MAc) = 0.754 vs 1.000
#  > > 8	std 	 Fit vs Val (MAc) = 0.755 vs 0.978
#  > > 8	std 	 Fit vs Val (MAc) = 0.759 vs 0.872
#  > > 8	std 	 Fit vs Val (MAc) = 0.754 vs 0.927
#  > > 8	std 	 Fit vs Val (MAc) = 0.756 vs 0.956
#  > > 8	std 	 Fit vs Val (MAc) = 0.756 vs 0.940
#  > > 8	std 	 Fit vs Val (MAc) = 0.755 vs 0.983
#  > > 8	std 	 Fit vs Val (MAc) = 0.743 vs 0.976
#  > > 8	std 	 Fit vs Val (MAc) = 0.756 vs 0.952
#  > > 8	std 	 Fit vs Val (MAc) = 0.755 vs 0.984
#  > > 8	std 	 Fit vs Val (MAc) = 0.737 vs 0.859
#  > > 8	std 	 Fit vs Val (MAc) = 0.755 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.754 vs 0.997
#  > > 8	std 	 Fit vs Val (MAc) = 0.756 vs 0.958
#  > > 8	std 	 Fit vs Val (MAc) = 0.754 vs 1.000
#  > > 8	std 	 Fit vs Val (MAc) = 0.755 vs 0.970
#  > > 8	std 	 Fit vs Val (MAc) = 0.748 vs 0.914
#  > > 8	std 	 Fit vs Val (MAc) = 0.756 vs 0.962
#  > > 8	std 	 Fit vs Val (MAc) = 0.760 vs 0.831
#  > > 8	std 	 Fit vs Val (MAc) = 0.763 vs 0.664
#  > > 8	std 	 Fit vs Val (MAc) = 0.755 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.760 vs 0.803
#  > > 8	std 	 Fit vs Val (MAc) = 0.762 vs 0.771
#  > > 8	std 	 Fit vs Val (MAc) = 0.761 vs 0.664
#  > > 8	std 	 Fit vs Val (MAc) = 0.764 vs 0.725
#  > > 8	std 	 Fit vs Val (MAc) = 0.757 vs 0.836
#  > > 8	std 	 Fit vs Val (MAc) = 0.751 vs 0.738
#  > > 8	std 	 Fit vs Val (MAc) = 0.763 vs 0.722
#  > > 8	std 	 Fit vs Val (MAc) = 0.733 vs 0.883
#  > > 8	std 	 Fit vs Val (MAc) = 0.754 vs 0.783
#  > > 8	std 	 Fit vs Val (MAc) = 0.755 vs nan
#  > > 8	std 	 Fit vs Val (MAc) = 0.761 vs 0.676
#  > > 8	std 	 Fit vs Val (MAc) = 0.761 vs 0.787
#  > > 8	std 	 Fit vs Val (MAc) = 0.761 vs 0.815
#  > > 8	std 	 Fit vs Val (MAc) = 0.749 vs 0.838
#  > > 8	std 	 Fit vs Val (MAc) = 0.759 vs 0.867
#  > > 8	std 	 Fit vs Val (MAc) = 0.731 vs 0.932
#  > > BEST-TH: 0.077 (0.002)
#  > > Test Acc: 0.792
# > ('16', 'mean')
#  > > 16	mean 	 Fit vs Val (MAc) = 0.872 vs 1.000
#  > > 16	mean 	 Fit vs Val (MAc) = 0.873 vs 0.980
#  > > 16	mean 	 Fit vs Val (MAc) = 0.875 vs 0.847
#  > > 16	mean 	 Fit vs Val (MAc) = 0.872 vs 0.953
#  > > 16	mean 	 Fit vs Val (MAc) = 0.874 vs 0.957
#  > > 16	mean 	 Fit vs Val (MAc) = 0.872 vs 0.974
#  > > 16	mean 	 Fit vs Val (MAc) = 0.874 vs 0.945
#  > > 16	mean 	 Fit vs Val (MAc) = 0.870 vs 0.855
#  > > 16	mean 	 Fit vs Val (MAc) = 0.874 vs 0.923
#  > > 16	mean 	 Fit vs Val (MAc) = 0.873 vs 0.987
# ...
#  > > BEST-TH: 0.079 (0.001)
#  > > Test Acc: 0.673
# > ('16', 'std')
#  > > 16	std 	 Fit vs Val (MAc) = 0.783 vs 1.000
#  > > 16	std 	 Fit vs Val (MAc) = 0.786 vs 0.978
#  > > 16	std 	 Fit vs Val (MAc) = 0.798 vs 0.876
#  > > 16	std 	 Fit vs Val (MAc) = 0.783 vs 0.904
#  > > 16	std 	 Fit vs Val (MAc) = 0.788 vs 0.959
#  > > 16	std 	 Fit vs Val (MAc) = 0.787 vs 0.960
#  > > 16	std 	 Fit vs Val (MAc) = 0.785 vs 0.971
#  > > 16	std 	 Fit vs Val (MAc) = 0.773 vs 0.767
#  > > 16	std 	 Fit vs Val (MAc) = 0.789 vs 0.954
#  > > 16	std 	 Fit vs Val (MAc) = 0.785 vs 0.976
#  > > 16	std 	 Fit vs Val (MAc) = 0.760 vs 0.768
#  > > 16	std 	 Fit vs Val (MAc) = 0.787 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.783 vs 0.997
#  > > 16	std 	 Fit vs Val (MAc) = 0.796 vs 0.589
#  > > 16	std 	 Fit vs Val (MAc) = 0.786 vs 0.848
#  > > 16	std 	 Fit vs Val (MAc) = 0.798 vs 0.463
#  > > 16	std 	 Fit vs Val (MAc) = 0.775 vs 0.854
#  > > 16	std 	 Fit vs Val (MAc) = 0.788 vs 0.962
#  > > 16	std 	 Fit vs Val (MAc) = 0.812 vs 0.461
#  > > 16	std 	 Fit vs Val (MAc) = 0.809 vs 0.555
#  > > 16	std 	 Fit vs Val (MAc) = 0.787 vs nan
#  > > 16	std 	 Fit vs Val (MAc) = 0.805 vs 0.396
#  > > BEST-TH: 0.097 (0.008)
#  > > Test Acc: 0.704
# > ('32', 'mean')
#  > > 32	mean 	 Fit vs Val (MAc) = 0.882 vs 0.983
#  > > 32	mean 	 Fit vs Val (MAc) = 0.885 vs 0.973
#  > > 32	mean 	 Fit vs Val (MAc) = 0.890 vs 0.818
#  > > 32	mean 	 Fit vs Val (MAc) = 0.881 vs 0.948
#  > > 32	mean 	 Fit vs Val (MAc) = 0.886 vs 0.939
#  > > 32	mean 	 Fit vs Val (MAc) = 0.883 vs 0.951
#  > > 32	mean 	 Fit vs Val (MAc) = 0.885 vs 0.928
#  > > 32	mean 	 Fit vs Val (MAc) = 0.871 vs 0.860
#  > > 32	mean 	 Fit vs Val (MAc) = 0.884 vs 0.910
#  > > 32	mean 	 Fit vs Val (MAc) = 0.883 vs 0.973
#  > > 32	mean 	 Fit vs Val (MAc) = 0.854 vs 0.928
#  > > 32	mean 	 Fit vs Val (MAc) = 0.884 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.883 vs 0.949
#  > > 32	mean 	 Fit vs Val (MAc) = 0.888 vs 0.907
#  > > 32	mean 	 Fit vs Val (MAc) = 0.882 vs 0.985
#  > > 32	mean 	 Fit vs Val (MAc) = 0.885 vs 0.940
#  > > 32	mean 	 Fit vs Val (MAc) = 0.874 vs 0.916
#  > > 32	mean 	 Fit vs Val (MAc) = 0.884 vs 0.943
#  > > 32	mean 	 Fit vs Val (MAc) = 0.892 vs 0.855
#  > > 32	mean 	 Fit vs Val (MAc) = 0.899 vs 0.864
#  > > 32	mean 	 Fit vs Val (MAc) = 0.884 vs nan
#  > > 32	mean 	 Fit vs Val (MAc) = 0.894 vs 0.856
#  > > BEST-TH: 0.337 (0.003)
#  > > Test Acc: 0.908
# > ('32', 'max')
#  > > 32	max 	 Fit vs Val (MAc) = 0.851 vs 0.995
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs 0.974
#  > > 32	max 	 Fit vs Val (MAc) = 0.863 vs 0.875
#  > > 32	max 	 Fit vs Val (MAc) = 0.850 vs 0.946
#  > > 32	max 	 Fit vs Val (MAc) = 0.856 vs 0.958
#  > > 32	max 	 Fit vs Val (MAc) = 0.852 vs 0.973
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs 0.958
#  > > 32	max 	 Fit vs Val (MAc) = 0.838 vs 0.915
#  > > 32	max 	 Fit vs Val (MAc) = 0.855 vs 0.945
#  > > 32	max 	 Fit vs Val (MAc) = 0.853 vs 0.969
#  > > 32	max 	 Fit vs Val (MAc) = 0.822 vs 0.860
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.852 vs 0.980
#  > > 32	max 	 Fit vs Val (MAc) = 0.860 vs 0.846
#  > > 32	max 	 Fit vs Val (MAc) = 0.852 vs 0.959
#  > > 32	max 	 Fit vs Val (MAc) = 0.859 vs 0.822
#  > > 32	max 	 Fit vs Val (MAc) = 0.841 vs 0.909
#  > > 32	max 	 Fit vs Val (MAc) = 0.855 vs 0.963
#  > > 32	max 	 Fit vs Val (MAc) = 0.867 vs 0.671
#  > > 32	max 	 Fit vs Val (MAc) = 0.864 vs 0.711
#  > > 32	max 	 Fit vs Val (MAc) = 0.854 vs nan
#  > > 32	max 	 Fit vs Val (MAc) = 0.865 vs 0.673
#  > > BEST-TH: 0.602 (0.010)
#  > > Test Acc: 0.838
# > ('32', 'min')
#  > > 32	min 	 Fit vs Val (MAc) = 0.720 vs 0.872
#  > > 32	min 	 Fit vs Val (MAc) = 0.722 vs 0.875
#  > > 32	min 	 Fit vs Val (MAc) = 0.729 vs 0.601
#  > > 32	min 	 Fit vs Val (MAc) = 0.716 vs 0.860
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.789
#  > > 32	min 	 Fit vs Val (MAc) = 0.722 vs 0.740
#  > > 32	min 	 Fit vs Val (MAc) = 0.722 vs 0.836
#  > > 32	min 	 Fit vs Val (MAc) = 0.692 vs 0.807
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.658
#  > > 32	min 	 Fit vs Val (MAc) = 0.718 vs 0.917
#  > > 32	min 	 Fit vs Val (MAc) = 0.776 vs 0.457
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs 0.820
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs 0.879
#  > > 32	min 	 Fit vs Val (MAc) = 0.718 vs 0.938
#  > > 32	min 	 Fit vs Val (MAc) = 0.720 vs 0.945
#  > > 32	min 	 Fit vs Val (MAc) = 0.695 vs 0.867
#  > > 32	min 	 Fit vs Val (MAc) = 0.724 vs 0.752
#  > > 32	min 	 Fit vs Val (MAc) = 0.720 vs 0.650
#  > > 32	min 	 Fit vs Val (MAc) = 0.726 vs 0.764
#  > > 32	min 	 Fit vs Val (MAc) = 0.721 vs nan
#  > > 32	min 	 Fit vs Val (MAc) = 0.725 vs 0.792
#  > > BEST-TH: 0.116 (0.004)
#  > > Test Acc: 0.739
# > ('32', 'std')
#  > > 32	std 	 Fit vs Val (MAc) = 0.794 vs 0.998
#  > > 32	std 	 Fit vs Val (MAc) = 0.796 vs 0.975
#  > > 32	std 	 Fit vs Val (MAc) = 0.808 vs 0.872
#  > > 32	std 	 Fit vs Val (MAc) = 0.794 vs 0.919
#  > > 32	std 	 Fit vs Val (MAc) = 0.798 vs 0.958
#  > > 32	std 	 Fit vs Val (MAc) = 0.796 vs 0.968
#  > > 32	std 	 Fit vs Val (MAc) = 0.796 vs 0.968
#  > > 32	std 	 Fit vs Val (MAc) = 0.770 vs 0.957
#  > > 32	std 	 Fit vs Val (MAc) = 0.799 vs 0.953
#  > > 32	std 	 Fit vs Val (MAc) = 0.796 vs 0.967
#  > > 32	std 	 Fit vs Val (MAc) = 0.748 vs 0.810
#  > > 32	std 	 Fit vs Val (MAc) = 0.796 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.794 vs 0.989
#  > > 32	std 	 Fit vs Val (MAc) = 0.802 vs 0.839
#  > > 32	std 	 Fit vs Val (MAc) = 0.795 vs 0.938
#  > > 32	std 	 Fit vs Val (MAc) = 0.802 vs 0.788
#  > > 32	std 	 Fit vs Val (MAc) = 0.775 vs 0.931
#  > > 32	std 	 Fit vs Val (MAc) = 0.797 vs 0.965
#  > > 32	std 	 Fit vs Val (MAc) = 0.818 vs 0.676
#  > > 32	std 	 Fit vs Val (MAc) = 0.817 vs 0.566
#  > > 32	std 	 Fit vs Val (MAc) = 0.796 vs nan
#  > > 32	std 	 Fit vs Val (MAc) = 0.812 vs 0.629
#  > > BEST-TH: 0.074 (0.004)
#  > > Test Acc: 0.792
# > ('64', 'mean')
#  > > 64	mean 	 Fit vs Val (MAc) = 0.845 vs 0.921
#  > > 64	mean 	 Fit vs Val (MAc) = 0.847 vs 0.922
#  > > 64	mean 	 Fit vs Val (MAc) = 0.854 vs 0.748
#  > > 64	mean 	 Fit vs Val (MAc) = 0.843 vs 0.906
#  > > 64	mean 	 Fit vs Val (MAc) = 0.849 vs 0.869
#  > > 64	mean 	 Fit vs Val (MAc) = 0.846 vs 0.887
#  > > 64	mean 	 Fit vs Val (MAc) = 0.848 vs 0.848
#  > > 64	mean 	 Fit vs Val (MAc) = 0.833 vs 0.847
#  > > 64	mean 	 Fit vs Val (MAc) = 0.848 vs 0.831
#  > > 64	mean 	 Fit vs Val (MAc) = 0.846 vs 0.918
#  > > 64	mean 	 Fit vs Val (MAc) = 0.820 vs 0.911
#  > > 64	mean 	 Fit vs Val (MAc) = 0.847 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.847 vs 0.870
#  > > 64	mean 	 Fit vs Val (MAc) = 0.850 vs 0.845
#  > > 64	mean 	 Fit vs Val (MAc) = 0.845 vs 0.927
#  > > 64	mean 	 Fit vs Val (MAc) = 0.848 vs 0.888
#  > > 64	mean 	 Fit vs Val (MAc) = 0.835 vs 0.882
#  > > 64	mean 	 Fit vs Val (MAc) = 0.847 vs 0.886
#  > > 64	mean 	 Fit vs Val (MAc) = 0.856 vs 0.827
#  > > 64	mean 	 Fit vs Val (MAc) = 0.860 vs 0.843
#  > > 64	mean 	 Fit vs Val (MAc) = 0.847 vs nan
#  > > 64	mean 	 Fit vs Val (MAc) = 0.856 vs 0.823
#  > > BEST-TH: 0.330 (0.002)
#  > > Test Acc: 0.872
# > ('64', 'max')
#  > > 64	max 	 Fit vs Val (MAc) = 0.844 vs 0.981
#  > > 64	max 	 Fit vs Val (MAc) = 0.846 vs 0.967
#  > > 64	max 	 Fit vs Val (MAc) = 0.855 vs 0.856
#  > > 64	max 	 Fit vs Val (MAc) = 0.842 vs 0.935
#  > > 64	max 	 Fit vs Val (MAc) = 0.848 vs 0.944
#  > > 64	max 	 Fit vs Val (MAc) = 0.844 vs 0.953
#  > > 64	max 	 Fit vs Val (MAc) = 0.846 vs 0.936
#  > > 64	max 	 Fit vs Val (MAc) = 0.826 vs 0.904
#  > > 64	max 	 Fit vs Val (MAc) = 0.847 vs 0.933
#  > > 64	max 	 Fit vs Val (MAc) = 0.845 vs 0.958
#  > > 64	max 	 Fit vs Val (MAc) = 0.806 vs 0.894
#  > > 64	max 	 Fit vs Val (MAc) = 0.845 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.845 vs 0.957
#  > > 64	max 	 Fit vs Val (MAc) = 0.850 vs 0.873
#  > > 64	max 	 Fit vs Val (MAc) = 0.845 vs 0.954
#  > > 64	max 	 Fit vs Val (MAc) = 0.848 vs 0.877
#  > > 64	max 	 Fit vs Val (MAc) = 0.829 vs 0.919
#  > > 64	max 	 Fit vs Val (MAc) = 0.846 vs 0.956
#  > > 64	max 	 Fit vs Val (MAc) = 0.860 vs 0.821
#  > > 64	max 	 Fit vs Val (MAc) = 0.859 vs 0.820
#  > > 64	max 	 Fit vs Val (MAc) = 0.845 vs nan
#  > > 64	max 	 Fit vs Val (MAc) = 0.857 vs 0.802
#  > > BEST-TH: 0.453 (0.010)
#  > > Test Acc: 0.894
# > ('64', 'min')
#  > > 64	min 	 Fit vs Val (MAc) = 0.726 vs 0.829
#  > > 64	min 	 Fit vs Val (MAc) = 0.727 vs 0.818
#  > > 64	min 	 Fit vs Val (MAc) = 0.732 vs 0.625
#  > > 64	min 	 Fit vs Val (MAc) = 0.718 vs 0.864
#  > > 64	min 	 Fit vs Val (MAc) = 0.729 vs 0.755
#  > > 64	min 	 Fit vs Val (MAc) = 0.727 vs 0.753
#  > > 64	min 	 Fit vs Val (MAc) = 0.727 vs 0.803
#  > > 64	min 	 Fit vs Val (MAc) = 0.707 vs 0.702
#  > > 64	min 	 Fit vs Val (MAc) = 0.729 vs 0.619
#  > > 64	min 	 Fit vs Val (MAc) = 0.724 vs 0.895
#  > > 64	min 	 Fit vs Val (MAc) = 0.779 vs 0.483
#  > > 64	min 	 Fit vs Val (MAc) = 0.726 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.726 vs 0.810
#  > > 64	min 	 Fit vs Val (MAc) = 0.726 vs 0.847
#  > > 64	min 	 Fit vs Val (MAc) = 0.723 vs 0.921
#  > > 64	min 	 Fit vs Val (MAc) = 0.724 vs 0.917
#  > > 64	min 	 Fit vs Val (MAc) = 0.707 vs 0.776
#  > > 64	min 	 Fit vs Val (MAc) = 0.728 vs 0.757
#  > > 64	min 	 Fit vs Val (MAc) = 0.728 vs 0.682
#  > > 64	min 	 Fit vs Val (MAc) = 0.732 vs 0.794
#  > > 64	min 	 Fit vs Val (MAc) = 0.726 vs nan
#  > > 64	min 	 Fit vs Val (MAc) = 0.730 vs 0.814
#  > > BEST-TH: 0.174 (0.012)
#  > > Test Acc: 0.778
# > ('64', 'std')
#  > > 64	std 	 Fit vs Val (MAc) = 0.780 vs 0.976
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs 0.957
#  > > 64	std 	 Fit vs Val (MAc) = 0.793 vs 0.860
#  > > 64	std 	 Fit vs Val (MAc) = 0.781 vs 0.885
#  > > 64	std 	 Fit vs Val (MAc) = 0.785 vs 0.939
#  > > 64	std 	 Fit vs Val (MAc) = 0.782 vs 0.948
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs 0.923
#  > > 64	std 	 Fit vs Val (MAc) = 0.759 vs 0.915
#  > > 64	std 	 Fit vs Val (MAc) = 0.784 vs 0.944
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs 0.902
#  > > 64	std 	 Fit vs Val (MAc) = 0.739 vs 0.842
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.782 vs 0.950
#  > > 64	std 	 Fit vs Val (MAc) = 0.788 vs 0.790
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs 0.858
#  > > 64	std 	 Fit vs Val (MAc) = 0.789 vs 0.713
#  > > 64	std 	 Fit vs Val (MAc) = 0.764 vs 0.883
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs 0.955
#  > > 64	std 	 Fit vs Val (MAc) = 0.803 vs 0.689
#  > > 64	std 	 Fit vs Val (MAc) = 0.801 vs 0.609
#  > > 64	std 	 Fit vs Val (MAc) = 0.783 vs nan
#  > > 64	std 	 Fit vs Val (MAc) = 0.797 vs 0.661
#  > > BEST-TH: 0.054 (0.002)
#  > > Test Acc: 0.793
# > ('128', 'mean')
#  > > 128	mean 	 Fit vs Val (MAc) = 0.805 vs 0.872
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.864
#  > > 128	mean 	 Fit vs Val (MAc) = 0.813 vs 0.714
#  > > 128	mean 	 Fit vs Val (MAc) = 0.802 vs 0.861
#  > > 128	mean 	 Fit vs Val (MAc) = 0.808 vs 0.823
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.831
#  > > 128	mean 	 Fit vs Val (MAc) = 0.807 vs 0.809
#  > > 128	mean 	 Fit vs Val (MAc) = 0.790 vs 0.819
#  > > 128	mean 	 Fit vs Val (MAc) = 0.808 vs 0.785
#  > > 128	mean 	 Fit vs Val (MAc) = 0.805 vs 0.884
#  > > 128	mean 	 Fit vs Val (MAc) = 0.791 vs 0.761
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.832
#  > > 128	mean 	 Fit vs Val (MAc) = 0.808 vs 0.823
#  > > 128	mean 	 Fit vs Val (MAc) = 0.804 vs 0.894
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs 0.868
#  > > 128	mean 	 Fit vs Val (MAc) = 0.792 vs 0.845
#  > > 128	mean 	 Fit vs Val (MAc) = 0.807 vs 0.830
#  > > 128	mean 	 Fit vs Val (MAc) = 0.816 vs 0.784
#  > > 128	mean 	 Fit vs Val (MAc) = 0.818 vs 0.818
#  > > 128	mean 	 Fit vs Val (MAc) = 0.806 vs nan
#  > > 128	mean 	 Fit vs Val (MAc) = 0.814 vs 0.803
#  > > BEST-TH: 0.315 (0.006)
#  > > Test Acc: 0.843
# > ('128', 'max')
#  > > 128	max 	 Fit vs Val (MAc) = 0.821 vs 0.927
#  > > 128	max 	 Fit vs Val (MAc) = 0.822 vs 0.916
#  > > 128	max 	 Fit vs Val (MAc) = 0.830 vs 0.800
#  > > 128	max 	 Fit vs Val (MAc) = 0.818 vs 0.902
#  > > 128	max 	 Fit vs Val (MAc) = 0.824 vs 0.890
#  > > 128	max 	 Fit vs Val (MAc) = 0.821 vs 0.898
#  > > 128	max 	 Fit vs Val (MAc) = 0.823 vs 0.875
#  > > 128	max 	 Fit vs Val (MAc) = 0.802 vs 0.880
#  > > 128	max 	 Fit vs Val (MAc) = 0.823 vs 0.873
#  > > 128	max 	 Fit vs Val (MAc) = 0.822 vs 0.917
#  > > 128	max 	 Fit vs Val (MAc) = 0.790 vs 0.871
#  > > 128	max 	 Fit vs Val (MAc) = 0.821 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.822 vs 0.892
#  > > 128	max 	 Fit vs Val (MAc) = 0.825 vs 0.853
#  > > 128	max 	 Fit vs Val (MAc) = 0.821 vs 0.918
#  > > 128	max 	 Fit vs Val (MAc) = 0.823 vs 0.877
#  > > 128	max 	 Fit vs Val (MAc) = 0.805 vs 0.888
#  > > 128	max 	 Fit vs Val (MAc) = 0.822 vs 0.899
#  > > 128	max 	 Fit vs Val (MAc) = 0.836 vs 0.811
#  > > 128	max 	 Fit vs Val (MAc) = 0.836 vs 0.815
#  > > 128	max 	 Fit vs Val (MAc) = 0.821 vs nan
#  > > 128	max 	 Fit vs Val (MAc) = 0.833 vs 0.809
#  > > BEST-TH: 0.380 (0.003)
#  > > Test Acc: 0.871
# > ('128', 'min')
#  > > 128	min 	 Fit vs Val (MAc) = 0.749 vs 0.754
#  > > 128	min 	 Fit vs Val (MAc) = 0.750 vs 0.744
#  > > 128	min 	 Fit vs Val (MAc) = 0.756 vs 0.565
#  > > 128	min 	 Fit vs Val (MAc) = 0.744 vs 0.813
#  > > 128	min 	 Fit vs Val (MAc) = 0.752 vs 0.673
#  > > 128	min 	 Fit vs Val (MAc) = 0.750 vs 0.692
#  > > 128	min 	 Fit vs Val (MAc) = 0.751 vs 0.695
#  > > 128	min 	 Fit vs Val (MAc) = 0.733 vs 0.720
#  > > 128	min 	 Fit vs Val (MAc) = 0.753 vs 0.612
#  > > 128	min 	 Fit vs Val (MAc) = 0.747 vs 0.817
#  > > 128	min 	 Fit vs Val (MAc) = 0.775 vs 0.553
#  > > 128	min 	 Fit vs Val (MAc) = 0.749 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.750 vs 0.721
#  > > 128	min 	 Fit vs Val (MAc) = 0.750 vs 0.751
#  > > 128	min 	 Fit vs Val (MAc) = 0.746 vs 0.836
#  > > 128	min 	 Fit vs Val (MAc) = 0.748 vs 0.837
#  > > 128	min 	 Fit vs Val (MAc) = 0.734 vs 0.773
#  > > 128	min 	 Fit vs Val (MAc) = 0.751 vs 0.692
#  > > 128	min 	 Fit vs Val (MAc) = 0.755 vs 0.689
#  > > 128	min 	 Fit vs Val (MAc) = 0.757 vs 0.790
#  > > 128	min 	 Fit vs Val (MAc) = 0.749 vs nan
#  > > 128	min 	 Fit vs Val (MAc) = 0.754 vs 0.759
#  > > BEST-TH: 0.252 (0.009)
#  > > Test Acc: 0.768
# > ('128', 'std')
#  > > 128	std 	 Fit vs Val (MAc) = 0.747 vs 0.906
#  > > 128	std 	 Fit vs Val (MAc) = 0.748 vs 0.896
#  > > 128	std 	 Fit vs Val (MAc) = 0.757 vs 0.816
#  > > 128	std 	 Fit vs Val (MAc) = 0.746 vs 0.813
#  > > 128	std 	 Fit vs Val (MAc) = 0.750 vs 0.885
#  > > 128	std 	 Fit vs Val (MAc) = 0.747 vs 0.898
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs 0.844
#  > > 128	std 	 Fit vs Val (MAc) = 0.726 vs 0.861
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs 0.892
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs 0.831
#  > > 128	std 	 Fit vs Val (MAc) = 0.716 vs 0.781
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.748 vs 0.866
#  > > 128	std 	 Fit vs Val (MAc) = 0.753 vs 0.738
#  > > 128	std 	 Fit vs Val (MAc) = 0.750 vs 0.776
#  > > 128	std 	 Fit vs Val (MAc) = 0.754 vs 0.672
#  > > 128	std 	 Fit vs Val (MAc) = 0.731 vs 0.833
#  > > 128	std 	 Fit vs Val (MAc) = 0.748 vs 0.898
#  > > 128	std 	 Fit vs Val (MAc) = 0.767 vs 0.702
#  > > 128	std 	 Fit vs Val (MAc) = 0.764 vs 0.597
#  > > 128	std 	 Fit vs Val (MAc) = 0.749 vs nan
#  > > 128	std 	 Fit vs Val (MAc) = 0.761 vs 0.647
#  > > BEST-TH: 0.035 (0.001)
#  > > Test Acc: 0.759
# > ('512', 'ori')
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs 0.827
#  > > 512	ori 	 Fit vs Val (MAc) = 0.776 vs 0.816
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.672
#  > > 512	ori 	 Fit vs Val (MAc) = 0.771 vs 0.840
#  > > 512	ori 	 Fit vs Val (MAc) = 0.778 vs 0.768
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs 0.785
#  > > 512	ori 	 Fit vs Val (MAc) = 0.777 vs 0.772
#  > > 512	ori 	 Fit vs Val (MAc) = 0.757 vs 0.799
#  > > 512	ori 	 Fit vs Val (MAc) = 0.778 vs 0.735
#  > > 512	ori 	 Fit vs Val (MAc) = 0.774 vs 0.852
#  > > 512	ori 	 Fit vs Val (MAc) = 0.772 vs 0.652
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.776 vs 0.795
#  > > 512	ori 	 Fit vs Val (MAc) = 0.778 vs 0.787
#  > > 512	ori 	 Fit vs Val (MAc) = 0.774 vs 0.858
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs 0.838
#  > > 512	ori 	 Fit vs Val (MAc) = 0.759 vs 0.823
#  > > 512	ori 	 Fit vs Val (MAc) = 0.776 vs 0.782
#  > > 512	ori 	 Fit vs Val (MAc) = 0.785 vs 0.750
#  > > 512	ori 	 Fit vs Val (MAc) = 0.787 vs 0.798
#  > > 512	ori 	 Fit vs Val (MAc) = 0.775 vs nan
#  > > 512	ori 	 Fit vs Val (MAc) = 0.783 vs 0.775
#  > > BEST-TH: 0.308 (0.008)
#  > > Test Acc: 0.813
# Done.
# CPU times: user 1h 26min 1s, sys: 10min 40s, total: 1h 36min 42s
# Wall time: 47min 11s

# %%
for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    exp_fit = VI_scores[e]
    exp_val = VI_scores_val[e]
    for vi, (r, f) in enumerate(VI_cols):
        ar_fit = pd.Series(exp_fit[vi])
        ar_val = pd.Series(exp_val[vi])
        
        results = (r, f , ar_fit.mean(), ar_fit.std(), ar_val.mean(), ar_val.std(), VI_scores_test[e][vi])
        print(" > > %-3s %s \t Fit vs Val vs Test (MAc) = %.3f (%.3f) vs %.3f (%.3f) vs %.3f" % results)
        if vi % 4 == 3:
            print()
    print()
    
# TODO: show generalization after getting mean th
# Out:
# Experiment [0] [1]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.915 (0.007) vs 0.924 (0.073) vs 0.838
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.869 (0.018) vs 0.939 (0.065) vs 0.606
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.713 (0.018) vs 0.693 (0.147) vs 0.445
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.852 (0.019) vs 0.921 (0.111) vs 0.676
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.931 (0.007) vs 0.950 (0.040) vs 0.881
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.886 (0.013) vs 0.932 (0.067) vs 0.439
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.725 (0.021) vs 0.779 (0.126) vs 0.559
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.863 (0.016) vs 0.917 (0.107) vs 0.585
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.925 (0.007) vs 0.946 (0.035) vs 0.894
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.898 (0.012) vs 0.941 (0.051) vs 0.778
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.734 (0.024) vs 0.812 (0.122) vs 0.682
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.867 (0.014) vs 0.918 (0.084) vs 0.674
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.886 (0.006) vs 0.893 (0.043) vs 0.873
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.896 (0.011) vs 0.942 (0.031) vs 0.862
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.743 (0.023) vs 0.784 (0.119) vs 0.757
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.845 (0.011) vs 0.887 (0.070) vs 0.674
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.844 (0.007) vs 0.828 (0.060) vs 0.842
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.869 (0.007) vs 0.888 (0.037) vs 0.854
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.775 (0.017) vs 0.723 (0.099) vs 0.786
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.803 (0.009) vs 0.830 (0.064) vs 0.681
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.813 (0.010) vs 0.789 (0.073) vs 0.819
#
# Experiment [1] [0]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.888 (0.007) vs 0.896 (0.096) vs 0.920
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.843 (0.013) vs 0.898 (0.162) vs 0.949
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.709 (0.014) vs 0.689 (0.175) vs 0.708
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.792 (0.014) vs 0.797 (0.249) vs 0.949
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.901 (0.008) vs 0.931 (0.058) vs 0.943
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.857 (0.010) vs 0.887 (0.161) vs 0.944
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.723 (0.016) vs 0.777 (0.125) vs 0.797
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.806 (0.013) vs 0.847 (0.179) vs 0.949
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.893 (0.009) vs 0.925 (0.045) vs 0.942
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.865 (0.010) vs 0.908 (0.090) vs 0.936
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.725 (0.017) vs 0.801 (0.117) vs 0.814
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.812 (0.016) vs 0.897 (0.116) vs 0.932
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.855 (0.008) vs 0.873 (0.045) vs 0.878
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.857 (0.012) vs 0.918 (0.048) vs 0.935
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.731 (0.016) vs 0.778 (0.105) vs 0.804
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.797 (0.014) vs 0.868 (0.102) vs 0.895
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.814 (0.007) vs 0.827 (0.045) vs 0.839
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.832 (0.010) vs 0.879 (0.037) vs 0.889
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.755 (0.010) vs 0.721 (0.087) vs 0.735
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.761 (0.012) vs 0.813 (0.087) vs 0.838
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.784 (0.007) vs 0.787 (0.057) vs 0.799
#
# Experiment [0, 1] [2]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.848 (0.004) vs 0.870 (0.090) vs 0.839
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.820 (0.006) vs 0.875 (0.104) vs 0.833
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.601 (0.006) vs 0.575 (0.182) vs 0.483
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.754 (0.008) vs 0.870 (0.106) vs 0.792
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.873 (0.004) vs 0.910 (0.058) vs 0.854
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.836 (0.005) vs 0.883 (0.095) vs 0.848
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.650 (0.004) vs 0.556 (0.143) vs 0.505
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.767 (0.008) vs 0.869 (0.106) vs 0.810
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.872 (0.004) vs 0.911 (0.047) vs 0.850
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.847 (0.005) vs 0.891 (0.082) vs 0.857
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.712 (0.004) vs 0.682 (0.120) vs 0.608
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.779 (0.007) vs 0.866 (0.106) vs 0.812
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.845 (0.004) vs 0.882 (0.043) vs 0.833
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.843 (0.005) vs 0.896 (0.059) vs 0.855
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.746 (0.004) vs 0.731 (0.102) vs 0.694
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.770 (0.006) vs 0.844 (0.108) vs 0.802
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.813 (0.004) vs 0.846 (0.047) vs 0.811
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.823 (0.005) vs 0.871 (0.045) vs 0.835
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.768 (0.004) vs 0.769 (0.081) vs 0.749
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.744 (0.006) vs 0.808 (0.099) vs 0.779
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.788 (0.004) vs 0.817 (0.054) vs 0.795
#
# Experiment [2] [0, 1]
#  > > 8   mean 	 Fit vs Val vs Test (MAc) = 0.877 (0.007) vs 0.887 (0.103) vs 0.857
#  > > 8   max 	 Fit vs Val vs Test (MAc) = 0.832 (0.011) vs 0.877 (0.181) vs 0.719
#  > > 8   min 	 Fit vs Val vs Test (MAc) = 0.709 (0.013) vs 0.686 (0.171) vs 0.582
#  > > 8   std 	 Fit vs Val vs Test (MAc) = 0.775 (0.012) vs 0.745 (0.298) vs 0.620
#
#  > > 16  mean 	 Fit vs Val vs Test (MAc) = 0.892 (0.007) vs 0.919 (0.064) vs 0.909
#  > > 16  max 	 Fit vs Val vs Test (MAc) = 0.847 (0.010) vs 0.868 (0.183) vs 0.729
#  > > 16  min 	 Fit vs Val vs Test (MAc) = 0.719 (0.014) vs 0.776 (0.123) vs 0.673
#  > > 16  std 	 Fit vs Val vs Test (MAc) = 0.788 (0.012) vs 0.812 (0.204) vs 0.704
#
#  > > 32  mean 	 Fit vs Val vs Test (MAc) = 0.883 (0.009) vs 0.921 (0.048) vs 0.908
#  > > 32  max 	 Fit vs Val vs Test (MAc) = 0.853 (0.010) vs 0.895 (0.103) vs 0.838
#  > > 32  min 	 Fit vs Val vs Test (MAc) = 0.722 (0.015) vs 0.791 (0.123) vs 0.739
#  > > 32  std 	 Fit vs Val vs Test (MAc) = 0.795 (0.015) vs 0.883 (0.127) vs 0.792
#
#  > > 64  mean 	 Fit vs Val vs Test (MAc) = 0.846 (0.008) vs 0.870 (0.045) vs 0.872
#  > > 64  max 	 Fit vs Val vs Test (MAc) = 0.844 (0.012) vs 0.912 (0.054) vs 0.894
#  > > 64  min 	 Fit vs Val vs Test (MAc) = 0.727 (0.013) vs 0.773 (0.109) vs 0.778
#  > > 64  std 	 Fit vs Val vs Test (MAc) = 0.782 (0.014) vs 0.860 (0.110) vs 0.793
#
#  > > 128 mean 	 Fit vs Val vs Test (MAc) = 0.806 (0.007) vs 0.826 (0.044) vs 0.843
#  > > 128 max 	 Fit vs Val vs Test (MAc) = 0.821 (0.010) vs 0.876 (0.039) vs 0.871
#  > > 128 min 	 Fit vs Val vs Test (MAc) = 0.750 (0.008) vs 0.724 (0.081) vs 0.768
#  > > 128 std 	 Fit vs Val vs Test (MAc) = 0.748 (0.012) vs 0.808 (0.092) vs 0.759
#
#  > > 512 ori 	 Fit vs Val vs Test (MAc) = 0.775 (0.007) vs 0.786 (0.054) vs 0.813

# %% [markdown]
# <hr>

# %% [markdown]
# ## Ensemble

# %%
def XGBTrain2(X_train, y_train, n_trees, verbose = False, val_imgs = None):

#     n = len(X_train)
#     f = .02
#     ix = X_train.index.values.copy()
#     np.random.shuffle(ix)
#     X_train = X_train.loc[ix[:int(n * f)]]
#     y_train = y_train.loc[ix[:int(n * f)]]
    
    
    ratio = float(np.sum(y_train == 1)) / np.sum(y_train==0)

    clf = xgb.XGBClassifier(
                    max_depth = 2,
                    n_estimators=n_trees,
                    learning_rate=0.1, 
                    nthread=2,
                    subsample=1,
                    colsample_bytree=1,
                    scale_pos_weight = ratio,
                    reg_alpha=0,
                    seed=1301)
    
    if type(val_imgs) != np.ndarray:
        eval_set = [
            (X_train, y_train),
        ]
    else:
        X_val, y_val = data.loc[IMG.isin(val_imgs)], y.loc[IMG.isin(val_imgs)]
        eval_set = [
            (X_train, y_train),
            (X_val, y_val),
        ]
        
    clf.fit(X_train, y_train, early_stopping_rounds=100 , eval_metric="auc",
            eval_set=eval_set,
            verbose = verbose,
           )
    
    return clf

# %%
fit_imgs = IMG.loc[solo.isin([0, 1])].unique()
val_imgs = IMG.loc[solo.isin([2])].unique()
XGBTrain2(data, y, 100, verbose = True, val_imgs = val_imgs)
# Out:
# [0]	validation_0-auc:0.875605	validation_1-auc:0.894875
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.894564	validation_1-auc:0.898531
# [2]	validation_0-auc:0.895076	validation_1-auc:0.905602
# [3]	validation_0-auc:0.898477	validation_1-auc:0.906858
# [4]	validation_0-auc:0.898575	validation_1-auc:0.906693
# [5]	validation_0-auc:0.898919	validation_1-auc:0.907464
# [6]	validation_0-auc:0.906975	validation_1-auc:0.91042
# [7]	validation_0-auc:0.906987	validation_1-auc:0.91061
# [8]	validation_0-auc:0.908277	validation_1-auc:0.915593
# [9]	validation_0-auc:0.912474	validation_1-auc:0.916657
# [10]	validation_0-auc:0.912519	validation_1-auc:0.917569
# [11]	validation_0-auc:0.913016	validation_1-auc:0.917981
# [12]	validation_0-auc:0.914175	validation_1-auc:0.921947
# [13]	validation_0-auc:0.914177	validation_1-auc:0.921822
# [14]	validation_0-auc:0.914825	validation_1-auc:0.923953
# [15]	validation_0-auc:0.939992	validation_1-auc:0.923873
# [16]	validation_0-auc:0.94382	validation_1-auc:0.925379
# [17]	validation_0-auc:0.944883	validation_1-auc:0.924936
# [18]	validation_0-auc:0.947914	validation_1-auc:0.925206
# [19]	validation_0-auc:0.947267	validation_1-auc:0.925796
# [20]	validation_0-auc:0.948411	validation_1-auc:0.925479
# [21]	validation_0-auc:0.949301	validation_1-auc:0.925259
# [22]	validation_0-auc:0.94985	validation_1-auc:0.925853
# [23]	validation_0-auc:0.950098	validation_1-auc:0.926504
# [24]	validation_0-auc:0.950442	validation_1-auc:0.926342
# [25]	validation_0-auc:0.950479	validation_1-auc:0.926584
# [26]	validation_0-auc:0.951336	validation_1-auc:0.926558
# [27]	validation_0-auc:0.951419	validation_1-auc:0.927185
# [28]	validation_0-auc:0.95354	validation_1-auc:0.927568
# [29]	validation_0-auc:0.953512	validation_1-auc:0.927345
# [30]	validation_0-auc:0.953863	validation_1-auc:0.927658
# [31]	validation_0-auc:0.954297	validation_1-auc:0.9276
# [32]	validation_0-auc:0.954676	validation_1-auc:0.929579
# [33]	validation_0-auc:0.955041	validation_1-auc:0.931065
# [34]	validation_0-auc:0.955072	validation_1-auc:0.931374
# [35]	validation_0-auc:0.955861	validation_1-auc:0.930563
# [36]	validation_0-auc:0.956165	validation_1-auc:0.93052
# [37]	validation_0-auc:0.956739	validation_1-auc:0.929833
# [38]	validation_0-auc:0.957198	validation_1-auc:0.929189
# [39]	validation_0-auc:0.957448	validation_1-auc:0.928935
# [40]	validation_0-auc:0.957882	validation_1-auc:0.928095
# [41]	validation_0-auc:0.958117	validation_1-auc:0.928165
# [42]	validation_0-auc:0.958637	validation_1-auc:0.927922
# [43]	validation_0-auc:0.958623	validation_1-auc:0.928994
# [44]	validation_0-auc:0.959084	validation_1-auc:0.928838
# [45]	validation_0-auc:0.959214	validation_1-auc:0.929269
# [46]	validation_0-auc:0.959575	validation_1-auc:0.929119
# [47]	validation_0-auc:0.959777	validation_1-auc:0.928782
# [48]	validation_0-auc:0.959901	validation_1-auc:0.92919
# [49]	validation_0-auc:0.960216	validation_1-auc:0.929086
# [50]	validation_0-auc:0.96031	validation_1-auc:0.929791
# [51]	validation_0-auc:0.960386	validation_1-auc:0.929962
# [52]	validation_0-auc:0.960349	validation_1-auc:0.930616
# [53]	validation_0-auc:0.960631	validation_1-auc:0.930709
# [54]	validation_0-auc:0.960713	validation_1-auc:0.931049
# [55]	validation_0-auc:0.960777	validation_1-auc:0.931294
# [56]	validation_0-auc:0.960871	validation_1-auc:0.931354
# [57]	validation_0-auc:0.961058	validation_1-auc:0.931329
# [58]	validation_0-auc:0.961181	validation_1-auc:0.931208
# [59]	validation_0-auc:0.961198	validation_1-auc:0.9311
# [60]	validation_0-auc:0.961251	validation_1-auc:0.93138
# [61]	validation_0-auc:0.961456	validation_1-auc:0.931229
# [62]	validation_0-auc:0.961634	validation_1-auc:0.931286
# [63]	validation_0-auc:0.961695	validation_1-auc:0.931467
# [64]	validation_0-auc:0.961709	validation_1-auc:0.931408
# [65]	validation_0-auc:0.961851	validation_1-auc:0.931514
# [66]	validation_0-auc:0.961877	validation_1-auc:0.932
# [67]	validation_0-auc:0.961951	validation_1-auc:0.93183
# [68]	validation_0-auc:0.961966	validation_1-auc:0.93176
# [69]	validation_0-auc:0.962074	validation_1-auc:0.931607
# [70]	validation_0-auc:0.962127	validation_1-auc:0.931649
# [71]	validation_0-auc:0.96223	validation_1-auc:0.931809
# [72]	validation_0-auc:0.962308	validation_1-auc:0.931552
# [73]	validation_0-auc:0.962415	validation_1-auc:0.931485
# [74]	validation_0-auc:0.962426	validation_1-auc:0.931659
# [75]	validation_0-auc:0.962436	validation_1-auc:0.931608
# [76]	validation_0-auc:0.962457	validation_1-auc:0.931994
# [77]	validation_0-auc:0.962496	validation_1-auc:0.931881
# [78]	validation_0-auc:0.962529	validation_1-auc:0.931955
# [79]	validation_0-auc:0.962667	validation_1-auc:0.931854
# [80]	validation_0-auc:0.962765	validation_1-auc:0.93178
# [81]	validation_0-auc:0.962773	validation_1-auc:0.931845
# [82]	validation_0-auc:0.962859	validation_1-auc:0.93181
# [83]	validation_0-auc:0.962961	validation_1-auc:0.931444
# [84]	validation_0-auc:0.963009	validation_1-auc:0.931596
# [85]	validation_0-auc:0.963014	validation_1-auc:0.931734
# [86]	validation_0-auc:0.963026	validation_1-auc:0.93179
# [87]	validation_0-auc:0.963086	validation_1-auc:0.931809
# [88]	validation_0-auc:0.963247	validation_1-auc:0.931807
# [89]	validation_0-auc:0.963295	validation_1-auc:0.931697
# [90]	validation_0-auc:0.963303	validation_1-auc:0.931807
# [91]	validation_0-auc:0.96331	validation_1-auc:0.931763
# [92]	validation_0-auc:0.963369	validation_1-auc:0.931796
# [93]	validation_0-auc:0.963408	validation_1-auc:0.931875
# [94]	validation_0-auc:0.963458	validation_1-auc:0.931748
# [95]	validation_0-auc:0.96354	validation_1-auc:0.932089
# [96]	validation_0-auc:0.963617	validation_1-auc:0.932102
# [97]	validation_0-auc:0.963654	validation_1-auc:0.932177
# [98]	validation_0-auc:0.963658	validation_1-auc:0.932265
# [99]	validation_0-auc:0.963746	validation_1-auc:0.932089
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=6, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=3.2863203482334225,
#        seed=1301, silent=True, subsample=1)

# %%
data.columns.to_list()
# Out:
# [('8', 'mean'),
#  ('8', 'max'),
#  ('8', 'min'),
#  ('8', 'std'),
#  ('16', 'mean'),
#  ('16', 'max'),
#  ('16', 'min'),
#  ('16', 'std'),
#  ('32', 'mean'),
#  ('32', 'max'),
#  ('32', 'min'),
#  ('32', 'std'),
#  ('64', 'mean'),
#  ('64', 'max'),
#  ('64', 'min'),
#  ('64', 'std'),
#  ('128', 'mean'),
#  ('128', 'max'),
#  ('128', 'min'),
#  ('128', 'std'),
#  ('512', 'ori')]

# %%
subset = data[[
#     ('64', 'mean'),
    ('32', 'mean'),
    ('16', 'mean'),
#     ('8', 'mean'),
    ('32', 'max'),
    ('64', 'max'),
#     ('128', 'min'),
#     ('32', 'std'),
#     ('16', 'std'),
    ('512', 'ori')
]]

# %%
# %%time
'''
Here we want to obtain and ensemble of theses features
''' 

# tree_list = list(range(30, 60, 10))
tree_list = [35]

VI_scores = [[[] for vi in tree_list] for _ in range(4)] # 4 is the number of experiments
VI_scores_val = [[[] for t in tree_list] for _ in range(4)]
VI_scores_test = [[0 for t in tree_list] for _ in range(4)]
THS = [[[] for vi in names_VI] for _ in range(4)]

for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    
    images = np.unique(IMG.loc[solo.isin(left)])
    for t, trees in enumerate(tree_list):

        print('>', trees)
        
        for _in, _out in loo.split(images):
            train_imgs, test_imgs = images[_in], images[_out]
            
            # fit score
            frac = .01
            fit_mask = IMG.isin(train_imgs) & (np.random.rand(len(data)) <= frac)
            fit_y = y.loc[fit_mask]
            clf = XGBTrain2(subset.loc[fit_mask], fit_y, trees)
            prediction = clf.predict_proba(subset.loc[fit_mask])[:,-1]
            _auc, mean_acc, bestTH, fpr, tpr = getPerformance(fit_y, prediction)
            
            # val score
            val_mask = IMG.isin(test_imgs)
            prediction = clf.predict_proba(subset.loc[val_mask])[:,-1]
            val_y = y.loc[val_mask]
            val_mean_acc = accuracy_score(val_y, 1 * (prediction > bestTH))
            
            # save
            VI_scores[e][t].append(mean_acc)
            VI_scores_val[e][t].append(val_mean_acc)
            THS[e][t].append(bestTH)
            print(" > > %2d \t Fit vs Val (MAc) = %.3f vs %.3f" % (test_imgs[0], mean_acc, val_mean_acc))
        
        # test score
        ar = np.array(THS[e][t])
        bestTH = np.median(ar)
        print(" > > BEST-TH: %.3f (%.3f)" % (bestTH, ar.std()))
        
        test_mask = solo.isin(test)
        prediction = clf.predict_proba(subset.loc[test_mask])[:,-1]
        test_y = y.loc[test_mask]
        test_mean_acc = accuracy_score(test_y, 1 * (prediction > bestTH))
        
        VI_scores_test[e][t] = test_mean_acc
        print(" > > TEST Score : %.3f" % test_mean_acc)
        
print("Done.")
# Out:
# Experiment [0] [1]
# > 35
#  > >  0 	 Fit vs Val (MAc) = 0.934 vs 0.995
#  > >  1 	 Fit vs Val (MAc) = 0.935 vs 0.980
#  > >  2 	 Fit vs Val (MAc) = 0.946 vs 0.846
#  > >  3 	 Fit vs Val (MAc) = 0.936 vs 0.955
#  > >  4 	 Fit vs Val (MAc) = 0.937 vs 0.957
#  > >  5 	 Fit vs Val (MAc) = 0.938 vs 0.969
#  > >  6 	 Fit vs Val (MAc) = 0.935 vs 0.967
#  > >  7 	 Fit vs Val (MAc) = 0.931 vs 0.856
#  > >  8 	 Fit vs Val (MAc) = 0.937 vs 0.933
#  > >  9 	 Fit vs Val (MAc) = 0.936 vs 0.985
#  > > 10 	 Fit vs Val (MAc) = 0.917 vs 0.926
#  > > 12 	 Fit vs Val (MAc) = 0.934 vs 0.985
#  > > 13 	 Fit vs Val (MAc) = 0.939 vs 0.928
#  > > 14 	 Fit vs Val (MAc) = 0.933 vs 1.000
#  > > 15 	 Fit vs Val (MAc) = 0.937 vs 0.950
#  > > 16 	 Fit vs Val (MAc) = 0.928 vs 0.930
#  > > 17 	 Fit vs Val (MAc) = 0.936 vs 0.974
#  > > BEST-TH: 0.963 (0.006)
#  > > TEST Score : 0.892
# Experiment [1] [0]
# > 35
#  > > 18 	 Fit vs Val (MAc) = 0.871 vs 0.863
#  > > 19 	 Fit vs Val (MAc) = 0.873 vs 0.872
#  > > 21 	 Fit vs Val (MAc) = 0.874 vs 0.876
#  > > 22 	 Fit vs Val (MAc) = 0.874 vs 0.876
#  > > 23 	 Fit vs Val (MAc) = 0.876 vs 0.855
#  > > 24 	 Fit vs Val (MAc) = 0.869 vs 0.869
#  > > 25 	 Fit vs Val (MAc) = 0.868 vs 0.897
#  > > 26 	 Fit vs Val (MAc) = 0.865 vs 0.925
#  > > 27 	 Fit vs Val (MAc) = 0.873 vs 0.841
#  > > 28 	 Fit vs Val (MAc) = 0.854 vs 0.967
#  > > 29 	 Fit vs Val (MAc) = 0.862 vs 0.930
#  > > 31 	 Fit vs Val (MAc) = 0.871 vs 0.887
#  > > 32 	 Fit vs Val (MAc) = 0.871 vs 0.882
#  > > 33 	 Fit vs Val (MAc) = 0.869 vs 0.837
#  > > 34 	 Fit vs Val (MAc) = 0.867 vs 0.908
#  > > 35 	 Fit vs Val (MAc) = 0.873 vs 0.877
#  > > 36 	 Fit vs Val (MAc) = 0.854 vs 0.963
#  > > 37 	 Fit vs Val (MAc) = 0.858 vs 0.926
#  > > 38 	 Fit vs Val (MAc) = 0.869 vs 0.918
#  > > 39 	 Fit vs Val (MAc) = 0.871 vs 0.880
#  > > BEST-TH: 0.808 (0.030)
#  > > TEST Score : 0.945
# Experiment [0, 1] [2]
# > 35
#  > >  0 	 Fit vs Val (MAc) = 0.882 vs 0.993
#  > >  1 	 Fit vs Val (MAc) = 0.886 vs 0.981
#  > >  2 	 Fit vs Val (MAc) = 0.887 vs 0.835
#  > >  3 	 Fit vs Val (MAc) = 0.882 vs 0.947
#  > >  4 	 Fit vs Val (MAc) = 0.885 vs 0.954
#  > >  5 	 Fit vs Val (MAc) = 0.883 vs 0.962
#  > >  6 	 Fit vs Val (MAc) = 0.886 vs 0.928
#  > >  7 	 Fit vs Val (MAc) = 0.885 vs 0.850
#  > >  8 	 Fit vs Val (MAc) = 0.885 vs 0.918
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-125-f7754e91ca43> in <module>
#      27             fit_mask = IMG.isin(train_imgs) & (np.random.rand(len(data)) <= frac)
#      28             fit_y = y.loc[fit_mask]
# ---> 29             clf = XGBTrain2(subset.loc[fit_mask], fit_y, trees)
#      30             prediction = clf.predict_proba(subset.loc[fit_mask])[:,-1]
#      31             _auc, mean_acc, bestTH, fpr, tpr = getPerformance(fit_y, prediction)
#
# <ipython-input-122-1a45e60551e6> in XGBTrain2(X_train, y_train, n_trees, verbose, val_imgs)
#      35     clf.fit(X_train, y_train, early_stopping_rounds=100 , eval_metric="auc",
#      36             eval_set=eval_set,
# ---> 37             verbose = verbose,
#      38            )
#      39
#
# ~/miniconda3/envs/py/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     698                               evals_result=evals_result, obj=obj, feval=feval,
#     699                               verbose_eval=verbose, xgb_model=None,
# --> 700                               callbacks=callbacks)
#     701
#     702         self.objective = xgb_options["objective"]
#
# ~/miniconda3/envs/py/lib/python3.7/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# ~/miniconda3/envs/py/lib/python3.7/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~/miniconda3/envs/py/lib/python3.7/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1043         if fobj is None:
#    1044             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1045                                                     dtrain.handle))
#    1046         else:
#    1047             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %%
for e, (left, test) in enumerate(experiments):
    print("Experiment", left, test)
    exp_fit = VI_scores[e]
    exp_val = VI_scores_val[e]
    for t, trees in enumerate(tree_list):
        ar_fit = pd.Series(exp_fit[t])
        ar_val = pd.Series(exp_val[t])
        
        results = (trees, ar_fit.mean(), ar_fit.std(), ar_val.mean(), ar_val.std(), VI_scores_test[e][t])
        print(" > > %d \t Fit vs Val vs Test (MAc) = %.3f (%.3f) vs %.3f (%.3f) vs %.3f" % results)
# Out:
# Experiment [0] [1]
#  > > 35 	 Fit vs Val vs Test (MAc) = 0.934 (0.007) vs 0.945 (0.050) vs 0.878
# Experiment [1] [0]
#  > > 35 	 Fit vs Val vs Test (MAc) = 0.869 (0.006) vs 0.889 (0.042) vs 0.935
# Experiment [0, 1] [2]
#  > > 35 	 Fit vs Val vs Test (MAc) = 0.885 (0.003) vs 0.912 (0.052) vs 0.857
# Experiment [2] [0, 1]
#  > > 35 	 Fit vs Val vs Test (MAc) = 0.870 (0.010) vs 0.838 (0.194) vs 0.915

# %%
"""
0.894
0.937
0.851
0.924 ?


#subset = data[[
#     ('64', 'mean'),
    ('32', 'mean'),
    ('16', 'mean'),
#     ('8', 'mean'),
    ('32', 'max'),
    ('64', 'max'),
#     ('128', 'min'),
#     ('32', 'std'),
#     ('8', 'std'),
    ('512', 'ori')
]]
max_depth = 2,
n_estimators=n_trees,
learning_rate=0.1, 
nthread=6,
subsample=1,
colsample_bytree=1,
scale_pos_weight = ratio,
reg_alpha=0,
seed=1301
Experiment [0] [1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.935 (0.005) vs 0.951 (0.040) vs 0.894
Experiment [1] [0]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.868 (0.006) vs 0.889 (0.043) vs 0.945
Experiment [0, 1] [2]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.885 (0.004) vs 0.915 (0.048) vs 0.858
Experiment [2] [0, 1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.865 (0.010) vs 0.835 (0.195) vs 0.917
 

# 5 feat
Experiment [0] [1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.934 (0.006) vs 0.952 (0.041) vs 0.893
Experiment [1] [0]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.868 (0.006) vs 0.889 (0.040) vs 0.937
Experiment [0, 1] [2]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.885 (0.004) vs 0.913 (0.052) vs 0.856
Experiment [2] [0, 1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.867 (0.010) vs 0.834 (0.198) vs 0.914

# below but LOO fixed
Experiment [0] [1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.928 (0.007) vs 0.940 (0.074) vs 0.882
Experiment [1] [0]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.861 (0.006) vs 0.886 (0.041) vs 0.951
Experiment [0, 1] [2]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.881 (0.004) vs 0.912 (0.056) vs 0.858
Experiment [2] [0, 1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.867 (0.009) vs 0.834 (0.196) vs 0.915


# Best of each function + original + no subcolumn in xgb
Experiment [0] [1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.931 (0.007) vs 0.951 (0.042) vs 0.890
Experiment [1] [0]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.902 (0.008) vs 0.930 (0.057) vs 0.943
Experiment [0, 1] [2]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.880 (0.004) vs 0.912 (0.059) vs 0.859
Experiment [2] [0, 1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.894 (0.008) vs 0.927 (0.059) vs 0.909
 

# Best of each function + original
Experiment [0] [1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.929 (0.008) vs 0.952 (0.037) vs 0.875
Experiment [1] [0]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.901 (0.008) vs 0.932 (0.056) vs 0.956
Experiment [0, 1] [2]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.879 (0.004) vs 0.909 (0.061) vs 0.859
Experiment [2] [0, 1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.892 (0.007) vs 0.926 (0.061) vs 0.901
 

Experiment [0] [1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.935 (0.006) vs 0.948 (0.043) vs 0.860
Experiment [1] [0]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.914 (0.006) vs 0.932 (0.062) vs 0.958
Experiment [0, 1] [2]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.891 (0.003) vs 0.910 (0.063) vs 0.853
Experiment [2] [0, 1]
 > > 35 	 Fit vs Val vs Test (MAc) = 0.906 (0.006) vs 0.925 (0.063) vs 0.900


trees = 25

Experiment [0] [1]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.935 (0.007) vs 0.947 (0.047) vs 0.854
Experiment [1] [0]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.911 (0.007) vs 0.923 (0.061) vs 0.947
Experiment [0, 1] [2]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.887 (0.004) vs 0.915 (0.055) vs 0.860
Experiment [2] [0, 1]
 > > 25 	 Fit vs Val vs Test (MAc) = 0.902 (0.006) vs 0.919 (0.064) vs 0.897

"""
